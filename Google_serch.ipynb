# %%
from urllib.parse import quote_plus
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.chrome.options import Options

import pandas as pd
keyword = pd.read_excel('/Users/monica/Documents/크롤링/MT_keywords for use.xlsx', index_col=[0])
keyword.head()
keyword_list = keyword.Keyword
len(keyword_list)

# %% [markdown]
# ### 검색키워드

# %%
search_keyword = []
discussion_search = 'inurl:forum|viewthread|showthread|viewtopic|showtopic|"index.php?topic" | intext:"reading this topic"|"next thread"|"next topic"|"send private message"'

for i in keyword_list:
    search_keyword.append(i+' '+discussion_search)
print(len(search_keyword))

# %%
baseUrl = 'https://www.google.com/search?q='

url=[]
for i in search_keyword:
    url.append(baseUrl + i)

print(len(url))

# %% [markdown]
# #### 돌리기

# %%
path = '/Users/monica/chromedriver'
driver = webdriver.Chrome(path)
driver.get(url_test)

html = driver.page_sorce
soup = BeautifulSoup(html)
