# %%
# %cd C:\Users\yukir\Documents\GitHub\Scrapper\py

from nlp_processing import *
set_global_determinism(seed=1337)

# %cd C:\Users\yukir\Documents\Monicas_workspace\Korea_medicine\LDA
# Out:
# C:\Users\yukir\Documents\GitHub\Scrapper\py
# True
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 12849277595586741181
# , name: "/device:XLA_CPU:0"
# device_type: "XLA_CPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 6761679850777099592
# physical_device_desc: "device: XLA_CPU device"
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 9883535296
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 3284864125567331726
# physical_device_desc: "device: 0, name: NVIDIA GeForce RTX 2080 Ti, pci bus id: 0000:01:00.0, compute capability: 7.5"
# , name: "/device:XLA_GPU:0"
# device_type: "XLA_GPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 6966865744471656762
# physical_device_desc: "device: XLA_GPU device"
# ]
# tf 2.2.0
# set_global_determinism(seed=1337) 이거 꼭 해라
# set_global_determinism(seed=1337) 이거 꼭 해라
# set_global_determinism(seed=1337) 이거 꼭 해라
# C:\Users\yukir\Documents\Monicas_workspace\Korea_medicine\LDA

# %%
review_data = pd.read_csv('stemmed_clean.csv', index_col = 0)
review_data.head()

df = review_data.copy()
# df = df.drop_duplicates()
# df = df.dropna()
# # df = df.drop(index=0)

# df = df.reset_index()
# df = df.drop(columns= '1')
print(df.shape)
df.head()
# Out:
# (14891, 9)
#    hospital  stars                                            reviews adress  \
# 0  청주나비솔한의원   10.0  병원이 전반적으로 깔끔해서 쾌적했어요대기가 좀 있지만 심하진 않은편이었고 간호사분들...     충북
# 1  청주나비솔한의원    7.5  체인 한의원이라서 망설였는데 시설도 깔끔하고 진료도 친절하게 너무 잘 봐주셨어요 그...     충북
# 2  청주나비솔한의원   10.0  사고 후유증으로 놀라서 한의원 방문 하였고 침 놔주시고 청심환 처방 해주셨습니다 편...     충북
# 3  청주나비솔한의원    8.8  오래 서있으면 발바닥이 너무 아파서 방문했습니다 진료랑 치료받는 건 괜찮았는데 별로...     충북
# 4  청주나비솔한의원   10.0  다이어트 환 처방 받았습니다 효과도 꽤 있었고 처음부터 무리하지 않는 선에서 체질에...     충북
#
#                                       cleaned_review  \
# 0  병원이 전반적으로 깔끔해서 쾌적했어요 대기가 좀 있지만 심하진 않은 편이었고 간호사...
# 1  체인 한의원이라서 망설였는데 시설도 깔끔하고 진료도 친절하게 너무 잘 봐주셨어요 그...
# 2  사고 후유증으로 놀라서 한의원 방문하였고 침 놔주시고 청심환 처방해주셨습니다 편안하...
# 3  오래 서 있으면 발바닥이 너무 아파서 방문했습니다 진료랑 치료받는 건 괜찮았는데 별...
# 4  다이어트 환 처방받았습니다 효과도 꽤 있었고 처음부터 무리하지 않는 선에서 체질에 ...
#
#                                                 noun  \
# 0  ['병원', '전반', '대기', '좀', '간호사', '의사', '설명', '주말...
# 1  ['체인', '한의원', '시설', '진료', '양심', '진료', '것', '믿음...
# 2  ['사고', '후유증', '한의원', '방문', '침', '청심환', '처방', '...
# 3  ['발바닥', '방문', '진료', '건', '별로', '효과', '못', '계속'...
# 4  ['다이어트', '환', '처방', '효과', '꽤', '처음', '선', '체질'...
#
#                                              stemmed  \
# 0  ['병원', '전반', '깔끔하다', '쾌적하다', '대기', '있다', '심하다'...
# 1  ['체인', '한의원', '망설이다', '시설', '깔끔하다', '진료', '친절하...
# 2  ['사고', '후유증', '놀라다', '한의원', '방문', '하다', '놓다', ...
# 3  ['서다', '있다', '발바닥', '아프다', '방문', '하다', '진료', '...
# 4  ['다이어트', '처방', '받다', '효과', '있다', '처음', '무리하다',...
#
#                                        stemmed_clean  \
# 0  [병원 전반 깔끔하다 쾌적하다 대기 있다 심하다 않다 펴다 간호사 친절하다 의사 친...
# 1  [체인 한의원 망설이다 시설 깔끔하다 진료 친절하다 자다 보다 양심 진료 하다 같다...
# 2  [사고 후유증 놀라다 한의원 방문 하다 놓다 청심환 처방 해주다 편안하다 휴식 하다...
# 3  [서다 있다 발바닥 아프다 방문 하다 진료 치료받다 괜찮다 별로 효과 보다 꾸준하다...
# 4  [다이어트 처방 받다 효과 있다 처음 무리하다 않다 체질 맞추다 진단 해주다 체질 ...
#
#                                           noun_clean
# 0         [병원 전반 대기 좀 간호사 의사 설명 주말 공휴일 진료 집 좀 가기 항상]
# 1          [체인 한의원 시설 진료 양심 진료 것 믿음 무조건 한약 치료 모습 믿음]
# 2       [사고 후유증 한의원 방문 침 청심환 처방 휴식 의원 내부 다음 기회 또 방문]
# 3                [발바닥 방문 진료 건 별로 효과 못 계속 대체 뭐 문제 계속]
# 4  [다이어트 환 처방 효과 꽤 처음 선 체질 진단 체질 평소 식 습관 운동 상태 확인...

# %%
df = df[['stars', 'cleaned_review']]
df= df[df['stars']<=6.2]
# df['noun_clean']=df['noun_clean'].replace('[','')
# df['noun_clean']=df['noun_clean'].replace(']','')
df.head()
# Out:
#      stars                                     cleaned_review
# 108    4.0  목 디스크 때문에 며칠 동안 목이 너무너무 아팠어요 마침 집 앞에 있는 한의원이 있...
# 188    6.0  지인 소개로 갔는데 친절하고 청결해 좋았고 기다리지 않았으며 늦은 시간에도 진료할 ...
# 201    5.5  침 치료만 좋아요 1진료실에서 침 치료할 때는 아픈 부위에다가 직접 침 놓으며 안 ...
# 204    5.5  박 선생님께서 충분한 설명과 치료 과정을 안내해주시고 꾸준히 치료받는 과정에서 저한...
# 210    5.5  평소에 허리랑 목이 안 좋았는데 갑자기 또 아파서 한의원에 방문했어요 침 맞는 게 ...

# %%
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from nltk.tokenize import RegexpTokenizer
from gensim import corpora, models
from gensim.models import CoherenceModel
import gensim
import matplotlib.pyplot as plt

# %%
from gensim.models.ldamodel import LdaModel 
from gensim.models.callbacks import CoherenceMetric 
from gensim import corpora 
from gensim.models.callbacks import PerplexityMetric 
import logging 
import pickle 
import pyLDAvis

from gensim.models.coherencemodel import CoherenceModel 
import matplotlib.pyplot as plt

import pyLDAvis.gensim
pyLDAvis.enable_notebook()

from konlpy.tag import Mecab 
from konlpy.tag import Okt
okt = Okt()
from tqdm import tqdm 
import re 
import pickle 
import csv

# %%
test_list = df['cleaned_review'].tolist()

test = test_list[0]
# print(test)

test_morphs = okt. pos(test, stem=True, norm = True)
for i in test_morphs:

    if i[1]=='Noun' and len(i[0])>1:
        print(i)
        
# print('------------------------------')
# print(test_morphs)

# %%
def get_nouns(tokenizer, sentence): 
    """ 단어의 길이가 2이상인 일반명사(NNG),
     고유명사(NNP), 외국어(SL)만을 반환한다. 
     :param tokenizer: 
     :param sentence: :return: """ 
    tagged = tokenizer.pos(sentence, stem = True, norm = True)
    words = []
    for i in tagged:
        if i[1]=='Noun' and len(i[0])>1:
            words.append(i[0])
        elif i[1]=='Adjective':
            words.append(i[0])

     
    return words

# %%
test_list = df['cleaned_review'].tolist()
test = test_list[0]
print(test)
a = get_nouns(okt, test)
print(a)
# Out:
# 목 디스크 때문에 며칠 동안 목이 너무너무 아팠어요 마침 집 앞에 있는 한의원이 있어서 가게 됐네요 진료실과 화장실 대기실은 깨끗했어요 하지만 의사선생님의 성의 없는 진료에 대해 실망스러웠어 요목 몇 번 만지고 침 놓고 끝났는데 낫지도 않고 효과도 미미했습니다 앞으로 만한 의원으로 다닐 것 같아요 원장님의 성의 있는 진료를 부탁드리며 리뷰를 남깁니다
# ['디스크', '때문', '며칠', '동안', '아프다', '마침', '있다', '한의원', '있다', '가게', '진료', '실과', '화장실', '대기실', '깨끗하다', '의사', '선생님', '성의', '없다', '진료', '대해', '실망', '스럽다', '지고', '효과', '미미하다', '의원', '같다', '원장', '성의', '있다', '진료', '부탁드리다', '리뷰']

# %%
def clean_text(text): 
    """ 한글, 영문, 숫자만 남기고 제거한다. 
    :param text: 
    :return: 
    """ 
    text = text.replace(".", " ").strip() 
    text = text.replace("·", " ").strip() 
    pattern = '[^ ㄱ-ㅣ가-힣|0-9|a-zA-Z]+' 
    text = re.sub(pattern=pattern, repl='', string=text) 
    return text 
    
def get_nouns(tokenizer, sentence): 
    """ 단어의 길이가 2이상인 일반명사(NNG),
     고유명사(NNP), 외국어(SL)만을 반환한다. 
     :param tokenizer: 
     :param sentence: :return: """ 
    tagged = tokenizer.pos(sentence, stem = True, norm = True)
    words = []
    for i in tagged:
        if i[1]=='Noun' and len(i[0])>1:
            words.append(i[0])
        elif i[1]=='Adjective':
            words.append(i[0])

     
    return words 
     
     
def tokenize(df): 
    tokenizer = okt
    processed_data = [] 
    for sent in tqdm(df['cleaned_review']):
        sentence = clean_text(sent.replace('\n', '').strip()) 
        processed_data.append(get_nouns(tokenizer, sentence)) 
        
    return processed_data
    
    
def save_processed_data(processed_data): 
    """ 토큰 분리한 데이터를 csv로 저장 :param processed_data: :return: """ 
    
    with open('stemm_token_adj.csv', 'w', newline='', encoding='utf-8') as f: 
        writer = csv.writer(f) 
        for data in processed_data:
             writer.writerow(data)

# %%
if __name__ == '__main__':
     # df = pd.read_csv('negative.csv', index_col = 0)
     processed_data = tokenize(df) # description 부분을 토크나이징 한다. 
     
     # 토큰 분리한 데이터를 저장 
     save_processed_data(processed_data)
# Out:
# 100%|██████████| 481/481 [00:10<00:00, 45.14it/s]

# %%
def compute_coherence_values(dictionary, corpus, texts, limit, start=2, step=3): 
    """ Compute c_v coherence for various number of topics 
    
    Parameters: 
    ---------- 
    dictionary : Gensim dictionary 
    corpus : Gensim corpus 
    texts : List of input texts 
    limit : Max num of topics
    Returns: 
    ------- 
    model_list : List of LDA topic models 
    coherence_values : Coherence values corresponding to the LDA model with respective number of topics 
    """ 
     
    coherence_values = [] 
    model_list = [] 
    
    for num_topics in range(start, limit, step): 
        model = LdaModel(corpus=corpus, id2word=dictionary, num_topics=num_topics) 
        model_list.append(model) 
        coherencemodel = CoherenceModel(model=model, texts=texts, dictionary=dictionary, coherence='c_v') 
        coherence_values.append(coherencemodel.get_coherence()) 
        
    return model_list, coherence_values 
    
    
def find_optimal_number_of_topics(dictionary, corpus, processed_data): 
    limit = 40; 
    start = 2; 
    step = 6; 
    
    model_list, coherence_values = compute_coherence_values(dictionary=dictionary, corpus=corpus, texts=processed_data, start=start, limit=limit, step=step) 
    x = range(start, limit, step) 
    plt.plot(x, coherence_values) 
    plt.xlabel("Num Topics") 
    plt.ylabel("Coherence score") 
    plt.legend(("coherence_values"), loc='best') 
    plt.show() 
    
if __name__ == '__main__': 
    processed_data = [sent.strip().split(",") for sent in tqdm(open('stemm_token_adj.csv', 'r', encoding='utf-8').readlines())] 
    # 정수 인코딩과 빈도수 생성 
    dictionary = corpora.Dictionary(processed_data) 
    
    # 출현빈도가 적거나 자주 등장하는 단어는 제거 
    dictionary.filter_extremes(no_below=10, no_above=0.05) 
    corpus = [dictionary.doc2bow(text) for text in processed_data] 
    print('Number of unique tokens: %d' % len(dictionary)) 
    print('Number of documents: %d' % len(corpus)) 
    
    logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO) 
    
    # 최적의 토픽 수 찾기 
    # 
    find_optimal_number_of_topics(dictionary, corpus, processed_data)
# Out:
# 100%|██████████| 481/481 [00:00<00:00, 240775.78it/s]
# 2021-11-03 20:04:26,964 : INFO : using symmetric alpha at 0.5
# 2021-11-03 20:04:26,964 : INFO : using symmetric eta at 0.5
# 2021-11-03 20:04:26,964 : INFO : using serial LDA version on this node
# 2021-11-03 20:04:26,966 : INFO : running online (single-pass) LDA training, 2 topics, 1 passes over the supplied corpus of 481 documents, updating model once every 481 documents, evaluating perplexity every 481 documents, iterating 50x with a convergence threshold of 0.001000
# 2021-11-03 20:04:26,967 : WARNING : too few updates, training might not converge; consider increasing the number of passes or iterations to improve accuracy
# Number of unique tokens: 167
# Number of documents: 481
# 2021-11-03 20:04:27,168 : INFO : -5.683 per-word bound, 51.4 perplexity estimate based on a held-out corpus of 481 documents with 2882 words
# 2021-11-03 20:04:27,169 : INFO : PROGRESS: pass 0, at document #481/481
# 2021-11-03 20:04:27,342 : INFO : topic #0 (0.500): 0.018*"피부" + 0.015*"부항" + 0.015*"자주" + 0.012*"얘기" + 0.012*"말씀" + 0.012*"침술" + 0.012*"대충" + 0.012*"모두" + 0.011*"진행" + 0.011*"추가"
# 2021-11-03 20:04:27,343 : INFO : topic #1 (0.500): 0.015*"주사" + 0.013*"이상" + 0.013*"정형외과" + 0.012*"기억" + 0.012*"복용" + 0.011*"체질" + 0.011*"꾸준하다" + 0.011*"시술" + 0.011*"주말" + 0.011*"저렴하다"
# 2021-11-03 20:04:27,344 : INFO : topic diff=0.401705, rho=1.000000
# 2021-11-03 20:04:27,344 : INFO : LdaModel lifecycle event {'msg': 'trained LdaModel(num_terms=167, num_topics=2, decay=0.5, chunksize=2000) in 0.38s', 'datetime': '2021-11-03T20:04:27.344452', 'gensim': '4.1.2', 'python': '3.8.11 (default, Aug  6 2021, 09:57:55) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19042-SP0', 'event': 'created'}
# 2021-11-03 20:04:27,345 : INFO : using ParallelWordOccurrenceAccumulator(processes=15, batch_size=64) to estimate probabilities from sliding windows
# 2021-11-03 20:04:30,114 : INFO : 15 accumulators retrieved from output queue
# 2021-11-03 20:04:30,126 : INFO : accumulated word occurrence stats for 883 virtual documents
# 2021-11-03 20:04:30,193 : INFO : using symmetric alpha at 0.125
# 2021-11-03 20:04:30,194 : INFO : using symmetric eta at 0.125
# 2021-11-03 20:04:30,194 : INFO : using serial LDA version on this node
# 2021-11-03 20:04:30,195 : INFO : running online (single-pass) LDA training, 8 topics, 1 passes over the supplied corpus of 481 documents, updating model once every 481 documents, evaluating perplexity every 481 documents, iterating 50x with a convergence threshold of 0.001000
# 2021-11-03 20:04:30,195 : WARNING : too few updates, training might not converge; consider increasing the number of passes or iterations to improve accuracy
# 2021-11-03 20:04:30,322 : INFO : -6.571 per-word bound, 95.1 perplexity estimate based on a held-out corpus of 481 documents with 2882 words
# 2021-11-03 20:04:30,324 : INFO : PROGRESS: pass 0, at document #481/481
# 2021-11-03 20:04:30,433 : INFO : topic #3 (0.125): 0.032*"기계" + 0.031*"굉장하다" + 0.022*"꾸준하다" + 0.022*"주차" + 0.022*"저렴하다" + 0.019*"접수" + 0.019*"양방" + 0.017*"태도" + 0.017*"건물" + 0.017*"여러"
# 2021-11-03 20:04:30,434 : INFO : topic #6 (0.125): 0.041*"복용" + 0.035*"대충" + 0.028*"추가" + 0.024*"이상" + 0.024*"얘기" + 0.018*"금액" + 0.018*"전혀" + 0.018*"권유" + 0.017*"모든" + 0.014*"개월"
# 2021-11-03 20:04:30,435 : INFO : topic #0 (0.125): 0.034*"부위" + 0.027*"결제" + 0.026*"피부" + 0.021*"개인" + 0.021*"찜질" + 0.021*"필요하다" + 0.021*"진짜" + 0.019*"아주" + 0.019*"꾸준하다" + 0.016*"경우"
# 2021-11-03 20:04:30,436 : INFO : topic #2 (0.125): 0.024*"이야기" + 0.024*"이상" + 0.024*"모두" + 0.021*"기억" + 0.019*"원래" + 0.019*"원인" + 0.018*"침대" + 0.018*"개월" + 0.018*"요한" + 0.018*"상세"
# 2021-11-03 20:04:30,436 : INFO : topic #5 (0.125): 0.035*"마음" + 0.031*"편하다" + 0.025*"꼼꼼하다" + 0.022*"보통" + 0.022*"건물" + 0.022*"시술" + 0.019*"여자" + 0.019*"전문" + 0.017*"부항" + 0.014*"진행"
# 2021-11-03 20:04:30,437 : INFO : topic diff=2.219186, rho=1.000000
# 2021-11-03 20:04:30,438 : INFO : LdaModel lifecycle event {'msg': 'trained LdaModel(num_terms=167, num_topics=8, decay=0.5, chunksize=2000) in 0.24s', 'datetime': '2021-11-03T20:04:30.438971', 'gensim': '4.1.2', 'python': '3.8.11 (default, Aug  6 2021, 09:57:55) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19042-SP0', 'event': 'created'}
# 2021-11-03 20:04:30,439 : INFO : using ParallelWordOccurrenceAccumulator(processes=15, batch_size=64) to estimate probabilities from sliding windows
# 2021-11-03 20:04:33,150 : INFO : 15 accumulators retrieved from output queue
# 2021-11-03 20:04:33,178 : INFO : accumulated word occurrence stats for 975 virtual documents
# 2021-11-03 20:04:33,418 : INFO : using symmetric alpha at 0.07142857142857142
# 2021-11-03 20:04:33,419 : INFO : using symmetric eta at 0.07142857142857142
# 2021-11-03 20:04:33,419 : INFO : using serial LDA version on this node
# 2021-11-03 20:04:33,420 : INFO : running online (single-pass) LDA training, 14 topics, 1 passes over the supplied corpus of 481 documents, updating model once every 481 documents, evaluating perplexity every 481 documents, iterating 50x with a convergence threshold of 0.001000
# 2021-11-03 20:04:33,420 : WARNING : too few updates, training might not converge; consider increasing the number of passes or iterations to improve accuracy
# 2021-11-03 20:04:33,545 : INFO : -7.351 per-word bound, 163.2 perplexity estimate based on a held-out corpus of 481 documents with 2882 words
# 2021-11-03 20:04:33,545 : INFO : PROGRESS: pass 0, at document #481/481
# 2021-11-03 20:04:33,644 : INFO : topic #13 (0.071): 0.025*"호전" + 0.021*"약간" + 0.020*"이야기" + 0.020*"지금" + 0.018*"건물" + 0.018*"말씀" + 0.018*"다만" + 0.017*"대충" + 0.015*"시원하다" + 0.015*"모두"
# 2021-11-03 20:04:33,645 : INFO : topic #12 (0.071): 0.047*"피부" + 0.030*"기계" + 0.030*"아주" + 0.030*"분위기" + 0.026*"침술" + 0.023*"주차" + 0.023*"양방" + 0.023*"입원" + 0.023*"다만" + 0.023*"이용"
# 2021-11-03 20:04:33,645 : INFO : topic #5 (0.071): 0.038*"간단하다" + 0.038*"태도" + 0.037*"복용" + 0.030*"마음" + 0.029*"진찰" + 0.023*"필요하다" + 0.023*"바쁘다" + 0.023*"꾸준하다" + 0.023*"여자" + 0.023*"굉장하다"
# 2021-11-03 20:04:33,646 : INFO : topic #2 (0.071): 0.028*"데스크" + 0.026*"전화" + 0.025*"가지" + 0.024*"침술" + 0.022*"추가" + 0.021*"하니" + 0.021*"주사" + 0.018*"기계" + 0.017*"정형외과" + 0.017*"접수"
# 2021-11-03 20:04:33,646 : INFO : topic #4 (0.071): 0.069*"자주" + 0.041*"가지" + 0.041*"진짜" + 0.025*"피부" + 0.025*"요법" + 0.025*"정확하다" + 0.025*"주변" + 0.021*"거리" + 0.017*"새롭다" + 0.017*"가장"
# 2021-11-03 20:04:33,646 : INFO : topic diff=5.676439, rho=1.000000
# 2021-11-03 20:04:33,647 : INFO : LdaModel lifecycle event {'msg': 'trained LdaModel(num_terms=167, num_topics=14, decay=0.5, chunksize=2000) in 0.23s', 'datetime': '2021-11-03T20:04:33.647605', 'gensim': '4.1.2', 'python': '3.8.11 (default, Aug  6 2021, 09:57:55) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19042-SP0', 'event': 'created'}
# 2021-11-03 20:04:33,649 : INFO : using ParallelWordOccurrenceAccumulator(processes=15, batch_size=64) to estimate probabilities from sliding windows
# 2021-11-03 20:04:36,361 : INFO : 15 accumulators retrieved from output queue
# 2021-11-03 20:04:36,399 : INFO : accumulated word occurrence stats for 981 virtual documents
# 2021-11-03 20:04:36,822 : INFO : using symmetric alpha at 0.05
# 2021-11-03 20:04:36,823 : INFO : using symmetric eta at 0.05
# 2021-11-03 20:04:36,823 : INFO : using serial LDA version on this node
# 2021-11-03 20:04:36,825 : INFO : running online (single-pass) LDA training, 20 topics, 1 passes over the supplied corpus of 481 documents, updating model once every 481 documents, evaluating perplexity every 481 documents, iterating 50x with a convergence threshold of 0.001000
# 2021-11-03 20:04:36,825 : WARNING : too few updates, training might not converge; consider increasing the number of passes or iterations to improve accuracy
# 2021-11-03 20:04:36,935 : INFO : -8.223 per-word bound, 298.7 perplexity estimate based on a held-out corpus of 481 documents with 2882 words
# 2021-11-03 20:04:36,936 : INFO : PROGRESS: pass 0, at document #481/481
# 2021-11-03 20:04:37,028 : INFO : topic #9 (0.050): 0.033*"시원하다" + 0.033*"보험" + 0.028*"개인" + 0.023*"가지" + 0.023*"꾸준하다" + 0.023*"침술" + 0.023*"데스크" + 0.023*"약간" + 0.022*"찜질" + 0.017*"위해"
# 2021-11-03 20:04:37,028 : INFO : topic #4 (0.050): 0.054*"저렴하다" + 0.044*"상세" + 0.033*"전혀" + 0.033*"친절" + 0.025*"모든" + 0.024*"원래" + 0.024*"방법" + 0.022*"접수" + 0.022*"침술" + 0.022*"편입"
# 2021-11-03 20:04:37,029 : INFO : topic #1 (0.050): 0.036*"개월" + 0.032*"리뷰" + 0.024*"소개" + 0.024*"간단하다" + 0.024*"가깝다" + 0.024*"실력" + 0.024*"부위" + 0.023*"꼼꼼하다" + 0.023*"개인" + 0.021*"복용"
# 2021-11-03 20:04:37,030 : INFO : topic #7 (0.050): 0.047*"발목" + 0.047*"입원" + 0.047*"교통사고" + 0.039*"호전" + 0.032*"요법" + 0.032*"진행" + 0.024*"대답" + 0.024*"진짜" + 0.024*"정확하다" + 0.024*"건물"
# 2021-11-03 20:04:37,030 : INFO : topic #14 (0.050): 0.053*"진행" + 0.049*"결제" + 0.042*"꼼꼼하다" + 0.033*"보통" + 0.026*"굉장하다" + 0.025*"부항" + 0.023*"진단" + 0.021*"안되다" + 0.020*"분위기" + 0.019*"카운터"
# 2021-11-03 20:04:37,031 : INFO : topic diff=9.908121, rho=1.000000
# 2021-11-03 20:04:37,031 : INFO : LdaModel lifecycle event {'msg': 'trained LdaModel(num_terms=167, num_topics=20, decay=0.5, chunksize=2000) in 0.21s', 'datetime': '2021-11-03T20:04:37.031446', 'gensim': '4.1.2', 'python': '3.8.11 (default, Aug  6 2021, 09:57:55) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19042-SP0', 'event': 'created'}
# 2021-11-03 20:04:37,034 : INFO : using ParallelWordOccurrenceAccumulator(processes=15, batch_size=64) to estimate probabilities from sliding windows
# 2021-11-03 20:04:39,991 : INFO : 15 accumulators retrieved from output queue
# 2021-11-03 20:04:40,037 : INFO : accumulated word occurrence stats for 984 virtual documents
# 2021-11-03 20:04:40,585 : INFO : using symmetric alpha at 0.038461538461538464
# 2021-11-03 20:04:40,586 : INFO : using symmetric eta at 0.038461538461538464
# 2021-11-03 20:04:40,586 : INFO : using serial LDA version on this node
# 2021-11-03 20:04:40,587 : INFO : running online (single-pass) LDA training, 26 topics, 1 passes over the supplied corpus of 481 documents, updating model once every 481 documents, evaluating perplexity every 481 documents, iterating 50x with a convergence threshold of 0.001000
# 2021-11-03 20:04:40,588 : WARNING : too few updates, training might not converge; consider increasing the number of passes or iterations to improve accuracy
# 2021-11-03 20:04:40,695 : INFO : -9.169 per-word bound, 575.7 perplexity estimate based on a held-out corpus of 481 documents with 2882 words
# 2021-11-03 20:04:40,695 : INFO : PROGRESS: pass 0, at document #481/481
# 2021-11-03 20:04:40,778 : INFO : topic #7 (0.038): 0.070*"리뷰" + 0.039*"부위" + 0.031*"피부" + 0.031*"개월" + 0.031*"처치" + 0.031*"진단" + 0.023*"전반" + 0.023*"침대" + 0.023*"체질" + 0.023*"꾸준하다"
# 2021-11-03 20:04:40,779 : INFO : topic #9 (0.038): 0.051*"자주" + 0.051*"요법" + 0.037*"보험" + 0.029*"소리" + 0.029*"그다지" + 0.023*"결제" + 0.022*"해주시" + 0.022*"한번" + 0.022*"찜질" + 0.022*"바쁘다"
# 2021-11-03 20:04:40,780 : INFO : topic #14 (0.038): 0.067*"주사" + 0.040*"데스크" + 0.040*"기본" + 0.040*"계시다" + 0.027*"인테리어" + 0.027*"전혀" + 0.027*"코로나" + 0.027*"태도" + 0.027*"주변" + 0.027*"시술"
# 2021-11-03 20:04:40,780 : INFO : topic #15 (0.038): 0.056*"마음" + 0.049*"개월" + 0.035*"복용" + 0.028*"시술" + 0.028*"편하다" + 0.028*"소개" + 0.024*"간단하다" + 0.021*"권유" + 0.021*"이상" + 0.021*"모든"
# 2021-11-03 20:04:40,781 : INFO : topic #3 (0.038): 0.038*"경우" + 0.030*"방법" + 0.030*"확인" + 0.030*"부항" + 0.030*"교통사고" + 0.030*"평일" + 0.023*"이후" + 0.023*"가지" + 0.023*"검색" + 0.023*"먼저"
# 2021-11-03 20:04:40,781 : INFO : topic diff=14.727118, rho=1.000000
# 2021-11-03 20:04:40,782 : INFO : LdaModel lifecycle event {'msg': 'trained LdaModel(num_terms=167, num_topics=26, decay=0.5, chunksize=2000) in 0.20s', 'datetime': '2021-11-03T20:04:40.782787', 'gensim': '4.1.2', 'python': '3.8.11 (default, Aug  6 2021, 09:57:55) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19042-SP0', 'event': 'created'}
# 2021-11-03 20:04:40,784 : INFO : using ParallelWordOccurrenceAccumulator(processes=15, batch_size=64) to estimate probabilities from sliding windows
# 2021-11-03 20:04:43,622 : INFO : 15 accumulators retrieved from output queue
# 2021-11-03 20:04:43,669 : INFO : accumulated word occurrence stats for 983 virtual documents
# 2021-11-03 20:04:44,368 : INFO : using symmetric alpha at 0.03125
# 2021-11-03 20:04:44,369 : INFO : using symmetric eta at 0.03125
# 2021-11-03 20:04:44,369 : INFO : using serial LDA version on this node
# 2021-11-03 20:04:44,370 : INFO : running online (single-pass) LDA training, 32 topics, 1 passes over the supplied corpus of 481 documents, updating model once every 481 documents, evaluating perplexity every 481 documents, iterating 50x with a convergence threshold of 0.001000
# 2021-11-03 20:04:44,371 : WARNING : too few updates, training might not converge; consider increasing the number of passes or iterations to improve accuracy
# 2021-11-03 20:04:44,481 : INFO : -10.358 per-word bound, 1312.4 perplexity estimate based on a held-out corpus of 481 documents with 2882 words
# 2021-11-03 20:04:44,482 : INFO : PROGRESS: pass 0, at document #481/481
# 2021-11-03 20:04:44,566 : INFO : topic #4 (0.031): 0.085*"진행" + 0.057*"자주" + 0.043*"경우" + 0.029*"만족하다" + 0.029*"건물" + 0.029*"친절" + 0.029*"전반" + 0.029*"원인" + 0.029*"가기" + 0.029*"모두"
# 2021-11-03 20:04:44,566 : INFO : topic #24 (0.031): 0.041*"요한" + 0.041*"힘들다" + 0.031*"전체" + 0.031*"특별하다" + 0.031*"피부" + 0.031*"다르다" + 0.031*"가깝다" + 0.031*"발목" + 0.031*"주말" + 0.020*"전문"
# 2021-11-03 20:04:44,567 : INFO : topic #23 (0.031): 0.048*"피부" + 0.039*"시술" + 0.039*"진단" + 0.029*"이야기" + 0.029*"추가" + 0.029*"가지" + 0.029*"소개" + 0.026*"주차" + 0.024*"주사" + 0.023*"편하다"
# 2021-11-03 20:04:44,568 : INFO : topic #7 (0.031): 0.044*"시술" + 0.039*"부위" + 0.030*"처치" + 0.026*"힘들다" + 0.026*"발목" + 0.026*"가게" + 0.026*"평일" + 0.021*"필요하다" + 0.017*"가장" + 0.017*"꼼꼼하다"
# 2021-11-03 20:04:44,568 : INFO : topic #1 (0.031): 0.066*"거의" + 0.047*"리뷰" + 0.029*"원인" + 0.029*"진찰" + 0.029*"얘기" + 0.029*"대충" + 0.029*"체질" + 0.019*"직접" + 0.019*"결제" + 0.019*"교통사고"
# 2021-11-03 20:04:44,569 : INFO : topic diff=19.782639, rho=1.000000
# 2021-11-03 20:04:44,570 : INFO : LdaModel lifecycle event {'msg': 'trained LdaModel(num_terms=167, num_topics=32, decay=0.5, chunksize=2000) in 0.20s', 'datetime': '2021-11-03T20:04:44.570184', 'gensim': '4.1.2', 'python': '3.8.11 (default, Aug  6 2021, 09:57:55) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19042-SP0', 'event': 'created'}
# 2021-11-03 20:04:44,572 : INFO : using ParallelWordOccurrenceAccumulator(processes=15, batch_size=64) to estimate probabilities from sliding windows
# 2021-11-03 20:04:47,342 : INFO : 15 accumulators retrieved from output queue
# 2021-11-03 20:04:47,391 : INFO : accumulated word occurrence stats for 984 virtual documents
# 2021-11-03 20:04:48,212 : INFO : using symmetric alpha at 0.02631578947368421
# 2021-11-03 20:04:48,213 : INFO : using symmetric eta at 0.02631578947368421
# 2021-11-03 20:04:48,213 : INFO : using serial LDA version on this node
# 2021-11-03 20:04:48,214 : INFO : running online (single-pass) LDA training, 38 topics, 1 passes over the supplied corpus of 481 documents, updating model once every 481 documents, evaluating perplexity every 481 documents, iterating 50x with a convergence threshold of 0.001000
# 2021-11-03 20:04:48,215 : WARNING : too few updates, training might not converge; consider increasing the number of passes or iterations to improve accuracy
# 2021-11-03 20:04:48,327 : INFO : -11.621 per-word bound, 3149.0 perplexity estimate based on a held-out corpus of 481 documents with 2882 words
# 2021-11-03 20:04:48,327 : INFO : PROGRESS: pass 0, at document #481/481
# 2021-11-03 20:04:48,410 : INFO : topic #2 (0.026): 0.054*"기억" + 0.041*"가면" + 0.041*"부위" + 0.041*"모두" + 0.027*"기본" + 0.027*"본인" + 0.027*"리뷰" + 0.027*"병행" + 0.027*"접근성" + 0.027*"입원"
# 2021-11-03 20:04:48,411 : INFO : topic #12 (0.026): 0.037*"질문" + 0.037*"권유" + 0.037*"요한" + 0.037*"위해" + 0.037*"본인" + 0.037*"어렵다" + 0.037*"건물" + 0.037*"약도" + 0.037*"보통" + 0.037*"전혀"
# 2021-11-03 20:04:48,411 : INFO : topic #31 (0.026): 0.070*"대충" + 0.058*"결제" + 0.047*"정형외과" + 0.035*"진짜" + 0.035*"주말" + 0.035*"이상" + 0.024*"부항" + 0.024*"어렵다" + 0.024*"여자" + 0.024*"검색"
# 2021-11-03 20:04:48,412 : INFO : topic #23 (0.026): 0.057*"시술" + 0.049*"양방" + 0.041*"주변" + 0.033*"발목" + 0.033*"편입" + 0.033*"이야기" + 0.033*"건물" + 0.033*"피부" + 0.025*"얘기" + 0.025*"모든"
# 2021-11-03 20:04:48,412 : INFO : topic #25 (0.026): 0.036*"진찰" + 0.036*"주변" + 0.036*"원래" + 0.036*"요한" + 0.036*"말씀" + 0.024*"다르다" + 0.024*"호전" + 0.024*"먼저" + 0.024*"접근성" + 0.024*"권유"
# 2021-11-03 20:04:48,413 : INFO : topic diff=25.308310, rho=1.000000
# 2021-11-03 20:04:48,414 : INFO : LdaModel lifecycle event {'msg': 'trained LdaModel(num_terms=167, num_topics=38, decay=0.5, chunksize=2000) in 0.20s', 'datetime': '2021-11-03T20:04:48.414462', 'gensim': '4.1.2', 'python': '3.8.11 (default, Aug  6 2021, 09:57:55) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19042-SP0', 'event': 'created'}
# 2021-11-03 20:04:48,417 : INFO : using ParallelWordOccurrenceAccumulator(processes=15, batch_size=64) to estimate probabilities from sliding windows
# 2021-11-03 20:04:51,165 : INFO : 15 accumulators retrieved from output queue
# 2021-11-03 20:04:51,221 : INFO : accumulated word occurrence stats for 984 virtual documents

# %%
if __name__ == '__main__': 
    processed_data = [sent.strip().split(",") for sent in tqdm(open('stemm_token.csv', 'r', encoding='utf-8').readlines())] 
    
    # 정수 인코딩과 빈도수 생성 d
    dictionary = corpora.Dictionary(processed_data) 
    
    # 출현빈도가 적거나 자주 등장하는 단어는 제거 
    dictionary.filter_extremes(no_below=10, no_above=0.05) 
    corpus = [dictionary.doc2bow(text) for text in processed_data] 
    print('Number of unique tokens: %d' % len(dictionary)) 
    print('Number of documents: %d' % len(corpus)) 
    
    logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO) 
    
    # 최적의 토픽 수 찾기 => 35개로 나옴 
    # # find_optimal_number_of_topics(dictionary, corpus, processed_data) 
    # # exit() 
    # 
    perplexity_logger = PerplexityMetric(corpus=corpus, logger='shell') 
    coherence_logger = CoherenceMetric(corpus=corpus, coherence="u_mass", logger='shell') 
    
    lda_model = LdaModel(corpus, id2word=dictionary, num_topics=7, passes=30, callbacks=[coherence_logger, perplexity_logger]) 
    
    topics = lda_model.print_topics(num_words=5) 
    for topic in topics: 
        print(topic) 
        
    # Compute Coherence Score using c_v 
    coherence_model_lda = CoherenceModel(model=lda_model, texts=processed_data, dictionary=dictionary, coherence='c_v') 
    coherence_lda = coherence_model_lda.get_coherence() 
    print('\nCoherence Score (c_v): ', coherence_lda) 
    
    # Compute Coherence Score using UMass 
    coherence_model_lda = CoherenceModel(model=lda_model, texts=processed_data, dictionary=dictionary, coherence="u_mass") 
    coherence_lda = coherence_model_lda.get_coherence() 
    print('\nCoherence Score (u_mass): ', coherence_lda) 
    
    
    # 저장 
    pickle.dump(corpus, open('lda_corpus.pkl', 'wb')) 
    dictionary.save('lda_dictionary.gensim') 
    lda_model.save('lda_model.gensim') 
    
    # pyLDAvis html 저장 
    lda_visualization = pyLDAvis.gensim.prepare(lda_model, corpus, dictionary, sort_topics=True) 
    pyLDAvis.save_html(lda_visualization, 'lda_v3.html')
# Out:
# 100%|██████████| 481/481 [00:00<00:00, 14968.65it/s]
# 2021-11-03 21:38:30,422 : INFO : adding document #0 to Dictionary(0 unique tokens: [])
# 2021-11-03 21:38:30,436 : INFO : built Dictionary(2363 unique tokens: ['가게', '대기실', '대해', '동안', '디스크']...) from 481 documents (total 12880 corpus positions)
# 2021-11-03 21:38:30,437 : INFO : Dictionary lifecycle event {'msg': "built Dictionary(2363 unique tokens: ['가게', '대기실', '대해', '동안', '디스크']...) from 481 documents (total 12880 corpus positions)", 'datetime': '2021-11-03T21:38:30.437762', 'gensim': '4.1.2', 'python': '3.8.11 (default, Aug  6 2021, 09:57:55) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19042-SP0', 'event': 'created'}
# 2021-11-03 21:38:30,439 : INFO : discarding 2221 tokens: [('대기실', 7), ('대해', 34), ('때문', 56), ('마침', 3), ('며칠', 8), ('선생님', 120), ('성의', 7), ('실과', 1), ('실망', 6), ('원장', 113)]...
# 2021-11-03 21:38:30,440 : INFO : keeping 142 tokens which were in no less than 10 and no more than 24 (=5.0%) documents
# 2021-11-03 21:38:30,441 : INFO : resulting dictionary: Dictionary(142 unique tokens: ['가게', '동안', '디스크', '리뷰', '소개']...)
# 2021-11-03 21:38:30,446 : INFO : using symmetric alpha at 0.14285714285714285
# 2021-11-03 21:38:30,447 : INFO : using symmetric eta at 0.14285714285714285
# 2021-11-03 21:38:30,447 : INFO : using serial LDA version on this node
# 2021-11-03 21:38:30,448 : INFO : running online (multi-pass) LDA training, 7 topics, 30 passes over the supplied corpus of 481 documents, updating model once every 481 documents, evaluating perplexity every 481 documents, iterating 50x with a convergence threshold of 0.001000
# 2021-11-03 21:38:30,589 : INFO : -6.322 per-word bound, 80.0 perplexity estimate based on a held-out corpus of 481 documents with 2458 words
# 2021-11-03 21:38:30,590 : INFO : PROGRESS: pass 0, at document #481/481
# Number of unique tokens: 142
# Number of documents: 481
# 2021-11-03 21:38:30,700 : INFO : topic #0 (0.143): 0.041*"자주" + 0.031*"질문" + 0.030*"대답" + 0.027*"응대" + 0.025*"원인" + 0.023*"진행" + 0.023*"마음" + 0.019*"대충" + 0.019*"말씀" + 0.019*"부위"
# 2021-11-03 21:38:30,701 : INFO : topic #1 (0.143): 0.035*"기억" + 0.027*"주사" + 0.025*"요한" + 0.022*"태도" + 0.022*"결과" + 0.019*"주말" + 0.019*"전혀" + 0.019*"개인" + 0.017*"잘못" + 0.017*"말씀"
# 2021-11-03 21:38:30,701 : INFO : topic #2 (0.143): 0.052*"입원" + 0.029*"진단" + 0.028*"다리" + 0.026*"부항" + 0.021*"리뷰" + 0.021*"아주" + 0.021*"기본" + 0.020*"디스크" + 0.018*"양방" + 0.018*"금액"
# 2021-11-03 21:38:30,703 : INFO : topic #3 (0.143): 0.035*"교통사고" + 0.035*"얘기" + 0.035*"피부" + 0.031*"대충" + 0.029*"체질" + 0.025*"편입" + 0.021*"확인" + 0.021*"리뷰" + 0.021*"발목" + 0.018*"다만"
# 2021-11-03 21:38:30,703 : INFO : topic #6 (0.143): 0.030*"시술" + 0.024*"모두" + 0.021*"진짜" + 0.020*"보통" + 0.019*"개월" + 0.018*"주사" + 0.017*"주말" + 0.015*"접수" + 0.015*"여자" + 0.015*"안내"
# 2021-11-03 21:38:30,704 : INFO : topic diff=1.920597, rho=1.000000
# 2021-11-03 21:38:30,708 : INFO : Epoch 0: Coherence estimate: -10.192097537527962
# 2021-11-03 21:38:30,822 : INFO : Epoch 0: Perplexity estimate: 51.8747146475688
# 2021-11-03 21:38:30,934 : INFO : -5.697 per-word bound, 51.9 perplexity estimate based on a held-out corpus of 481 documents with 2458 words
# 2021-11-03 21:38:30,934 : INFO : PROGRESS: pass 1, at document #481/481
# 2021-11-03 21:38:31,021 : INFO : topic #1 (0.143): 0.042*"기억" + 0.036*"주사" + 0.031*"태도" + 0.030*"요한" + 0.023*"잘못" + 0.022*"결과" + 0.021*"주말" + 0.020*"호전" + 0.019*"개인" + 0.019*"전혀"
# 2021-11-03 21:38:31,022 : INFO : topic #3 (0.143): 0.041*"교통사고" + 0.038*"대충" + 0.037*"얘기" + 0.036*"피부" + 0.029*"편입" + 0.026*"체질" + 0.025*"분위기" + 0.023*"그다지" + 0.023*"리뷰" + 0.022*"확인"
# 2021-11-03 21:38:31,022 : INFO : topic #4 (0.143): 0.038*"체질" + 0.037*"진행" + 0.034*"이상" + 0.027*"복용" + 0.024*"전혀" + 0.023*"제대로" + 0.022*"모두" + 0.019*"가면" + 0.019*"전문" + 0.018*"모든"
# 2021-11-03 21:38:31,023 : INFO : topic #0 (0.143): 0.048*"자주" + 0.038*"대답" + 0.033*"질문" + 0.033*"원인" + 0.032*"응대" + 0.023*"마음" + 0.023*"대충" + 0.022*"개선" + 0.021*"침술" + 0.021*"진행"
# 2021-11-03 21:38:31,023 : INFO : topic #5 (0.143): 0.032*"찜질" + 0.030*"결제" + 0.029*"진찰" + 0.027*"해주시" + 0.026*"기계" + 0.026*"얘기" + 0.022*"한번" + 0.021*"추가" + 0.019*"정형외과" + 0.018*"건강"
# 2021-11-03 21:38:31,023 : INFO : topic diff=0.294372, rho=0.577350
# 2021-11-03 21:38:31,027 : INFO : Epoch 1: Coherence estimate: -10.933854101321003
# 2021-11-03 21:38:31,128 : INFO : Epoch 1: Perplexity estimate: 48.832287979405926
# 2021-11-03 21:38:31,225 : INFO : -5.609 per-word bound, 48.8 perplexity estimate based on a held-out corpus of 481 documents with 2458 words
# 2021-11-03 21:38:31,226 : INFO : PROGRESS: pass 2, at document #481/481
# 2021-11-03 21:38:31,305 : INFO : topic #6 (0.143): 0.038*"시술" + 0.029*"진짜" + 0.026*"모두" + 0.023*"접수" + 0.022*"개월" + 0.019*"말씀" + 0.019*"보통" + 0.019*"주말" + 0.018*"발목" + 0.018*"안내"
# 2021-11-03 21:38:31,305 : INFO : topic #2 (0.143): 0.053*"입원" + 0.040*"진단" + 0.035*"부항" + 0.034*"다리" + 0.030*"기본" + 0.025*"양방" + 0.024*"디스크" + 0.023*"부황" + 0.022*"달라" + 0.022*"마음"
# 2021-11-03 21:38:31,306 : INFO : topic #1 (0.143): 0.048*"기억" + 0.041*"주사" + 0.035*"태도" + 0.033*"요한" + 0.027*"호전" + 0.026*"잘못" + 0.023*"주말" + 0.022*"결과" + 0.019*"전혀" + 0.019*"여러"
# 2021-11-03 21:38:31,306 : INFO : topic #5 (0.143): 0.034*"찜질" + 0.031*"결제" + 0.031*"진찰" + 0.030*"얘기" + 0.029*"기계" + 0.029*"해주시" + 0.024*"추가" + 0.022*"한번" + 0.022*"정형외과" + 0.019*"건강"
# 2021-11-03 21:38:31,307 : INFO : topic #4 (0.143): 0.041*"체질" + 0.037*"진행" + 0.037*"이상" + 0.031*"복용" + 0.026*"전혀" + 0.026*"제대로" + 0.023*"모두" + 0.021*"전문" + 0.021*"가면" + 0.019*"모든"
# 2021-11-03 21:38:31,307 : INFO : topic diff=0.271492, rho=0.500000
# 2021-11-03 21:38:31,311 : INFO : Epoch 2: Coherence estimate: -11.256989178197648
# 2021-11-03 21:38:31,410 : INFO : Epoch 2: Perplexity estimate: 46.988139965001714
# 2021-11-03 21:38:31,501 : INFO : -5.554 per-word bound, 47.0 perplexity estimate based on a held-out corpus of 481 documents with 2458 words
# 2021-11-03 21:38:31,501 : INFO : PROGRESS: pass 3, at document #481/481
# 2021-11-03 21:38:31,565 : INFO : topic #0 (0.143): 0.054*"자주" + 0.043*"대답" + 0.042*"원인" + 0.035*"응대" + 0.034*"질문" + 0.026*"마음" + 0.026*"평일" + 0.025*"대충" + 0.025*"개선" + 0.022*"침술"
# 2021-11-03 21:38:31,565 : INFO : topic #4 (0.143): 0.042*"체질" + 0.038*"이상" + 0.037*"진행" + 0.034*"복용" + 0.028*"전혀" + 0.027*"제대로" + 0.024*"모두" + 0.023*"전문" + 0.022*"가면" + 0.020*"주변"
# 2021-11-03 21:38:31,566 : INFO : topic #1 (0.143): 0.052*"기억" + 0.044*"주사" + 0.037*"태도" + 0.035*"요한" + 0.031*"호전" + 0.029*"잘못" + 0.026*"주말" + 0.023*"결과" + 0.021*"약간" + 0.021*"여러"
# 2021-11-03 21:38:31,567 : INFO : topic #2 (0.143): 0.054*"입원" + 0.044*"진단" + 0.037*"부항" + 0.035*"다리" + 0.033*"기본" + 0.027*"양방" + 0.026*"부황" + 0.025*"디스크" + 0.024*"마음" + 0.023*"동안"
# 2021-11-03 21:38:31,567 : INFO : topic #5 (0.143): 0.035*"찜질" + 0.033*"얘기" + 0.033*"결제" + 0.033*"진찰" + 0.032*"기계" + 0.029*"해주시" + 0.025*"추가" + 0.023*"정형외과" + 0.022*"보험" + 0.021*"한번"
# 2021-11-03 21:38:31,568 : INFO : topic diff=0.255859, rho=0.447214
# 2021-11-03 21:38:31,572 : INFO : Epoch 3: Coherence estimate: -10.917732369750581
# 2021-11-03 21:38:31,667 : INFO : Epoch 3: Perplexity estimate: 45.796004607852794
# 2021-11-03 21:38:31,754 : INFO : -5.516 per-word bound, 45.8 perplexity estimate based on a held-out corpus of 481 documents with 2458 words
# 2021-11-03 21:38:31,755 : INFO : PROGRESS: pass 4, at document #481/481
# 2021-11-03 21:38:31,826 : INFO : topic #3 (0.143): 0.049*"대충" + 0.048*"교통사고" + 0.037*"얘기" + 0.036*"그다지" + 0.035*"피부" + 0.033*"분위기" + 0.031*"편입" + 0.026*"상세" + 0.025*"건물" + 0.024*"요법"
# 2021-11-03 21:38:31,827 : INFO : topic #2 (0.143): 0.053*"입원" + 0.047*"진단" + 0.038*"부항" + 0.036*"다리" + 0.034*"기본" + 0.031*"양방" + 0.029*"부황" + 0.026*"디스크" + 0.025*"마음" + 0.024*"동안"
# 2021-11-03 21:38:31,827 : INFO : topic #5 (0.143): 0.035*"찜질" + 0.035*"얘기" + 0.034*"진찰" + 0.034*"결제" + 0.033*"기계" + 0.031*"해주시" + 0.027*"추가" + 0.024*"보험" + 0.024*"정형외과" + 0.021*"한번"
# 2021-11-03 21:38:31,828 : INFO : topic #0 (0.143): 0.055*"자주" + 0.044*"대답" + 0.044*"원인" + 0.036*"응대" + 0.034*"질문" + 0.029*"평일" + 0.028*"마음" + 0.026*"대충" + 0.025*"개선" + 0.022*"부위"
# 2021-11-03 21:38:31,828 : INFO : topic #6 (0.143): 0.039*"시술" + 0.033*"진짜" + 0.027*"접수" + 0.027*"모두" + 0.023*"개월" + 0.023*"발목" + 0.022*"나름" + 0.022*"말씀" + 0.020*"안내" + 0.020*"결제"
# 2021-11-03 21:38:31,829 : INFO : topic diff=0.239729, rho=0.408248
# 2021-11-03 21:38:31,833 : INFO : Epoch 4: Coherence estimate: -10.421547301195535
# 2021-11-03 21:38:31,924 : INFO : Epoch 4: Perplexity estimate: 44.894812132677195
# 2021-11-03 21:38:32,016 : INFO : -5.488 per-word bound, 44.9 perplexity estimate based on a held-out corpus of 481 documents with 2458 words
# 2021-11-03 21:38:32,016 : INFO : PROGRESS: pass 5, at document #481/481
# 2021-11-03 21:38:32,083 : INFO : topic #1 (0.143): 0.056*"기억" + 0.045*"주사" + 0.040*"태도" + 0.036*"요한" + 0.033*"호전" + 0.032*"잘못" + 0.030*"주말" + 0.025*"약간" + 0.024*"여러" + 0.024*"결과"
# 2021-11-03 21:38:32,084 : INFO : topic #2 (0.143): 0.054*"입원" + 0.049*"진단" + 0.039*"부항" + 0.036*"다리" + 0.035*"기본" + 0.033*"양방" + 0.032*"부황" + 0.028*"디스크" + 0.028*"마음" + 0.025*"동안"
# 2021-11-03 21:38:32,084 : INFO : topic #4 (0.143): 0.044*"체질" + 0.042*"이상" + 0.040*"복용" + 0.037*"진행" + 0.030*"전혀" + 0.029*"제대로" + 0.025*"전문" + 0.025*"모두" + 0.023*"가면" + 0.023*"주변"
# 2021-11-03 21:38:32,085 : INFO : topic #3 (0.143): 0.051*"대충" + 0.051*"교통사고" + 0.038*"그다지" + 0.036*"피부" + 0.035*"얘기" + 0.035*"분위기" + 0.031*"편입" + 0.027*"상세" + 0.026*"건물" + 0.025*"요법"
# 2021-11-03 21:38:32,085 : INFO : topic #5 (0.143): 0.037*"얘기" + 0.036*"찜질" + 0.035*"결제" + 0.035*"기계" + 0.034*"진찰" + 0.032*"해주시" + 0.029*"추가" + 0.026*"보험" + 0.025*"정형외과" + 0.021*"자기"
# 2021-11-03 21:38:32,086 : INFO : topic diff=0.220648, rho=0.377964
# 2021-11-03 21:38:32,091 : INFO : Epoch 5: Coherence estimate: -10.628044210112048
# 2021-11-03 21:38:32,181 : INFO : Epoch 5: Perplexity estimate: 44.18090156281833
# 2021-11-03 21:38:32,273 : INFO : -5.465 per-word bound, 44.2 perplexity estimate based on a held-out corpus of 481 documents with 2458 words
# 2021-11-03 21:38:32,273 : INFO : PROGRESS: pass 6, at document #481/481
# 2021-11-03 21:38:32,341 : INFO : topic #3 (0.143): 0.054*"대충" + 0.052*"교통사고" + 0.039*"그다지" + 0.037*"분위기" + 0.036*"피부" + 0.035*"얘기" + 0.031*"편입" + 0.027*"상세" + 0.027*"건물" + 0.026*"요법"
# 2021-11-03 21:38:32,342 : INFO : topic #5 (0.143): 0.038*"얘기" + 0.036*"결제" + 0.036*"찜질" + 0.036*"기계" + 0.034*"진찰" + 0.033*"해주시" + 0.029*"추가" + 0.027*"보험" + 0.025*"정형외과" + 0.023*"여자"
# 2021-11-03 21:38:32,342 : INFO : topic #6 (0.143): 0.039*"시술" + 0.034*"진짜" + 0.029*"접수" + 0.027*"모두" + 0.025*"발목" + 0.025*"나름" + 0.024*"주차" + 0.023*"말씀" + 0.023*"개월" + 0.021*"안내"
# 2021-11-03 21:38:32,342 : INFO : topic #2 (0.143): 0.053*"입원" + 0.050*"진단" + 0.040*"부항" + 0.036*"다리" + 0.036*"기본" + 0.034*"양방" + 0.034*"부황" + 0.030*"마음" + 0.030*"디스크" + 0.026*"동안"
# 2021-11-03 21:38:32,343 : INFO : topic #0 (0.143): 0.059*"자주" + 0.047*"원인" + 0.046*"대답" + 0.038*"질문" + 0.036*"응대" + 0.033*"평일" + 0.027*"대충" + 0.025*"개선" + 0.024*"마음" + 0.024*"진행"
# 2021-11-03 21:38:32,343 : INFO : topic diff=0.198193, rho=0.353553
# 2021-11-03 21:38:32,346 : INFO : Epoch 6: Coherence estimate: -10.414102265824557
# 2021-11-03 21:38:32,441 : INFO : Epoch 6: Perplexity estimate: 43.62539641717931
# 2021-11-03 21:38:32,530 : INFO : -5.447 per-word bound, 43.6 perplexity estimate based on a held-out corpus of 481 documents with 2458 words
# 2021-11-03 21:38:32,531 : INFO : PROGRESS: pass 7, at document #481/481
# 2021-11-03 21:38:32,598 : INFO : topic #3 (0.143): 0.055*"대충" + 0.053*"교통사고" + 0.039*"그다지" + 0.038*"분위기" + 0.035*"피부" + 0.034*"얘기" + 0.031*"편입" + 0.028*"건물" + 0.027*"상세" + 0.026*"아주"
# 2021-11-03 21:38:32,598 : INFO : topic #0 (0.143): 0.061*"자주" + 0.048*"원인" + 0.047*"대답" + 0.038*"질문" + 0.036*"응대" + 0.034*"평일" + 0.027*"대충" + 0.025*"개선" + 0.025*"피부" + 0.025*"진행"
# 2021-11-03 21:38:32,599 : INFO : topic #4 (0.143): 0.046*"체질" + 0.044*"이상" + 0.043*"복용" + 0.037*"진행" + 0.031*"전혀" + 0.030*"제대로" + 0.026*"전문" + 0.025*"모두" + 0.025*"주변" + 0.024*"가면"
# 2021-11-03 21:38:32,599 : INFO : topic #5 (0.143): 0.039*"얘기" + 0.037*"결제" + 0.037*"기계" + 0.036*"찜질" + 0.035*"진찰" + 0.034*"해주시" + 0.030*"추가" + 0.028*"보험" + 0.025*"정형외과" + 0.024*"여자"
# 2021-11-03 21:38:32,599 : INFO : topic #2 (0.143): 0.053*"입원" + 0.051*"진단" + 0.040*"부항" + 0.036*"다리" + 0.036*"기본" + 0.035*"부황" + 0.035*"양방" + 0.031*"디스크" + 0.031*"마음" + 0.026*"동안"
# 2021-11-03 21:38:32,600 : INFO : topic diff=0.174587, rho=0.333333
# 2021-11-03 21:38:32,605 : INFO : Epoch 7: Coherence estimate: -10.544621490561962
# 2021-11-03 21:38:32,696 : INFO : Epoch 7: Perplexity estimate: 43.234958450932375
# 2021-11-03 21:38:32,786 : INFO : -5.434 per-word bound, 43.2 perplexity estimate based on a held-out corpus of 481 documents with 2458 words
# 2021-11-03 21:38:32,786 : INFO : PROGRESS: pass 8, at document #481/481
# 2021-11-03 21:38:32,845 : INFO : topic #1 (0.143): 0.058*"기억" + 0.044*"주사" + 0.043*"태도" + 0.038*"주말" + 0.035*"요한" + 0.034*"호전" + 0.032*"잘못" + 0.029*"약간" + 0.026*"침술" + 0.026*"침대"
# 2021-11-03 21:38:32,846 : INFO : topic #6 (0.143): 0.039*"시술" + 0.035*"진짜" + 0.030*"접수" + 0.028*"모두" + 0.026*"발목" + 0.026*"나름" + 0.026*"주차" + 0.025*"말씀" + 0.023*"개월" + 0.022*"안내"
# 2021-11-03 21:38:32,847 : INFO : topic #2 (0.143): 0.053*"입원" + 0.051*"진단" + 0.041*"부항" + 0.036*"다리" + 0.036*"부황" + 0.036*"양방" + 0.036*"기본" + 0.032*"디스크" + 0.032*"마음" + 0.026*"동안"
# 2021-11-03 21:38:32,847 : INFO : topic #5 (0.143): 0.040*"얘기" + 0.038*"기계" + 0.038*"결제" + 0.036*"찜질" + 0.035*"진찰" + 0.034*"해주시" + 0.030*"추가" + 0.029*"보험" + 0.025*"여자" + 0.025*"정형외과"
# 2021-11-03 21:38:32,848 : INFO : topic #3 (0.143): 0.055*"대충" + 0.054*"교통사고" + 0.040*"그다지" + 0.040*"분위기" + 0.036*"얘기" + 0.035*"피부" + 0.030*"편입" + 0.029*"건물" + 0.027*"아주" + 0.027*"상세"
# 2021-11-03 21:38:32,848 : INFO : topic diff=0.152250, rho=0.316228
# 2021-11-03 21:38:32,851 : INFO : Epoch 8: Coherence estimate: -10.623179948309334
# 2021-11-03 21:38:32,941 : INFO : Epoch 8: Perplexity estimate: 42.92145709281064
# 2021-11-03 21:38:33,027 : INFO : -5.424 per-word bound, 42.9 perplexity estimate based on a held-out corpus of 481 documents with 2458 words
# 2021-11-03 21:38:33,027 : INFO : PROGRESS: pass 9, at document #481/481
# 2021-11-03 21:38:33,094 : INFO : topic #2 (0.143): 0.053*"입원" + 0.052*"진단" + 0.042*"부항" + 0.037*"부황" + 0.037*"양방" + 0.036*"다리" + 0.036*"기본" + 0.033*"디스크" + 0.033*"마음" + 0.026*"동안"
# 2021-11-03 21:38:33,095 : INFO : topic #6 (0.143): 0.040*"시술" + 0.036*"진짜" + 0.031*"접수" + 0.028*"모두" + 0.027*"발목" + 0.027*"나름" + 0.027*"주차" + 0.025*"말씀" + 0.023*"안내" + 0.022*"개월"
# 2021-11-03 21:38:33,096 : INFO : topic #0 (0.143): 0.062*"자주" + 0.048*"원인" + 0.048*"대답" + 0.039*"질문" + 0.036*"응대" + 0.034*"평일" + 0.028*"대충" + 0.027*"피부" + 0.025*"개선" + 0.025*"진행"
# 2021-11-03 21:38:33,096 : INFO : topic #1 (0.143): 0.058*"기억" + 0.044*"주사" + 0.043*"태도" + 0.039*"주말" + 0.034*"호전" + 0.034*"요한" + 0.032*"잘못" + 0.031*"약간" + 0.028*"침술" + 0.027*"침대"
# 2021-11-03 21:38:33,097 : INFO : topic #4 (0.143): 0.047*"체질" + 0.046*"복용" + 0.045*"이상" + 0.036*"진행" + 0.030*"전혀" + 0.030*"제대로" + 0.026*"모두" + 0.026*"전문" + 0.026*"주변" + 0.025*"가면"
# 2021-11-03 21:38:33,097 : INFO : topic diff=0.133813, rho=0.301511
# 2021-11-03 21:38:33,101 : INFO : Epoch 9: Coherence estimate: -10.628154165128432
# 2021-11-03 21:38:33,189 : INFO : Epoch 9: Perplexity estimate: 42.65163485472358
# 2021-11-03 21:38:33,274 : INFO : -5.415 per-word bound, 42.7 perplexity estimate based on a held-out corpus of 481 documents with 2458 words
# 2021-11-03 21:38:33,274 : INFO : PROGRESS: pass 10, at document #481/481
# 2021-11-03 21:38:33,337 : INFO : topic #2 (0.143): 0.053*"입원" + 0.053*"진단" + 0.043*"부항" + 0.038*"부황" + 0.038*"양방" + 0.037*"다리" + 0.036*"기본" + 0.034*"디스크" + 0.033*"마음" + 0.026*"동안"
# 2021-11-03 21:38:33,338 : INFO : topic #3 (0.143): 0.057*"대충" + 0.056*"교통사고" + 0.042*"분위기" + 0.041*"그다지" + 0.036*"피부" + 0.036*"얘기" + 0.032*"건물" + 0.030*"편입" + 0.030*"아주" + 0.028*"상세"
# 2021-11-03 21:38:33,338 : INFO : topic #0 (0.143): 0.063*"자주" + 0.048*"대답" + 0.048*"원인" + 0.039*"질문" + 0.036*"응대" + 0.035*"평일" + 0.029*"대충" + 0.027*"피부" + 0.025*"개선" + 0.025*"진행"
# 2021-11-03 21:38:33,340 : INFO : topic #6 (0.143): 0.040*"시술" + 0.037*"진짜" + 0.031*"접수" + 0.028*"모두" + 0.028*"주차" + 0.027*"나름" + 0.027*"발목" + 0.026*"말씀" + 0.023*"안내" + 0.022*"개월"
# 2021-11-03 21:38:33,340 : INFO : topic #1 (0.143): 0.058*"기억" + 0.044*"주사" + 0.043*"태도" + 0.040*"주말" + 0.034*"호전" + 0.034*"요한" + 0.032*"잘못" + 0.032*"약간" + 0.029*"침술" + 0.027*"침대"
# 2021-11-03 21:38:33,340 : INFO : topic diff=0.118042, rho=0.288675
# 2021-11-03 21:38:33,344 : INFO : Epoch 10: Coherence estimate: -10.627869954314374
# 2021-11-03 21:38:33,433 : INFO : Epoch 10: Perplexity estimate: 42.42390346151421
# 2021-11-03 21:38:33,519 : INFO : -5.406 per-word bound, 42.4 perplexity estimate based on a held-out corpus of 481 documents with 2458 words
# 2021-11-03 21:38:33,519 : INFO : PROGRESS: pass 11, at document #481/481
# 2021-11-03 21:38:33,583 : INFO : topic #6 (0.143): 0.040*"시술" + 0.038*"진짜" + 0.031*"접수" + 0.029*"모두" + 0.028*"주차" + 0.028*"나름" + 0.028*"발목" + 0.026*"말씀" + 0.023*"안내" + 0.022*"개월"
# 2021-11-03 21:38:33,583 : INFO : topic #3 (0.143): 0.058*"대충" + 0.057*"교통사고" + 0.043*"분위기" + 0.041*"그다지" + 0.036*"피부" + 0.036*"얘기" + 0.032*"건물" + 0.031*"아주" + 0.028*"편입" + 0.028*"상세"
# 2021-11-03 21:38:33,584 : INFO : topic #2 (0.143): 0.054*"입원" + 0.053*"진단" + 0.043*"부항" + 0.038*"양방" + 0.038*"부황" + 0.037*"다리" + 0.035*"기본" + 0.035*"디스크" + 0.034*"마음" + 0.027*"동안"
# 2021-11-03 21:38:33,584 : INFO : topic #1 (0.143): 0.057*"기억" + 0.043*"주사" + 0.043*"태도" + 0.041*"주말" + 0.034*"호전" + 0.033*"요한" + 0.032*"약간" + 0.032*"잘못" + 0.031*"침술" + 0.028*"침대"
# 2021-11-03 21:38:33,584 : INFO : topic #4 (0.143): 0.048*"체질" + 0.046*"복용" + 0.045*"이상" + 0.035*"진행" + 0.030*"제대로" + 0.029*"전혀" + 0.027*"모두" + 0.027*"주변" + 0.026*"전문" + 0.025*"가면"
# 2021-11-03 21:38:33,585 : INFO : topic diff=0.104453, rho=0.277350
# 2021-11-03 21:38:33,590 : INFO : Epoch 11: Coherence estimate: -10.627510437233452
# 2021-11-03 21:38:33,680 : INFO : Epoch 11: Perplexity estimate: 42.23015912576985
# 2021-11-03 21:38:33,766 : INFO : -5.400 per-word bound, 42.2 perplexity estimate based on a held-out corpus of 481 documents with 2458 words
# 2021-11-03 21:38:33,766 : INFO : PROGRESS: pass 12, at document #481/481
# 2021-11-03 21:38:33,830 : INFO : topic #3 (0.143): 0.058*"대충" + 0.057*"교통사고" + 0.043*"분위기" + 0.041*"그다지" + 0.036*"피부" + 0.036*"얘기" + 0.033*"건물" + 0.032*"아주" + 0.028*"상세" + 0.028*"차도"
# 2021-11-03 21:38:33,831 : INFO : topic #2 (0.143): 0.054*"입원" + 0.053*"진단" + 0.043*"부항" + 0.039*"양방" + 0.039*"부황" + 0.037*"다리" + 0.036*"디스크" + 0.035*"기본" + 0.034*"마음" + 0.027*"동안"
# 2021-11-03 21:38:33,831 : INFO : topic #4 (0.143): 0.049*"체질" + 0.046*"복용" + 0.045*"이상" + 0.034*"진행" + 0.031*"제대로" + 0.029*"전혀" + 0.028*"모두" + 0.027*"주변" + 0.026*"전문" + 0.026*"가면"
# 2021-11-03 21:38:33,832 : INFO : topic #5 (0.143): 0.043*"얘기" + 0.042*"기계" + 0.039*"결제" + 0.036*"해주시" + 0.035*"찜질" + 0.035*"진찰" + 0.032*"추가" + 0.029*"보험" + 0.027*"여자" + 0.026*"정형외과"
# 2021-11-03 21:38:33,832 : INFO : topic #6 (0.143): 0.041*"시술" + 0.038*"진짜" + 0.032*"접수" + 0.029*"주차" + 0.029*"모두" + 0.028*"나름" + 0.028*"발목" + 0.026*"말씀" + 0.023*"안내" + 0.022*"결제"
# 2021-11-03 21:38:33,832 : INFO : topic diff=0.091676, rho=0.267261
# 2021-11-03 21:38:33,837 : INFO : Epoch 12: Coherence estimate: -10.347497351773132
# 2021-11-03 21:38:33,921 : INFO : Epoch 12: Perplexity estimate: 42.04662079845369
# 2021-11-03 21:38:34,008 : INFO : -5.394 per-word bound, 42.0 perplexity estimate based on a held-out corpus of 481 documents with 2458 words
# 2021-11-03 21:38:34,009 : INFO : PROGRESS: pass 13, at document #481/481
# 2021-11-03 21:38:34,071 : INFO : topic #5 (0.143): 0.044*"얘기" + 0.042*"기계" + 0.039*"결제" + 0.037*"해주시" + 0.035*"진찰" + 0.035*"찜질" + 0.032*"추가" + 0.030*"보험" + 0.027*"여자" + 0.026*"정형외과"
# 2021-11-03 21:38:34,072 : INFO : topic #6 (0.143): 0.042*"시술" + 0.039*"진짜" + 0.032*"접수" + 0.030*"주차" + 0.029*"모두" + 0.028*"나름" + 0.028*"발목" + 0.027*"말씀" + 0.024*"안내" + 0.022*"결제"
# 2021-11-03 21:38:34,072 : INFO : topic #3 (0.143): 0.059*"대충" + 0.057*"교통사고" + 0.044*"분위기" + 0.042*"그다지" + 0.037*"피부" + 0.036*"얘기" + 0.033*"아주" + 0.033*"건물" + 0.028*"상세" + 0.028*"차도"
# 2021-11-03 21:38:34,073 : INFO : topic #1 (0.143): 0.057*"기억" + 0.043*"태도" + 0.043*"주말" + 0.043*"주사" + 0.034*"호전" + 0.034*"침술" + 0.033*"약간" + 0.033*"요한" + 0.031*"잘못" + 0.028*"침대"
# 2021-11-03 21:38:34,073 : INFO : topic #4 (0.143): 0.049*"체질" + 0.046*"복용" + 0.046*"이상" + 0.034*"진행" + 0.031*"제대로" + 0.029*"전혀" + 0.028*"모두" + 0.027*"주변" + 0.026*"전문" + 0.026*"가면"
# 2021-11-03 21:38:34,074 : INFO : topic diff=0.080517, rho=0.258199
# 2021-11-03 21:38:34,078 : INFO : Epoch 13: Coherence estimate: -10.34484048907642
# 2021-11-03 21:38:34,163 : INFO : Epoch 13: Perplexity estimate: 41.86943945109526
# 2021-11-03 21:38:34,248 : INFO : -5.388 per-word bound, 41.9 perplexity estimate based on a held-out corpus of 481 documents with 2458 words
# 2021-11-03 21:38:34,249 : INFO : PROGRESS: pass 14, at document #481/481
# 2021-11-03 21:38:34,311 : INFO : topic #3 (0.143): 0.060*"대충" + 0.058*"교통사고" + 0.044*"분위기" + 0.042*"그다지" + 0.037*"피부" + 0.036*"얘기" + 0.034*"아주" + 0.033*"건물" + 0.029*"차도" + 0.028*"상세"
# 2021-11-03 21:38:34,311 : INFO : topic #1 (0.143): 0.057*"기억" + 0.043*"주말" + 0.043*"태도" + 0.043*"주사" + 0.035*"침술" + 0.034*"호전" + 0.034*"약간" + 0.033*"요한" + 0.031*"잘못" + 0.029*"침대"
# 2021-11-03 21:38:34,312 : INFO : topic #5 (0.143): 0.045*"얘기" + 0.042*"기계" + 0.039*"결제" + 0.037*"해주시" + 0.035*"진찰" + 0.034*"찜질" + 0.032*"추가" + 0.030*"보험" + 0.027*"여자" + 0.027*"정형외과"
# 2021-11-03 21:38:34,312 : INFO : topic #4 (0.143): 0.049*"체질" + 0.046*"복용" + 0.046*"이상" + 0.034*"진행" + 0.031*"제대로" + 0.029*"전혀" + 0.028*"모두" + 0.028*"주변" + 0.026*"전문" + 0.026*"가면"
# 2021-11-03 21:38:34,313 : INFO : topic #0 (0.143): 0.066*"자주" + 0.049*"대답" + 0.048*"원인" + 0.039*"질문" + 0.037*"평일" + 0.036*"응대" + 0.030*"대충" + 0.029*"피부" + 0.025*"개선" + 0.025*"진행"
# 2021-11-03 21:38:34,313 : INFO : topic diff=0.071368, rho=0.250000
# 2021-11-03 21:38:34,317 : INFO : Epoch 14: Coherence estimate: -10.346553425701982
# 2021-11-03 21:38:34,409 : INFO : Epoch 14: Perplexity estimate: 41.730440616416026
# 2021-11-03 21:38:34,496 : INFO : -5.383 per-word bound, 41.7 perplexity estimate based on a held-out corpus of 481 documents with 2458 words
# 2021-11-03 21:38:34,496 : INFO : PROGRESS: pass 15, at document #481/481
# 2021-11-03 21:38:34,561 : INFO : topic #4 (0.143): 0.049*"체질" + 0.047*"이상" + 0.046*"복용" + 0.034*"진행" + 0.031*"제대로" + 0.028*"모두" + 0.028*"전혀" + 0.028*"주변" + 0.026*"가면" + 0.026*"전문"
# 2021-11-03 21:38:34,562 : INFO : topic #1 (0.143): 0.057*"기억" + 0.044*"주말" + 0.043*"태도" + 0.043*"주사" + 0.036*"침술" + 0.034*"호전" + 0.034*"약간" + 0.032*"요한" + 0.031*"잘못" + 0.029*"침대"
# 2021-11-03 21:38:34,562 : INFO : topic #2 (0.143): 0.054*"입원" + 0.054*"진단" + 0.044*"부항" + 0.040*"부황" + 0.040*"양방" + 0.037*"다리" + 0.036*"디스크" + 0.035*"마음" + 0.034*"기본" + 0.027*"동안"
# 2021-11-03 21:38:34,563 : INFO : topic #5 (0.143): 0.045*"얘기" + 0.043*"기계" + 0.039*"결제" + 0.038*"해주시" + 0.035*"진찰" + 0.034*"찜질" + 0.033*"추가" + 0.030*"보험" + 0.027*"여자" + 0.027*"정형외과"
# 2021-11-03 21:38:34,563 : INFO : topic #3 (0.143): 0.060*"대충" + 0.058*"교통사고" + 0.044*"분위기" + 0.042*"그다지" + 0.037*"피부" + 0.036*"얘기" + 0.034*"아주" + 0.033*"건물" + 0.029*"차도" + 0.028*"상세"
# 2021-11-03 21:38:34,563 : INFO : topic diff=0.064270, rho=0.242536
# 2021-11-03 21:38:34,567 : INFO : Epoch 15: Coherence estimate: -10.34778588062793
# 2021-11-03 21:38:34,660 : INFO : Epoch 15: Perplexity estimate: 41.59892758092321
# 2021-11-03 21:38:34,742 : INFO : -5.378 per-word bound, 41.6 perplexity estimate based on a held-out corpus of 481 documents with 2458 words
# 2021-11-03 21:38:34,743 : INFO : PROGRESS: pass 16, at document #481/481
# 2021-11-03 21:38:34,809 : INFO : topic #1 (0.143): 0.057*"기억" + 0.044*"주말" + 0.043*"태도" + 0.043*"주사" + 0.036*"침술" + 0.035*"약간" + 0.035*"호전" + 0.032*"요한" + 0.031*"잘못" + 0.029*"침대"
# 2021-11-03 21:38:34,810 : INFO : topic #4 (0.143): 0.050*"체질" + 0.047*"이상" + 0.046*"복용" + 0.034*"진행" + 0.031*"제대로" + 0.029*"모두" + 0.028*"전혀" + 0.028*"주변" + 0.026*"가면" + 0.026*"전문"
# 2021-11-03 21:38:34,810 : INFO : topic #3 (0.143): 0.060*"대충" + 0.058*"교통사고" + 0.044*"분위기" + 0.042*"그다지" + 0.037*"피부" + 0.036*"얘기" + 0.035*"아주" + 0.033*"건물" + 0.030*"차도" + 0.029*"상세"
# 2021-11-03 21:38:34,811 : INFO : topic #6 (0.143): 0.045*"시술" + 0.041*"진짜" + 0.032*"접수" + 0.032*"주차" + 0.029*"모두" + 0.029*"나름" + 0.028*"발목" + 0.027*"말씀" + 0.024*"안내" + 0.023*"결제"
# 2021-11-03 21:38:34,811 : INFO : topic #0 (0.143): 0.067*"자주" + 0.049*"대답" + 0.048*"원인" + 0.039*"질문" + 0.038*"평일" + 0.036*"응대" + 0.031*"대충" + 0.029*"피부" + 0.026*"처치" + 0.026*"부위"
# 2021-11-03 21:38:34,811 : INFO : topic diff=0.057968, rho=0.235702
# 2021-11-03 21:38:34,815 : INFO : Epoch 16: Coherence estimate: -10.064426577738896
# 2021-11-03 21:38:34,902 : INFO : Epoch 16: Perplexity estimate: 41.485508210774974
# 2021-11-03 21:38:34,988 : INFO : -5.375 per-word bound, 41.5 perplexity estimate based on a held-out corpus of 481 documents with 2458 words
# 2021-11-03 21:38:34,989 : INFO : PROGRESS: pass 17, at document #481/481
# 2021-11-03 21:38:35,045 : INFO : topic #0 (0.143): 0.068*"자주" + 0.049*"대답" + 0.048*"원인" + 0.039*"질문" + 0.038*"평일" + 0.036*"응대" + 0.032*"대충" + 0.029*"피부" + 0.027*"처치" + 0.026*"부위"
# 2021-11-03 21:38:35,046 : INFO : topic #1 (0.143): 0.057*"기억" + 0.044*"주말" + 0.043*"태도" + 0.043*"주사" + 0.037*"침술" + 0.035*"약간" + 0.035*"호전" + 0.032*"요한" + 0.031*"잘못" + 0.029*"침대"
# 2021-11-03 21:38:35,047 : INFO : topic #2 (0.143): 0.054*"입원" + 0.054*"진단" + 0.045*"부항" + 0.040*"부황" + 0.040*"양방" + 0.037*"다리" + 0.037*"디스크" + 0.035*"마음" + 0.034*"기본" + 0.027*"동안"
# 2021-11-03 21:38:35,047 : INFO : topic #4 (0.143): 0.051*"체질" + 0.048*"이상" + 0.046*"복용" + 0.033*"진행" + 0.032*"제대로" + 0.029*"모두" + 0.028*"전혀" + 0.028*"주변" + 0.026*"가면" + 0.026*"전문"
# 2021-11-03 21:38:35,047 : INFO : topic #3 (0.143): 0.060*"대충" + 0.059*"교통사고" + 0.045*"분위기" + 0.042*"그다지" + 0.037*"피부" + 0.036*"얘기" + 0.035*"아주" + 0.033*"건물" + 0.030*"차도" + 0.030*"여러"
# 2021-11-03 21:38:35,048 : INFO : topic diff=0.052766, rho=0.229416
# 2021-11-03 21:38:35,052 : INFO : Epoch 17: Coherence estimate: -9.928395837830985
# 2021-11-03 21:38:35,141 : INFO : Epoch 17: Perplexity estimate: 41.38159648774292
# 2021-11-03 21:38:35,229 : INFO : -5.371 per-word bound, 41.4 perplexity estimate based on a held-out corpus of 481 documents with 2458 words
# 2021-11-03 21:38:35,229 : INFO : PROGRESS: pass 18, at document #481/481
# 2021-11-03 21:38:35,292 : INFO : topic #1 (0.143): 0.057*"기억" + 0.044*"주말" + 0.043*"태도" + 0.043*"주사" + 0.038*"침술" + 0.036*"약간" + 0.035*"호전" + 0.032*"요한" + 0.031*"잘못" + 0.029*"침대"
# 2021-11-03 21:38:35,293 : INFO : topic #0 (0.143): 0.068*"자주" + 0.049*"대답" + 0.048*"원인" + 0.039*"질문" + 0.038*"평일" + 0.036*"응대" + 0.032*"대충" + 0.029*"피부" + 0.028*"처치" + 0.027*"부위"
# 2021-11-03 21:38:35,293 : INFO : topic #6 (0.143): 0.046*"시술" + 0.041*"진짜" + 0.033*"접수" + 0.032*"주차" + 0.029*"모두" + 0.029*"나름" + 0.029*"발목" + 0.027*"말씀" + 0.024*"안내" + 0.023*"결제"
# 2021-11-03 21:38:35,294 : INFO : topic #3 (0.143): 0.060*"대충" + 0.059*"교통사고" + 0.045*"분위기" + 0.042*"그다지" + 0.037*"얘기" + 0.036*"피부" + 0.036*"아주" + 0.033*"건물" + 0.030*"차도" + 0.030*"여러"
# 2021-11-03 21:38:35,295 : INFO : topic #2 (0.143): 0.054*"입원" + 0.054*"진단" + 0.045*"부항" + 0.040*"부황" + 0.040*"양방" + 0.037*"다리" + 0.037*"디스크" + 0.035*"마음" + 0.034*"기본" + 0.027*"동안"
# 2021-11-03 21:38:35,295 : INFO : topic diff=0.048006, rho=0.223607
# 2021-11-03 21:38:35,299 : INFO : Epoch 18: Coherence estimate: -9.929571347675388
# 2021-11-03 21:38:35,386 : INFO : Epoch 18: Perplexity estimate: 41.33443407821097
# 2021-11-03 21:38:35,465 : INFO : -5.368 per-word bound, 41.3 perplexity estimate based on a held-out corpus of 481 documents with 2458 words
# 2021-11-03 21:38:35,466 : INFO : PROGRESS: pass 19, at document #481/481
# 2021-11-03 21:38:35,528 : INFO : topic #3 (0.143): 0.060*"대충" + 0.059*"교통사고" + 0.045*"분위기" + 0.042*"그다지" + 0.037*"아주" + 0.037*"얘기" + 0.036*"피부" + 0.033*"건물" + 0.031*"여러" + 0.031*"차도"
# 2021-11-03 21:38:35,528 : INFO : topic #4 (0.143): 0.052*"체질" + 0.048*"이상" + 0.046*"복용" + 0.033*"진행" + 0.032*"제대로" + 0.029*"모두" + 0.028*"주변" + 0.028*"전혀" + 0.026*"가면" + 0.026*"전문"
# 2021-11-03 21:38:35,529 : INFO : topic #5 (0.143): 0.047*"얘기" + 0.043*"기계" + 0.038*"해주시" + 0.038*"결제" + 0.035*"추가" + 0.034*"진찰" + 0.033*"찜질" + 0.029*"보험" + 0.028*"정형외과" + 0.027*"여자"
# 2021-11-03 21:38:35,529 : INFO : topic #0 (0.143): 0.069*"자주" + 0.049*"대답" + 0.047*"원인" + 0.039*"질문" + 0.038*"평일" + 0.036*"응대" + 0.032*"대충" + 0.029*"피부" + 0.029*"처치" + 0.028*"부위"
# 2021-11-03 21:38:35,530 : INFO : topic #2 (0.143): 0.054*"입원" + 0.054*"진단" + 0.045*"부항" + 0.041*"부황" + 0.041*"양방" + 0.037*"다리" + 0.037*"디스크" + 0.035*"마음" + 0.034*"기본" + 0.027*"동안"
# 2021-11-03 21:38:35,530 : INFO : topic diff=0.044429, rho=0.218218
# 2021-11-03 21:38:35,534 : INFO : Epoch 19: Coherence estimate: -9.929443578040376
# 2021-11-03 21:38:35,617 : INFO : Epoch 19: Perplexity estimate: 41.21710118649148
# 2021-11-03 21:38:35,700 : INFO : -5.366 per-word bound, 41.2 perplexity estimate based on a held-out corpus of 481 documents with 2458 words
# 2021-11-03 21:38:35,700 : INFO : PROGRESS: pass 20, at document #481/481
# 2021-11-03 21:38:35,759 : INFO : topic #3 (0.143): 0.060*"대충" + 0.059*"교통사고" + 0.046*"분위기" + 0.043*"그다지" + 0.037*"아주" + 0.037*"얘기" + 0.036*"피부" + 0.033*"건물" + 0.032*"여러" + 0.031*"차도"
# 2021-11-03 21:38:35,760 : INFO : topic #5 (0.143): 0.047*"얘기" + 0.043*"기계" + 0.038*"해주시" + 0.038*"결제" + 0.036*"추가" + 0.034*"진찰" + 0.033*"찜질" + 0.029*"보험" + 0.029*"정형외과" + 0.027*"여자"
# 2021-11-03 21:38:35,761 : INFO : topic #4 (0.143): 0.053*"체질" + 0.049*"이상" + 0.046*"복용" + 0.033*"진행" + 0.032*"제대로" + 0.030*"모두" + 0.028*"주변" + 0.027*"전혀" + 0.026*"가면" + 0.025*"전문"
# 2021-11-03 21:38:35,761 : INFO : topic #1 (0.143): 0.056*"기억" + 0.045*"주말" + 0.043*"주사" + 0.043*"태도" + 0.039*"침술" + 0.037*"약간" + 0.035*"호전" + 0.032*"요한" + 0.031*"잘못" + 0.029*"침대"
# 2021-11-03 21:38:35,761 : INFO : topic #0 (0.143): 0.069*"자주" + 0.049*"대답" + 0.047*"원인" + 0.039*"질문" + 0.038*"평일" + 0.036*"응대" + 0.032*"대충" + 0.030*"처치" + 0.029*"피부" + 0.028*"부위"
# 2021-11-03 21:38:35,762 : INFO : topic diff=0.041416, rho=0.213201
# 2021-11-03 21:38:35,766 : INFO : Epoch 20: Coherence estimate: -9.925093021727685
# 2021-11-03 21:38:35,856 : INFO : Epoch 20: Perplexity estimate: 41.151793459011216
# 2021-11-03 21:38:35,944 : INFO : -5.363 per-word bound, 41.2 perplexity estimate based on a held-out corpus of 481 documents with 2458 words
# 2021-11-03 21:38:35,944 : INFO : PROGRESS: pass 21, at document #481/481
# 2021-11-03 21:38:36,003 : INFO : topic #6 (0.143): 0.048*"시술" + 0.042*"진짜" + 0.033*"접수" + 0.033*"주차" + 0.029*"나름" + 0.029*"발목" + 0.029*"모두" + 0.027*"말씀" + 0.024*"안내" + 0.023*"결제"
# 2021-11-03 21:38:36,003 : INFO : topic #2 (0.143): 0.055*"입원" + 0.055*"진단" + 0.046*"부항" + 0.041*"양방" + 0.041*"부황" + 0.038*"다리" + 0.037*"디스크" + 0.037*"마음" + 0.034*"기본" + 0.027*"동안"
# 2021-11-03 21:38:36,004 : INFO : topic #3 (0.143): 0.060*"대충" + 0.059*"교통사고" + 0.046*"분위기" + 0.043*"그다지" + 0.038*"아주" + 0.037*"얘기" + 0.036*"피부" + 0.033*"건물" + 0.032*"여러" + 0.032*"차도"
# 2021-11-03 21:38:36,005 : INFO : topic #5 (0.143): 0.048*"얘기" + 0.043*"기계" + 0.038*"해주시" + 0.038*"결제" + 0.036*"추가" + 0.034*"진찰" + 0.033*"찜질" + 0.029*"보험" + 0.029*"정형외과" + 0.027*"여자"
# 2021-11-03 21:38:36,006 : INFO : topic #1 (0.143): 0.056*"기억" + 0.045*"주말" + 0.043*"주사" + 0.043*"태도" + 0.040*"침술" + 0.037*"약간" + 0.035*"호전" + 0.032*"요한" + 0.031*"잘못" + 0.029*"침대"
# 2021-11-03 21:38:36,007 : INFO : topic diff=0.038419, rho=0.208514
# 2021-11-03 21:38:36,011 : INFO : Epoch 21: Coherence estimate: -9.925890845309528
# 2021-11-03 21:38:36,094 : INFO : Epoch 21: Perplexity estimate: 41.07296039394419
# 2021-11-03 21:38:36,176 : INFO : -5.361 per-word bound, 41.1 perplexity estimate based on a held-out corpus of 481 documents with 2458 words
# 2021-11-03 21:38:36,176 : INFO : PROGRESS: pass 22, at document #481/481
# 2021-11-03 21:38:36,238 : INFO : topic #3 (0.143): 0.060*"대충" + 0.059*"교통사고" + 0.046*"분위기" + 0.043*"그다지" + 0.038*"아주" + 0.037*"얘기" + 0.036*"피부" + 0.033*"여러" + 0.033*"건물" + 0.032*"차도"
# 2021-11-03 21:38:36,239 : INFO : topic #0 (0.143): 0.070*"자주" + 0.049*"대답" + 0.047*"원인" + 0.039*"질문" + 0.039*"평일" + 0.036*"응대" + 0.033*"대충" + 0.031*"처치" + 0.029*"부위" + 0.029*"피부"
# 2021-11-03 21:38:36,239 : INFO : topic #6 (0.143): 0.048*"시술" + 0.042*"진짜" + 0.034*"접수" + 0.033*"주차" + 0.029*"나름" + 0.029*"발목" + 0.029*"모두" + 0.028*"말씀" + 0.024*"안내" + 0.023*"결제"
# 2021-11-03 21:38:36,240 : INFO : topic #5 (0.143): 0.048*"얘기" + 0.043*"기계" + 0.039*"해주시" + 0.038*"결제" + 0.036*"추가" + 0.034*"진찰" + 0.033*"찜질" + 0.029*"보험" + 0.029*"정형외과" + 0.027*"여자"
# 2021-11-03 21:38:36,241 : INFO : topic #2 (0.143): 0.055*"입원" + 0.055*"진단" + 0.046*"부항" + 0.041*"양방" + 0.041*"부황" + 0.038*"다리" + 0.037*"디스크" + 0.037*"마음" + 0.034*"기본" + 0.027*"동안"
# 2021-11-03 21:38:36,242 : INFO : topic diff=0.035788, rho=0.204124
# 2021-11-03 21:38:36,246 : INFO : Epoch 22: Coherence estimate: -9.925985616621116
# 2021-11-03 21:38:36,328 : INFO : Epoch 22: Perplexity estimate: 41.03309106903477
# 2021-11-03 21:38:36,415 : INFO : -5.359 per-word bound, 41.0 perplexity estimate based on a held-out corpus of 481 documents with 2458 words
# 2021-11-03 21:38:36,415 : INFO : PROGRESS: pass 23, at document #481/481
# 2021-11-03 21:38:36,476 : INFO : topic #1 (0.143): 0.056*"기억" + 0.046*"주말" + 0.044*"주사" + 0.043*"태도" + 0.041*"침술" + 0.039*"약간" + 0.034*"호전" + 0.032*"요한" + 0.031*"잘못" + 0.029*"침대"
# 2021-11-03 21:38:36,477 : INFO : topic #2 (0.143): 0.055*"입원" + 0.055*"진단" + 0.046*"부항" + 0.041*"부황" + 0.041*"양방" + 0.038*"마음" + 0.038*"다리" + 0.038*"디스크" + 0.034*"기본" + 0.028*"먼저"
# 2021-11-03 21:38:36,477 : INFO : topic #0 (0.143): 0.070*"자주" + 0.049*"대답" + 0.047*"원인" + 0.039*"질문" + 0.039*"평일" + 0.036*"응대" + 0.033*"대충" + 0.032*"처치" + 0.030*"부위" + 0.029*"피부"
# 2021-11-03 21:38:36,478 : INFO : topic #3 (0.143): 0.060*"대충" + 0.059*"교통사고" + 0.046*"분위기" + 0.043*"그다지" + 0.038*"아주" + 0.036*"얘기" + 0.036*"피부" + 0.033*"여러" + 0.033*"건물" + 0.033*"차도"
# 2021-11-03 21:38:36,478 : INFO : topic #4 (0.143): 0.054*"체질" + 0.049*"이상" + 0.046*"복용" + 0.032*"진행" + 0.032*"제대로" + 0.030*"모두" + 0.028*"주변" + 0.027*"전혀" + 0.026*"가면" + 0.025*"전문"
# 2021-11-03 21:38:36,478 : INFO : topic diff=0.033793, rho=0.200000
# 2021-11-03 21:38:36,482 : INFO : Epoch 23: Coherence estimate: -10.063045824554665
# 2021-11-03 21:38:36,572 : INFO : Epoch 23: Perplexity estimate: 40.96851676335718
# 2021-11-03 21:38:36,653 : INFO : -5.357 per-word bound, 41.0 perplexity estimate based on a held-out corpus of 481 documents with 2458 words
# 2021-11-03 21:38:36,654 : INFO : PROGRESS: pass 24, at document #481/481
# 2021-11-03 21:38:36,718 : INFO : topic #1 (0.143): 0.056*"기억" + 0.046*"주말" + 0.044*"주사" + 0.043*"태도" + 0.041*"침술" + 0.039*"약간" + 0.034*"호전" + 0.032*"요한" + 0.031*"잘못" + 0.029*"침대"
# 2021-11-03 21:38:36,718 : INFO : topic #6 (0.143): 0.049*"시술" + 0.043*"진짜" + 0.034*"접수" + 0.034*"주차" + 0.029*"나름" + 0.029*"발목" + 0.028*"모두" + 0.028*"말씀" + 0.024*"안내" + 0.024*"결제"
# 2021-11-03 21:38:36,719 : INFO : topic #4 (0.143): 0.055*"체질" + 0.049*"이상" + 0.046*"복용" + 0.032*"진행" + 0.032*"제대로" + 0.030*"모두" + 0.028*"주변" + 0.027*"전혀" + 0.026*"가면" + 0.025*"전문"
# 2021-11-03 21:38:36,719 : INFO : topic #0 (0.143): 0.071*"자주" + 0.049*"대답" + 0.047*"원인" + 0.039*"질문" + 0.039*"평일" + 0.036*"응대" + 0.033*"대충" + 0.032*"처치" + 0.030*"부위" + 0.029*"피부"
# 2021-11-03 21:38:36,719 : INFO : topic #5 (0.143): 0.049*"얘기" + 0.043*"기계" + 0.039*"해주시" + 0.038*"결제" + 0.037*"추가" + 0.034*"진찰" + 0.033*"찜질" + 0.030*"보험" + 0.029*"정형외과" + 0.027*"여자"
# 2021-11-03 21:38:36,720 : INFO : topic diff=0.031291, rho=0.196116
# 2021-11-03 21:38:36,723 : INFO : Epoch 24: Coherence estimate: -10.061375687742295
# 2021-11-03 21:38:36,812 : INFO : Epoch 24: Perplexity estimate: 40.939906895481094
# 2021-11-03 21:38:36,895 : INFO : -5.355 per-word bound, 40.9 perplexity estimate based on a held-out corpus of 481 documents with 2458 words
# 2021-11-03 21:38:36,895 : INFO : PROGRESS: pass 25, at document #481/481
# 2021-11-03 21:38:36,951 : INFO : topic #4 (0.143): 0.055*"체질" + 0.050*"이상" + 0.046*"복용" + 0.032*"진행" + 0.032*"제대로" + 0.031*"모두" + 0.028*"주변" + 0.027*"전혀" + 0.026*"가면" + 0.025*"전문"
# 2021-11-03 21:38:36,952 : INFO : topic #0 (0.143): 0.071*"자주" + 0.050*"대답" + 0.048*"원인" + 0.039*"질문" + 0.039*"평일" + 0.036*"응대" + 0.033*"대충" + 0.033*"처치" + 0.031*"부위" + 0.029*"피부"
# 2021-11-03 21:38:36,952 : INFO : topic #5 (0.143): 0.049*"얘기" + 0.043*"기계" + 0.039*"해주시" + 0.038*"결제" + 0.037*"추가" + 0.034*"진찰" + 0.033*"찜질" + 0.030*"보험" + 0.029*"정형외과" + 0.027*"여자"
# 2021-11-03 21:38:36,952 : INFO : topic #3 (0.143): 0.060*"대충" + 0.059*"교통사고" + 0.047*"분위기" + 0.043*"그다지" + 0.039*"아주" + 0.037*"얘기" + 0.036*"피부" + 0.034*"여러" + 0.033*"차도" + 0.033*"건물"
# 2021-11-03 21:38:36,953 : INFO : topic #1 (0.143): 0.056*"기억" + 0.046*"주말" + 0.044*"주사" + 0.044*"태도" + 0.042*"침술" + 0.039*"약간" + 0.034*"호전" + 0.032*"요한" + 0.030*"잘못" + 0.029*"침대"
# 2021-11-03 21:38:36,953 : INFO : topic diff=0.029695, rho=0.192450
# 2021-11-03 21:38:36,958 : INFO : Epoch 25: Coherence estimate: -10.061375687742295
# 2021-11-03 21:38:37,042 : INFO : Epoch 25: Perplexity estimate: 40.86482735651817
# 2021-11-03 21:38:37,127 : INFO : -5.354 per-word bound, 40.9 perplexity estimate based on a held-out corpus of 481 documents with 2458 words
# 2021-11-03 21:38:37,128 : INFO : PROGRESS: pass 26, at document #481/481
# 2021-11-03 21:38:37,189 : INFO : topic #4 (0.143): 0.055*"체질" + 0.050*"이상" + 0.046*"복용" + 0.032*"진행" + 0.032*"제대로" + 0.030*"모두" + 0.028*"주변" + 0.027*"전혀" + 0.026*"가면" + 0.025*"전문"
# 2021-11-03 21:38:37,189 : INFO : topic #2 (0.143): 0.055*"입원" + 0.055*"진단" + 0.046*"부항" + 0.042*"마음" + 0.042*"부황" + 0.041*"양방" + 0.038*"다리" + 0.038*"디스크" + 0.034*"기본" + 0.028*"먼저"
# 2021-11-03 21:38:37,190 : INFO : topic #0 (0.143): 0.072*"자주" + 0.050*"대답" + 0.048*"원인" + 0.039*"평일" + 0.039*"질문" + 0.036*"응대" + 0.033*"처치" + 0.033*"대충" + 0.031*"부위" + 0.030*"피부"
# 2021-11-03 21:38:37,191 : INFO : topic #3 (0.143): 0.060*"대충" + 0.059*"교통사고" + 0.048*"분위기" + 0.043*"그다지" + 0.039*"아주" + 0.037*"얘기" + 0.037*"피부" + 0.034*"여러" + 0.033*"차도" + 0.033*"건물"
# 2021-11-03 21:38:37,192 : INFO : topic #1 (0.143): 0.056*"기억" + 0.046*"주말" + 0.045*"주사" + 0.044*"태도" + 0.042*"침술" + 0.040*"약간" + 0.034*"호전" + 0.032*"요한" + 0.030*"잘못" + 0.029*"침대"
# 2021-11-03 21:38:37,193 : INFO : topic diff=0.027678, rho=0.188982
# 2021-11-03 21:38:37,197 : INFO : Epoch 26: Coherence estimate: -10.06056968038842
# 2021-11-03 21:38:37,274 : INFO : Epoch 26: Perplexity estimate: 40.83332885988231
# 2021-11-03 21:38:37,361 : INFO : -5.352 per-word bound, 40.8 perplexity estimate based on a held-out corpus of 481 documents with 2458 words
# 2021-11-03 21:38:37,362 : INFO : PROGRESS: pass 27, at document #481/481
# 2021-11-03 21:38:37,425 : INFO : topic #4 (0.143): 0.056*"체질" + 0.050*"이상" + 0.046*"복용" + 0.032*"진행" + 0.032*"제대로" + 0.030*"모두" + 0.028*"주변" + 0.027*"전혀" + 0.026*"가면" + 0.025*"전문"
# 2021-11-03 21:38:37,427 : INFO : topic #2 (0.143): 0.055*"입원" + 0.055*"진단" + 0.047*"부항" + 0.043*"마음" + 0.042*"부황" + 0.041*"양방" + 0.038*"다리" + 0.038*"디스크" + 0.034*"기본" + 0.028*"먼저"
# 2021-11-03 21:38:37,427 : INFO : topic #3 (0.143): 0.060*"대충" + 0.059*"교통사고" + 0.048*"분위기" + 0.043*"그다지" + 0.039*"아주" + 0.037*"피부" + 0.037*"얘기" + 0.035*"여러" + 0.034*"차도" + 0.033*"건물"
# 2021-11-03 21:38:37,427 : INFO : topic #0 (0.143): 0.072*"자주" + 0.050*"대답" + 0.048*"원인" + 0.039*"평일" + 0.039*"질문" + 0.036*"응대" + 0.034*"처치" + 0.033*"대충" + 0.031*"부위" + 0.030*"피부"
# 2021-11-03 21:38:37,427 : INFO : topic #6 (0.143): 0.049*"시술" + 0.043*"진짜" + 0.035*"접수" + 0.034*"주차" + 0.029*"나름" + 0.029*"발목" + 0.028*"모두" + 0.028*"말씀" + 0.024*"안내" + 0.024*"결제"
# 2021-11-03 21:38:37,428 : INFO : topic diff=0.025642, rho=0.185695
# 2021-11-03 21:38:37,432 : INFO : Epoch 27: Coherence estimate: -10.05979151385498
# 2021-11-03 21:38:37,517 : INFO : Epoch 27: Perplexity estimate: 40.80011775335546
# 2021-11-03 21:38:37,603 : INFO : -5.350 per-word bound, 40.8 perplexity estimate based on a held-out corpus of 481 documents with 2458 words
# 2021-11-03 21:38:37,603 : INFO : PROGRESS: pass 28, at document #481/481
# 2021-11-03 21:38:37,661 : INFO : topic #3 (0.143): 0.060*"대충" + 0.059*"교통사고" + 0.048*"분위기" + 0.043*"그다지" + 0.039*"아주" + 0.037*"피부" + 0.037*"얘기" + 0.035*"여러" + 0.034*"차도" + 0.033*"건물"
# 2021-11-03 21:38:37,661 : INFO : topic #1 (0.143): 0.055*"기억" + 0.046*"주말" + 0.045*"주사" + 0.044*"태도" + 0.043*"침술" + 0.040*"약간" + 0.034*"호전" + 0.032*"요한" + 0.030*"잘못" + 0.029*"침대"
# 2021-11-03 21:38:37,662 : INFO : topic #0 (0.143): 0.072*"자주" + 0.050*"대답" + 0.048*"원인" + 0.040*"평일" + 0.039*"질문" + 0.036*"응대" + 0.034*"대충" + 0.034*"처치" + 0.031*"부위" + 0.030*"피부"
# 2021-11-03 21:38:37,662 : INFO : topic #5 (0.143): 0.049*"얘기" + 0.043*"기계" + 0.039*"해주시" + 0.038*"결제" + 0.037*"추가" + 0.034*"진찰" + 0.034*"찜질" + 0.029*"보험" + 0.029*"정형외과" + 0.027*"여자"
# 2021-11-03 21:38:37,663 : INFO : topic #2 (0.143): 0.055*"입원" + 0.055*"진단" + 0.047*"부항" + 0.044*"마음" + 0.043*"부황" + 0.041*"양방" + 0.038*"다리" + 0.038*"디스크" + 0.034*"기본" + 0.028*"먼저"
# 2021-11-03 21:38:37,663 : INFO : topic diff=0.023990, rho=0.182574
# 2021-11-03 21:38:37,666 : INFO : Epoch 28: Coherence estimate: -10.06156807191192
# 2021-11-03 21:38:37,746 : INFO : Epoch 28: Perplexity estimate: 40.73266634421527
# 2021-11-03 21:38:37,829 : INFO : -5.349 per-word bound, 40.7 perplexity estimate based on a held-out corpus of 481 documents with 2458 words
# 2021-11-03 21:38:37,830 : INFO : PROGRESS: pass 29, at document #481/481
# 2021-11-03 21:38:37,888 : INFO : topic #4 (0.143): 0.056*"체질" + 0.050*"이상" + 0.046*"복용" + 0.032*"진행" + 0.032*"제대로" + 0.031*"모두" + 0.028*"주변" + 0.027*"전혀" + 0.026*"가면" + 0.025*"전문"
# 2021-11-03 21:38:37,888 : INFO : topic #3 (0.143): 0.059*"교통사고" + 0.059*"대충" + 0.048*"분위기" + 0.043*"그다지" + 0.039*"아주" + 0.038*"피부" + 0.037*"얘기" + 0.035*"여러" + 0.034*"차도" + 0.033*"건물"
# 2021-11-03 21:38:37,889 : INFO : topic #5 (0.143): 0.049*"얘기" + 0.043*"기계" + 0.039*"해주시" + 0.038*"결제" + 0.037*"추가" + 0.034*"진찰" + 0.034*"찜질" + 0.029*"보험" + 0.029*"정형외과" + 0.027*"여자"
# 2021-11-03 21:38:37,889 : INFO : topic #6 (0.143): 0.050*"시술" + 0.043*"진짜" + 0.035*"접수" + 0.034*"주차" + 0.029*"나름" + 0.029*"발목" + 0.028*"모두" + 0.028*"말씀" + 0.025*"안내" + 0.024*"결제"
# 2021-11-03 21:38:37,889 : INFO : topic #2 (0.143): 0.055*"입원" + 0.055*"진단" + 0.047*"부항" + 0.045*"마음" + 0.043*"부황" + 0.041*"양방" + 0.038*"다리" + 0.038*"디스크" + 0.034*"기본" + 0.029*"먼저"
# 2021-11-03 21:38:37,890 : INFO : topic diff=0.022308, rho=0.179605
# 2021-11-03 21:38:37,894 : INFO : Epoch 29: Coherence estimate: -10.060897249392342
# 2021-11-03 21:38:37,978 : INFO : Epoch 29: Perplexity estimate: 40.69638446049032
# 2021-11-03 21:38:37,978 : INFO : LdaModel lifecycle event {'msg': 'trained LdaModel(num_terms=142, num_topics=7, decay=0.5, chunksize=2000) in 7.53s', 'datetime': '2021-11-03T21:38:37.978419', 'gensim': '4.1.2', 'python': '3.8.11 (default, Aug  6 2021, 09:57:55) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19042-SP0', 'event': 'created'}
# 2021-11-03 21:38:37,979 : INFO : topic #0 (0.143): 0.073*"자주" + 0.050*"대답" + 0.048*"원인" + 0.040*"평일" + 0.039*"질문"
# 2021-11-03 21:38:37,979 : INFO : topic #1 (0.143): 0.055*"기억" + 0.046*"주말" + 0.046*"주사" + 0.044*"태도" + 0.043*"침술"
# 2021-11-03 21:38:37,980 : INFO : topic #2 (0.143): 0.055*"입원" + 0.055*"진단" + 0.047*"부항" + 0.045*"마음" + 0.043*"부황"
# 2021-11-03 21:38:37,980 : INFO : topic #3 (0.143): 0.059*"교통사고" + 0.059*"대충" + 0.048*"분위기" + 0.043*"그다지" + 0.039*"아주"
# 2021-11-03 21:38:37,981 : INFO : topic #4 (0.143): 0.056*"체질" + 0.050*"이상" + 0.046*"복용" + 0.032*"진행" + 0.032*"제대로"
# 2021-11-03 21:38:37,981 : INFO : topic #5 (0.143): 0.049*"얘기" + 0.043*"기계" + 0.039*"해주시" + 0.038*"결제" + 0.037*"추가"
# 2021-11-03 21:38:37,981 : INFO : topic #6 (0.143): 0.050*"시술" + 0.043*"진짜" + 0.035*"접수" + 0.034*"주차" + 0.029*"나름"
# 2021-11-03 21:38:37,983 : INFO : using ParallelWordOccurrenceAccumulator(processes=15, batch_size=64) to estimate probabilities from sliding windows
# (0, '0.073*"자주" + 0.050*"대답" + 0.048*"원인" + 0.040*"평일" + 0.039*"질문"')
# (1, '0.055*"기억" + 0.046*"주말" + 0.046*"주사" + 0.044*"태도" + 0.043*"침술"')
# (2, '0.055*"입원" + 0.055*"진단" + 0.047*"부항" + 0.045*"마음" + 0.043*"부황"')
# (3, '0.059*"교통사고" + 0.059*"대충" + 0.048*"분위기" + 0.043*"그다지" + 0.039*"아주"')
# (4, '0.056*"체질" + 0.050*"이상" + 0.046*"복용" + 0.032*"진행" + 0.032*"제대로"')
# (5, '0.049*"얘기" + 0.043*"기계" + 0.039*"해주시" + 0.038*"결제" + 0.037*"추가"')
# (6, '0.050*"시술" + 0.043*"진짜" + 0.035*"접수" + 0.034*"주차" + 0.029*"나름"')
# 2021-11-03 21:38:41,017 : INFO : 15 accumulators retrieved from output queue
# 2021-11-03 21:38:41,049 : INFO : accumulated word occurrence stats for 769 virtual documents
# 2021-11-03 21:38:41,287 : INFO : Dictionary lifecycle event {'fname_or_handle': 'lda_dictionary.gensim', 'separately': 'None', 'sep_limit': 10485760, 'ignore': frozenset(), 'datetime': '2021-11-03T21:38:41.287486', 'gensim': '4.1.2', 'python': '3.8.11 (default, Aug  6 2021, 09:57:55) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19042-SP0', 'event': 'saving'}
# 2021-11-03 21:38:41,288 : INFO : saved lda_dictionary.gensim
# 2021-11-03 21:38:41,288 : INFO : LdaState lifecycle event {'fname_or_handle': 'lda_model.gensim.state', 'separately': 'None', 'sep_limit': 10485760, 'ignore': frozenset(), 'datetime': '2021-11-03T21:38:41.288488', 'gensim': '4.1.2', 'python': '3.8.11 (default, Aug  6 2021, 09:57:55) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19042-SP0', 'event': 'saving'}
# 2021-11-03 21:38:41,290 : INFO : saved lda_model.gensim.state
# 2021-11-03 21:38:41,290 : INFO : LdaModel lifecycle event {'fname_or_handle': 'lda_model.gensim', 'separately': "['expElogbeta', 'sstats']", 'sep_limit': 10485760, 'ignore': ['dispatcher', 'state', 'id2word'], 'datetime': '2021-11-03T21:38:41.290488', 'gensim': '4.1.2', 'python': '3.8.11 (default, Aug  6 2021, 09:57:55) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19042-SP0', 'event': 'saving'}
# 2021-11-03 21:38:41,291 : INFO : storing np array 'expElogbeta' to lda_model.gensim.expElogbeta.npy
# 2021-11-03 21:38:41,292 : INFO : not storing attribute dispatcher
# 2021-11-03 21:38:41,292 : INFO : not storing attribute state
# 2021-11-03 21:38:41,293 : INFO : not storing attribute id2word
# 2021-11-03 21:38:41,295 : INFO : saved lda_model.gensim
# Coherence Score (c_v):  0.34585129952739635
#
# Coherence Score (u_mass):  -10.351635017090654
# C:\Users\yukir\anaconda3\envs\NLP\lib\site-packages\pyLDAvis\_prepare.py:228: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   default_term_info  = pd.DataFrame({'saliency': saliency, 'Term': vocab, \

# %%
pyLDAvis.display(lda_visualization)
# Out:
# <link rel="stylesheet" type="text/css" href="https://cdn.rawgit.com/bmabey/pyLDAvis/files/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el1353224159188368643658483592"></div>
# <script type="text/javascript">
#
# var ldavis_el1353224159188368643658483592_data = {"mdsDat": {"x": [-0.031555843229487464, -0.05482864040240986, 0.0742108080335963, 0.1446530328582244, 0.19183698821445405, -0.1283277586162128, -0.19598858685816462], "y": [-0.023961585319256688, -0.039486641858983984, 0.18384246920697267, 0.039074633441117904, -0.1620776723095682, 0.13874050643088764, -0.13613170959116933], "topics": [1, 2, 3, 4, 5, 6, 7], "cluster": [1, 1, 1, 1, 1, 1, 1], "Freq": [16.885862341520752, 16.85403580971067, 16.556165414591387, 14.687947558096868, 13.375360851016941, 10.919957923217751, 10.720670101845633]}, "tinfo": {"Term": ["\uc790\uc8fc", "\ub300\ucda9", "\uccb4\uc9c8", "\uc598\uae30", "\uc785\uc6d0", "\uc9c4\ub2e8", "\uae30\uc5b5", "\uad50\ud1b5\uc0ac\uace0", "\uc2dc\uc220", "\ubd80\ud56d", "\ubcf5\uc6a9", "\ub300\ub2f5", "\uc8fc\ub9d0", "\uc774\uc0c1", "\ud0dc\ub3c4", "\uc9c4\uc9dc", "\uae30\uacc4", "\uc6d0\uc778", "\uacb0\uc81c", "\ud53c\ubd80", "\ud574\uc8fc\uc2dc", "\uc8fc\uc0ac", "\ubd84\uc704\uae30", "\uc591\ubc29", "\ubd80\ud669", "\uadf8\ub2e4\uc9c0", "\uc544\uc8fc", "\uc57d\uac04", "\uc9c8\ubb38", "\ub2e4\ub9ac", "\uc8fc\ucc28", "\uad00\ub9ac", "\uc9c4\uc9dc", "\ub098\ub984", "\uc811\uc218", "\uc548\ub0b4", "\uacbd\ud5d8", "\uacfc\uc789", "\uc2dc\uc220", "\ubc1c\ubaa9", "\uc694\uccad", "\uc804\ud654", "\uc2e0\uacbd", "\ub9d0\uc500", "\uc778\ud14c\ub9ac\uc5b4", "\uae08\uc561", "\ub098\uc774", "\ubaa8\ub450", "\uac00\uae30", "\uc544\uc8fc", "\uacb0\uc81c", "\uad8c\uc720", "\ub370\uc2a4\ud06c", "\uac80\uc0c9", "\ubcf8\uc778", "\uc5ec\uc790", "\ud06c\uac8c", "\uac00\uac8c", "\uac1c\uc6d4", "\ud53c\ubd80", "\ub2e4\ub9cc", "\uc8fc\uc0ac", "\ucd94\uac00", "\ud574\uc8fc\uc2dc", "\uc9c4\ucc30", "\ubcf4\ud5d8", "\uc790\uae30", "\uac74\uac15", "\ucd94\uac00", "\uae30\uacc4", "\uc598\uae30", "\uacb0\uc81c", "\uc815\ud615\uc678\uacfc", "\ucc1c\uc9c8", "\uc5ec\uc790", "\ubb34\uc2a8", "\uac00\uc9c0", "\ubc29\ubc95", "\uc9c1\uc811", "\uc704\ud574", "\ud558\ub8e8", "\uc798\ubabb", "\uc694\ubc95", "\ub9c8\uc0ac\uc9c0", "\uc6d0\ub798", "\uac80\uc0c9", "\ubb38\uc81c", "\ubcf4\ud1b5", "\uc774\ud6c4", "\ud55c\ubc88", "\ud6c4\uae30", "\uacb0\uacfc", "\uacfc\uc789", "\ub2e4\ub9cc", "\ubcf5\uc6a9", "\uac74\ubb3c", "\uccb4\uc9c8", "\uc8fc\ubcc0", "\ucd08\uc9c4", "\uc774\uc0c1", "\ubcf5\uc6a9", "\uc81c\ub300\ub85c", "\uac00\uba74", "\ud655\uc778", "\uc804\ubb38", "\ud574\ub3c4", "\uc9c4\ub9e5", "\ucc38\uace0", "\uc18c\ub9ac", "\ub0b4\uc6a9", "\uc774\uc720", "\uc804\uccb4", "\uc9c4\ud589", "\ud6c4\uae30", "\uacbd\uc6b0", "\uac11\uc790\uae30", "\ubcf8\uc778", "\ubaa8\ub4e0", "\ubaa8\ub450", "\uac70\uc758", "\ucf54\ub85c\ub098", "\uc804\ud600", "\uc804\ud654", "\uac1c\uc6d4", "\uc808\ub300", "\uc57d\ub3c4", "\uc9c8\ubb38", "\ub9ac\ubdf0", "\ud55c\ubc88", "\ubcf4\ud1b5", "\uae30\uc5b5", "\uc57d\uac04", "\uc8fc\ub9d0", "\ud0dc\ub3c4", "\uce68\uc220", "\ubcf4\uc2dc", "\ubcd1\ud589", "\ud638\uc804", "\uc694\ud55c", "\uc8fc\uc0ac", "\uc798\ubabb", "\uce68\ub300", "\ud06c\uac8c", "\uc804\uccb4", "\uacb0\uacfc", "\uc57d\ub3c4", "\ub2ec\ub77c", "\uc2e0\uacbd", "\uc774\uc6a9", "\uc774\ud6c4", "\uc804\ud600", "\uc5ec\ub7ec", "\uc808\ub300", "\uac1c\uc778", "\ub3d9\uc548", "\uc77c\uc8fc\uc77c", "\uac00\uc9c0", "\uc774\uc57c\uae30", "\uac70\ub9ac", "\uce5c\uc808", "\uc2dc\uc220", "\ub9d0\uc500", "\uc9c4\ud589", "\uc785\uc6d0", "\uc9c4\ub2e8", "\ub2e4\ub9ac", "\ub514\uc2a4\ud06c", "\uc591\ubc29", "\ubd80\ud669", "\uae30\ubcf8", "\ub9c8\uc74c", "\uc624\ud788\ub824", "\ubd80\ud56d", "\ub3d9\uc548", "\uba3c\uc800", "\uc2e4\ub825", "\uc18c\uac1c", "\ud3b8\uc785", "\uac00\uc7a5", "\uc778\ud14c\ub9ac\uc5b4", "\ub9c8\uc0ac\uc9c0", "\uc811\uadfc\uc131", "\uce5c\uc808", "\uc77c\uc8fc\uc77c", "\uac00\uae30", "\uac70\ub9ac", "\uc815\ud615\uc678\uacfc", "\ub9ac\ubdf0", "\uac00\uac8c", "\ucf54\ub85c\ub098", "\uc704\ud574", "\ubcf4\ud1b5", "\ub2ec\ub77c", "\uc774\uc57c\uae30", "\ubaa8\ub450", "\uce68\uc220", "\uc751\ub300", "\ub300\ub2f5", "\ud3c9\uc77c", "\uc790\uc8fc", "\ucc98\uce58", "\u ...
