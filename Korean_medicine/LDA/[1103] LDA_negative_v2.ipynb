# %%
# %cd C:\Users\yukir\Documents\GitHub\Scrapper\py

from nlp_processing import *
set_global_determinism(seed=1337)

# %cd C:\Users\yukir\Documents\Monicas_workspace\Korea_medicine\LDA
# Out:
# C:\Users\yukir\Documents\GitHub\Scrapper\py
# True
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 13104435152491153732
# , name: "/device:XLA_CPU:0"
# device_type: "XLA_CPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 2345441087260082930
# physical_device_desc: "device: XLA_CPU device"
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 9883535296
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 1798825609184344710
# physical_device_desc: "device: 0, name: NVIDIA GeForce RTX 2080 Ti, pci bus id: 0000:01:00.0, compute capability: 7.5"
# , name: "/device:XLA_GPU:0"
# device_type: "XLA_GPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 15486748868070978986
# physical_device_desc: "device: XLA_GPU device"
# ]
# tf 2.2.0
# set_global_determinism(seed=1337) 이거 꼭 해라
# set_global_determinism(seed=1337) 이거 꼭 해라
# set_global_determinism(seed=1337) 이거 꼭 해라
# C:\Users\yukir\Documents\Monicas_workspace\Korea_medicine\LDA

# %%
review_data = pd.read_csv('stemmed_clean.csv', index_col = 0)
review_data.head()

df = review_data.copy()
# df = df.drop_duplicates()
# df = df.dropna()
# # df = df.drop(index=0)

# df = df.reset_index()
# df = df.drop(columns= '1')
print(df.shape)
df.head()
# Out:
# (14891, 9)
#    hospital  stars                                            reviews adress  \
# 0  청주나비솔한의원   10.0  병원이 전반적으로 깔끔해서 쾌적했어요대기가 좀 있지만 심하진 않은편이었고 간호사분들...     충북
# 1  청주나비솔한의원    7.5  체인 한의원이라서 망설였는데 시설도 깔끔하고 진료도 친절하게 너무 잘 봐주셨어요 그...     충북
# 2  청주나비솔한의원   10.0  사고 후유증으로 놀라서 한의원 방문 하였고 침 놔주시고 청심환 처방 해주셨습니다 편...     충북
# 3  청주나비솔한의원    8.8  오래 서있으면 발바닥이 너무 아파서 방문했습니다 진료랑 치료받는 건 괜찮았는데 별로...     충북
# 4  청주나비솔한의원   10.0  다이어트 환 처방 받았습니다 효과도 꽤 있었고 처음부터 무리하지 않는 선에서 체질에...     충북
#
#                                       cleaned_review  \
# 0  병원이 전반적으로 깔끔해서 쾌적했어요 대기가 좀 있지만 심하진 않은 편이었고 간호사...
# 1  체인 한의원이라서 망설였는데 시설도 깔끔하고 진료도 친절하게 너무 잘 봐주셨어요 그...
# 2  사고 후유증으로 놀라서 한의원 방문하였고 침 놔주시고 청심환 처방해주셨습니다 편안하...
# 3  오래 서 있으면 발바닥이 너무 아파서 방문했습니다 진료랑 치료받는 건 괜찮았는데 별...
# 4  다이어트 환 처방받았습니다 효과도 꽤 있었고 처음부터 무리하지 않는 선에서 체질에 ...
#
#                                                 noun  \
# 0  ['병원', '전반', '대기', '좀', '간호사', '의사', '설명', '주말...
# 1  ['체인', '한의원', '시설', '진료', '양심', '진료', '것', '믿음...
# 2  ['사고', '후유증', '한의원', '방문', '침', '청심환', '처방', '...
# 3  ['발바닥', '방문', '진료', '건', '별로', '효과', '못', '계속'...
# 4  ['다이어트', '환', '처방', '효과', '꽤', '처음', '선', '체질'...
#
#                                              stemmed  \
# 0  ['병원', '전반', '깔끔하다', '쾌적하다', '대기', '있다', '심하다'...
# 1  ['체인', '한의원', '망설이다', '시설', '깔끔하다', '진료', '친절하...
# 2  ['사고', '후유증', '놀라다', '한의원', '방문', '하다', '놓다', ...
# 3  ['서다', '있다', '발바닥', '아프다', '방문', '하다', '진료', '...
# 4  ['다이어트', '처방', '받다', '효과', '있다', '처음', '무리하다',...
#
#                                        stemmed_clean  \
# 0  [병원 전반 깔끔하다 쾌적하다 대기 있다 심하다 않다 펴다 간호사 친절하다 의사 친...
# 1  [체인 한의원 망설이다 시설 깔끔하다 진료 친절하다 자다 보다 양심 진료 하다 같다...
# 2  [사고 후유증 놀라다 한의원 방문 하다 놓다 청심환 처방 해주다 편안하다 휴식 하다...
# 3  [서다 있다 발바닥 아프다 방문 하다 진료 치료받다 괜찮다 별로 효과 보다 꾸준하다...
# 4  [다이어트 처방 받다 효과 있다 처음 무리하다 않다 체질 맞추다 진단 해주다 체질 ...
#
#                                           noun_clean
# 0         [병원 전반 대기 좀 간호사 의사 설명 주말 공휴일 진료 집 좀 가기 항상]
# 1          [체인 한의원 시설 진료 양심 진료 것 믿음 무조건 한약 치료 모습 믿음]
# 2       [사고 후유증 한의원 방문 침 청심환 처방 휴식 의원 내부 다음 기회 또 방문]
# 3                [발바닥 방문 진료 건 별로 효과 못 계속 대체 뭐 문제 계속]
# 4  [다이어트 환 처방 효과 꽤 처음 선 체질 진단 체질 평소 식 습관 운동 상태 확인...

# %%
df = df[['stars', 'cleaned_review']]
df= df[df['stars']<=6.2]
# df['noun_clean']=df['noun_clean'].replace('[','')
# df['noun_clean']=df['noun_clean'].replace(']','')
df.head()
# Out:
#      stars                                     cleaned_review
# 108    4.0  목 디스크 때문에 며칠 동안 목이 너무너무 아팠어요 마침 집 앞에 있는 한의원이 있...
# 188    6.0  지인 소개로 갔는데 친절하고 청결해 좋았고 기다리지 않았으며 늦은 시간에도 진료할 ...
# 201    5.5  침 치료만 좋아요 1진료실에서 침 치료할 때는 아픈 부위에다가 직접 침 놓으며 안 ...
# 204    5.5  박 선생님께서 충분한 설명과 치료 과정을 안내해주시고 꾸준히 치료받는 과정에서 저한...
# 210    5.5  평소에 허리랑 목이 안 좋았는데 갑자기 또 아파서 한의원에 방문했어요 침 맞는 게 ...

# %%
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from nltk.tokenize import RegexpTokenizer
from gensim import corpora, models
from gensim.models import CoherenceModel
import gensim
import matplotlib.pyplot as plt

# %%
from gensim.models.ldamodel import LdaModel 
from gensim.models.callbacks import CoherenceMetric 
from gensim import corpora 
from gensim.models.callbacks import PerplexityMetric 
import logging 
import pickle 
import pyLDAvis

from gensim.models.coherencemodel import CoherenceModel 
import matplotlib.pyplot as plt

import pyLDAvis.gensim
pyLDAvis.enable_notebook()

from konlpy.tag import Mecab 
from konlpy.tag import Okt
okt = Okt()
from tqdm import tqdm 
import re 
import pickle 
import csv

# %%
test_list = df['cleaned_review'].tolist()

test = test_list[0]
# print(test)

test_morphs = okt. pos(test, stem=True, norm = True)
for i in test_morphs:

    if i[1]=='Noun' and len(i[0])>1:
        print(i)
        
# print('------------------------------')
# print(test_morphs)

# %%
def get_nouns(tokenizer, sentence): 
    """ 단어의 길이가 2이상인 일반명사(NNG),
     고유명사(NNP), 외국어(SL)만을 반환한다. 
     :param tokenizer: 
     :param sentence: :return: """ 
    tagged = tokenizer.pos(sentence, stem = True, norm = True)
    words = []
    for i in tagged:
        if i[1]=='Noun' and len(i[0])>1:
            words.append(i[0])
        elif i[1]=='Adjective':
            words.append(i[0])

     
    return words

# %%
test_list = df['cleaned_review'].tolist()
test = test_list[0]
print(test)
a = get_nouns(okt, test)
print(a)
# Out:
# 목 디스크 때문에 며칠 동안 목이 너무너무 아팠어요 마침 집 앞에 있는 한의원이 있어서 가게 됐네요 진료실과 화장실 대기실은 깨끗했어요 하지만 의사선생님의 성의 없는 진료에 대해 실망스러웠어 요목 몇 번 만지고 침 놓고 끝났는데 낫지도 않고 효과도 미미했습니다 앞으로 만한 의원으로 다닐 것 같아요 원장님의 성의 있는 진료를 부탁드리며 리뷰를 남깁니다
# ['디스크', '때문', '며칠', '동안', '아프다', '마침', '있다', '한의원', '있다', '가게', '진료', '실과', '화장실', '대기실', '깨끗하다', '의사', '선생님', '성의', '없다', '진료', '대해', '실망', '스럽다', '지고', '효과', '미미하다', '의원', '같다', '원장', '성의', '있다', '진료', '부탁드리다', '리뷰']

# %%
def clean_text(text): 
    """ 한글, 영문, 숫자만 남기고 제거한다. 
    :param text: 
    :return: 
    """ 
    text = text.replace(".", " ").strip() 
    text = text.replace("·", " ").strip() 
    pattern = '[^ ㄱ-ㅣ가-힣|0-9|a-zA-Z]+' 
    text = re.sub(pattern=pattern, repl='', string=text) 
    return text 
    
def get_nouns(tokenizer, sentence): 
    """ 단어의 길이가 2이상인 일반명사(NNG),
     고유명사(NNP), 외국어(SL)만을 반환한다. 
     :param tokenizer: 
     :param sentence: :return: """ 
    tagged = tokenizer.pos(sentence, stem = True, norm = True)
    words = []
    for i in tagged:
        if i[1]=='Noun' and len(i[0])>1:
            words.append(i[0])
        elif i[1]=='Adjective':
            words.append(i[0])

     
    return words 
     
     
def tokenize(df): 
    tokenizer = okt
    processed_data = [] 
    for sent in tqdm(df['cleaned_review']):
        sentence = clean_text(sent.replace('\n', '').strip()) 
        processed_data.append(get_nouns(tokenizer, sentence)) 
        
    return processed_data
    
    
def save_processed_data(processed_data): 
    """ 토큰 분리한 데이터를 csv로 저장 :param processed_data: :return: """ 
    
    with open('stemm_token_adj.csv', 'w', newline='', encoding='utf-8') as f: 
        writer = csv.writer(f) 
        for data in processed_data:
             writer.writerow(data)

# %%
if __name__ == '__main__':
     # df = pd.read_csv('negative.csv', index_col = 0)
     processed_data = tokenize(df) # description 부분을 토크나이징 한다. 
     
     # 토큰 분리한 데이터를 저장 
     save_processed_data(processed_data)
# Out:
# 100%|██████████| 481/481 [00:10<00:00, 45.14it/s]

# %%
def compute_coherence_values(dictionary, corpus, texts, limit, start=2, step=3): 
    """ Compute c_v coherence for various number of topics 
    
    Parameters: 
    ---------- 
    dictionary : Gensim dictionary 
    corpus : Gensim corpus 
    texts : List of input texts 
    limit : Max num of topics
    Returns: 
    ------- 
    model_list : List of LDA topic models 
    coherence_values : Coherence values corresponding to the LDA model with respective number of topics 
    """ 
     
    coherence_values = [] 
    model_list = [] 
    
    for num_topics in range(start, limit, step): 
        model = LdaModel(corpus=corpus, id2word=dictionary, num_topics=num_topics) 
        model_list.append(model) 
        coherencemodel = CoherenceModel(model=model, texts=texts, dictionary=dictionary, coherence='c_v') 
        coherence_values.append(coherencemodel.get_coherence()) 
        
    return model_list, coherence_values 
    
    
def find_optimal_number_of_topics(dictionary, corpus, processed_data): 
    limit = 40; 
    start = 2; 
    step = 6; 
    
    model_list, coherence_values = compute_coherence_values(dictionary=dictionary, corpus=corpus, texts=processed_data, start=start, limit=limit, step=step) 
    x = range(start, limit, step) 
    plt.plot(x, coherence_values) 
    plt.xlabel("Num Topics") 
    plt.ylabel("Coherence score") 
    plt.legend(("coherence_values"), loc='best') 
    plt.show() 
    
if __name__ == '__main__': 
    processed_data = [sent.strip().split(",") for sent in tqdm(open('stemm_token_adj.csv', 'r', encoding='utf-8').readlines())] 
    # 정수 인코딩과 빈도수 생성 
    dictionary = corpora.Dictionary(processed_data) 
    
    # 출현빈도가 적거나 자주 등장하는 단어는 제거 
    dictionary.filter_extremes(no_below=10, no_above=0.05) 
    corpus = [dictionary.doc2bow(text) for text in processed_data] 
    print('Number of unique tokens: %d' % len(dictionary)) 
    print('Number of documents: %d' % len(corpus)) 
    
    logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO) 
    
    # 최적의 토픽 수 찾기 
    # 
    find_optimal_number_of_topics(dictionary, corpus, processed_data)
# Out:
# 100%|██████████| 481/481 [00:00<00:00, 240775.78it/s]
# 2021-11-03 20:04:26,964 : INFO : using symmetric alpha at 0.5
# 2021-11-03 20:04:26,964 : INFO : using symmetric eta at 0.5
# 2021-11-03 20:04:26,964 : INFO : using serial LDA version on this node
# 2021-11-03 20:04:26,966 : INFO : running online (single-pass) LDA training, 2 topics, 1 passes over the supplied corpus of 481 documents, updating model once every 481 documents, evaluating perplexity every 481 documents, iterating 50x with a convergence threshold of 0.001000
# 2021-11-03 20:04:26,967 : WARNING : too few updates, training might not converge; consider increasing the number of passes or iterations to improve accuracy
# Number of unique tokens: 167
# Number of documents: 481
# 2021-11-03 20:04:27,168 : INFO : -5.683 per-word bound, 51.4 perplexity estimate based on a held-out corpus of 481 documents with 2882 words
# 2021-11-03 20:04:27,169 : INFO : PROGRESS: pass 0, at document #481/481
# 2021-11-03 20:04:27,342 : INFO : topic #0 (0.500): 0.018*"피부" + 0.015*"부항" + 0.015*"자주" + 0.012*"얘기" + 0.012*"말씀" + 0.012*"침술" + 0.012*"대충" + 0.012*"모두" + 0.011*"진행" + 0.011*"추가"
# 2021-11-03 20:04:27,343 : INFO : topic #1 (0.500): 0.015*"주사" + 0.013*"이상" + 0.013*"정형외과" + 0.012*"기억" + 0.012*"복용" + 0.011*"체질" + 0.011*"꾸준하다" + 0.011*"시술" + 0.011*"주말" + 0.011*"저렴하다"
# 2021-11-03 20:04:27,344 : INFO : topic diff=0.401705, rho=1.000000
# 2021-11-03 20:04:27,344 : INFO : LdaModel lifecycle event {'msg': 'trained LdaModel(num_terms=167, num_topics=2, decay=0.5, chunksize=2000) in 0.38s', 'datetime': '2021-11-03T20:04:27.344452', 'gensim': '4.1.2', 'python': '3.8.11 (default, Aug  6 2021, 09:57:55) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19042-SP0', 'event': 'created'}
# 2021-11-03 20:04:27,345 : INFO : using ParallelWordOccurrenceAccumulator(processes=15, batch_size=64) to estimate probabilities from sliding windows
# 2021-11-03 20:04:30,114 : INFO : 15 accumulators retrieved from output queue
# 2021-11-03 20:04:30,126 : INFO : accumulated word occurrence stats for 883 virtual documents
# 2021-11-03 20:04:30,193 : INFO : using symmetric alpha at 0.125
# 2021-11-03 20:04:30,194 : INFO : using symmetric eta at 0.125
# 2021-11-03 20:04:30,194 : INFO : using serial LDA version on this node
# 2021-11-03 20:04:30,195 : INFO : running online (single-pass) LDA training, 8 topics, 1 passes over the supplied corpus of 481 documents, updating model once every 481 documents, evaluating perplexity every 481 documents, iterating 50x with a convergence threshold of 0.001000
# 2021-11-03 20:04:30,195 : WARNING : too few updates, training might not converge; consider increasing the number of passes or iterations to improve accuracy
# 2021-11-03 20:04:30,322 : INFO : -6.571 per-word bound, 95.1 perplexity estimate based on a held-out corpus of 481 documents with 2882 words
# 2021-11-03 20:04:30,324 : INFO : PROGRESS: pass 0, at document #481/481
# 2021-11-03 20:04:30,433 : INFO : topic #3 (0.125): 0.032*"기계" + 0.031*"굉장하다" + 0.022*"꾸준하다" + 0.022*"주차" + 0.022*"저렴하다" + 0.019*"접수" + 0.019*"양방" + 0.017*"태도" + 0.017*"건물" + 0.017*"여러"
# 2021-11-03 20:04:30,434 : INFO : topic #6 (0.125): 0.041*"복용" + 0.035*"대충" + 0.028*"추가" + 0.024*"이상" + 0.024*"얘기" + 0.018*"금액" + 0.018*"전혀" + 0.018*"권유" + 0.017*"모든" + 0.014*"개월"
# 2021-11-03 20:04:30,435 : INFO : topic #0 (0.125): 0.034*"부위" + 0.027*"결제" + 0.026*"피부" + 0.021*"개인" + 0.021*"찜질" + 0.021*"필요하다" + 0.021*"진짜" + 0.019*"아주" + 0.019*"꾸준하다" + 0.016*"경우"
# 2021-11-03 20:04:30,436 : INFO : topic #2 (0.125): 0.024*"이야기" + 0.024*"이상" + 0.024*"모두" + 0.021*"기억" + 0.019*"원래" + 0.019*"원인" + 0.018*"침대" + 0.018*"개월" + 0.018*"요한" + 0.018*"상세"
# 2021-11-03 20:04:30,436 : INFO : topic #5 (0.125): 0.035*"마음" + 0.031*"편하다" + 0.025*"꼼꼼하다" + 0.022*"보통" + 0.022*"건물" + 0.022*"시술" + 0.019*"여자" + 0.019*"전문" + 0.017*"부항" + 0.014*"진행"
# 2021-11-03 20:04:30,437 : INFO : topic diff=2.219186, rho=1.000000
# 2021-11-03 20:04:30,438 : INFO : LdaModel lifecycle event {'msg': 'trained LdaModel(num_terms=167, num_topics=8, decay=0.5, chunksize=2000) in 0.24s', 'datetime': '2021-11-03T20:04:30.438971', 'gensim': '4.1.2', 'python': '3.8.11 (default, Aug  6 2021, 09:57:55) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19042-SP0', 'event': 'created'}
# 2021-11-03 20:04:30,439 : INFO : using ParallelWordOccurrenceAccumulator(processes=15, batch_size=64) to estimate probabilities from sliding windows
# 2021-11-03 20:04:33,150 : INFO : 15 accumulators retrieved from output queue
# 2021-11-03 20:04:33,178 : INFO : accumulated word occurrence stats for 975 virtual documents
# 2021-11-03 20:04:33,418 : INFO : using symmetric alpha at 0.07142857142857142
# 2021-11-03 20:04:33,419 : INFO : using symmetric eta at 0.07142857142857142
# 2021-11-03 20:04:33,419 : INFO : using serial LDA version on this node
# 2021-11-03 20:04:33,420 : INFO : running online (single-pass) LDA training, 14 topics, 1 passes over the supplied corpus of 481 documents, updating model once every 481 documents, evaluating perplexity every 481 documents, iterating 50x with a convergence threshold of 0.001000
# 2021-11-03 20:04:33,420 : WARNING : too few updates, training might not converge; consider increasing the number of passes or iterations to improve accuracy
# 2021-11-03 20:04:33,545 : INFO : -7.351 per-word bound, 163.2 perplexity estimate based on a held-out corpus of 481 documents with 2882 words
# 2021-11-03 20:04:33,545 : INFO : PROGRESS: pass 0, at document #481/481
# 2021-11-03 20:04:33,644 : INFO : topic #13 (0.071): 0.025*"호전" + 0.021*"약간" + 0.020*"이야기" + 0.020*"지금" + 0.018*"건물" + 0.018*"말씀" + 0.018*"다만" + 0.017*"대충" + 0.015*"시원하다" + 0.015*"모두"
# 2021-11-03 20:04:33,645 : INFO : topic #12 (0.071): 0.047*"피부" + 0.030*"기계" + 0.030*"아주" + 0.030*"분위기" + 0.026*"침술" + 0.023*"주차" + 0.023*"양방" + 0.023*"입원" + 0.023*"다만" + 0.023*"이용"
# 2021-11-03 20:04:33,645 : INFO : topic #5 (0.071): 0.038*"간단하다" + 0.038*"태도" + 0.037*"복용" + 0.030*"마음" + 0.029*"진찰" + 0.023*"필요하다" + 0.023*"바쁘다" + 0.023*"꾸준하다" + 0.023*"여자" + 0.023*"굉장하다"
# 2021-11-03 20:04:33,646 : INFO : topic #2 (0.071): 0.028*"데스크" + 0.026*"전화" + 0.025*"가지" + 0.024*"침술" + 0.022*"추가" + 0.021*"하니" + 0.021*"주사" + 0.018*"기계" + 0.017*"정형외과" + 0.017*"접수"
# 2021-11-03 20:04:33,646 : INFO : topic #4 (0.071): 0.069*"자주" + 0.041*"가지" + 0.041*"진짜" + 0.025*"피부" + 0.025*"요법" + 0.025*"정확하다" + 0.025*"주변" + 0.021*"거리" + 0.017*"새롭다" + 0.017*"가장"
# 2021-11-03 20:04:33,646 : INFO : topic diff=5.676439, rho=1.000000
# 2021-11-03 20:04:33,647 : INFO : LdaModel lifecycle event {'msg': 'trained LdaModel(num_terms=167, num_topics=14, decay=0.5, chunksize=2000) in 0.23s', 'datetime': '2021-11-03T20:04:33.647605', 'gensim': '4.1.2', 'python': '3.8.11 (default, Aug  6 2021, 09:57:55) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19042-SP0', 'event': 'created'}
# 2021-11-03 20:04:33,649 : INFO : using ParallelWordOccurrenceAccumulator(processes=15, batch_size=64) to estimate probabilities from sliding windows
# 2021-11-03 20:04:36,361 : INFO : 15 accumulators retrieved from output queue
# 2021-11-03 20:04:36,399 : INFO : accumulated word occurrence stats for 981 virtual documents
# 2021-11-03 20:04:36,822 : INFO : using symmetric alpha at 0.05
# 2021-11-03 20:04:36,823 : INFO : using symmetric eta at 0.05
# 2021-11-03 20:04:36,823 : INFO : using serial LDA version on this node
# 2021-11-03 20:04:36,825 : INFO : running online (single-pass) LDA training, 20 topics, 1 passes over the supplied corpus of 481 documents, updating model once every 481 documents, evaluating perplexity every 481 documents, iterating 50x with a convergence threshold of 0.001000
# 2021-11-03 20:04:36,825 : WARNING : too few updates, training might not converge; consider increasing the number of passes or iterations to improve accuracy
# 2021-11-03 20:04:36,935 : INFO : -8.223 per-word bound, 298.7 perplexity estimate based on a held-out corpus of 481 documents with 2882 words
# 2021-11-03 20:04:36,936 : INFO : PROGRESS: pass 0, at document #481/481
# 2021-11-03 20:04:37,028 : INFO : topic #9 (0.050): 0.033*"시원하다" + 0.033*"보험" + 0.028*"개인" + 0.023*"가지" + 0.023*"꾸준하다" + 0.023*"침술" + 0.023*"데스크" + 0.023*"약간" + 0.022*"찜질" + 0.017*"위해"
# 2021-11-03 20:04:37,028 : INFO : topic #4 (0.050): 0.054*"저렴하다" + 0.044*"상세" + 0.033*"전혀" + 0.033*"친절" + 0.025*"모든" + 0.024*"원래" + 0.024*"방법" + 0.022*"접수" + 0.022*"침술" + 0.022*"편입"
# 2021-11-03 20:04:37,029 : INFO : topic #1 (0.050): 0.036*"개월" + 0.032*"리뷰" + 0.024*"소개" + 0.024*"간단하다" + 0.024*"가깝다" + 0.024*"실력" + 0.024*"부위" + 0.023*"꼼꼼하다" + 0.023*"개인" + 0.021*"복용"
# 2021-11-03 20:04:37,030 : INFO : topic #7 (0.050): 0.047*"발목" + 0.047*"입원" + 0.047*"교통사고" + 0.039*"호전" + 0.032*"요법" + 0.032*"진행" + 0.024*"대답" + 0.024*"진짜" + 0.024*"정확하다" + 0.024*"건물"
# 2021-11-03 20:04:37,030 : INFO : topic #14 (0.050): 0.053*"진행" + 0.049*"결제" + 0.042*"꼼꼼하다" + 0.033*"보통" + 0.026*"굉장하다" + 0.025*"부항" + 0.023*"진단" + 0.021*"안되다" + 0.020*"분위기" + 0.019*"카운터"
# 2021-11-03 20:04:37,031 : INFO : topic diff=9.908121, rho=1.000000
# 2021-11-03 20:04:37,031 : INFO : LdaModel lifecycle event {'msg': 'trained LdaModel(num_terms=167, num_topics=20, decay=0.5, chunksize=2000) in 0.21s', 'datetime': '2021-11-03T20:04:37.031446', 'gensim': '4.1.2', 'python': '3.8.11 (default, Aug  6 2021, 09:57:55) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19042-SP0', 'event': 'created'}
# 2021-11-03 20:04:37,034 : INFO : using ParallelWordOccurrenceAccumulator(processes=15, batch_size=64) to estimate probabilities from sliding windows
# 2021-11-03 20:04:39,991 : INFO : 15 accumulators retrieved from output queue
# 2021-11-03 20:04:40,037 : INFO : accumulated word occurrence stats for 984 virtual documents
# 2021-11-03 20:04:40,585 : INFO : using symmetric alpha at 0.038461538461538464
# 2021-11-03 20:04:40,586 : INFO : using symmetric eta at 0.038461538461538464
# 2021-11-03 20:04:40,586 : INFO : using serial LDA version on this node
# 2021-11-03 20:04:40,587 : INFO : running online (single-pass) LDA training, 26 topics, 1 passes over the supplied corpus of 481 documents, updating model once every 481 documents, evaluating perplexity every 481 documents, iterating 50x with a convergence threshold of 0.001000
# 2021-11-03 20:04:40,588 : WARNING : too few updates, training might not converge; consider increasing the number of passes or iterations to improve accuracy
# 2021-11-03 20:04:40,695 : INFO : -9.169 per-word bound, 575.7 perplexity estimate based on a held-out corpus of 481 documents with 2882 words
# 2021-11-03 20:04:40,695 : INFO : PROGRESS: pass 0, at document #481/481
# 2021-11-03 20:04:40,778 : INFO : topic #7 (0.038): 0.070*"리뷰" + 0.039*"부위" + 0.031*"피부" + 0.031*"개월" + 0.031*"처치" + 0.031*"진단" + 0.023*"전반" + 0.023*"침대" + 0.023*"체질" + 0.023*"꾸준하다"
# 2021-11-03 20:04:40,779 : INFO : topic #9 (0.038): 0.051*"자주" + 0.051*"요법" + 0.037*"보험" + 0.029*"소리" + 0.029*"그다지" + 0.023*"결제" + 0.022*"해주시" + 0.022*"한번" + 0.022*"찜질" + 0.022*"바쁘다"
# 2021-11-03 20:04:40,780 : INFO : topic #14 (0.038): 0.067*"주사" + 0.040*"데스크" + 0.040*"기본" + 0.040*"계시다" + 0.027*"인테리어" + 0.027*"전혀" + 0.027*"코로나" + 0.027*"태도" + 0.027*"주변" + 0.027*"시술"
# 2021-11-03 20:04:40,780 : INFO : topic #15 (0.038): 0.056*"마음" + 0.049*"개월" + 0.035*"복용" + 0.028*"시술" + 0.028*"편하다" + 0.028*"소개" + 0.024*"간단하다" + 0.021*"권유" + 0.021*"이상" + 0.021*"모든"
# 2021-11-03 20:04:40,781 : INFO : topic #3 (0.038): 0.038*"경우" + 0.030*"방법" + 0.030*"확인" + 0.030*"부항" + 0.030*"교통사고" + 0.030*"평일" + 0.023*"이후" + 0.023*"가지" + 0.023*"검색" + 0.023*"먼저"
# 2021-11-03 20:04:40,781 : INFO : topic diff=14.727118, rho=1.000000
# 2021-11-03 20:04:40,782 : INFO : LdaModel lifecycle event {'msg': 'trained LdaModel(num_terms=167, num_topics=26, decay=0.5, chunksize=2000) in 0.20s', 'datetime': '2021-11-03T20:04:40.782787', 'gensim': '4.1.2', 'python': '3.8.11 (default, Aug  6 2021, 09:57:55) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19042-SP0', 'event': 'created'}
# 2021-11-03 20:04:40,784 : INFO : using ParallelWordOccurrenceAccumulator(processes=15, batch_size=64) to estimate probabilities from sliding windows
# 2021-11-03 20:04:43,622 : INFO : 15 accumulators retrieved from output queue
# 2021-11-03 20:04:43,669 : INFO : accumulated word occurrence stats for 983 virtual documents
# 2021-11-03 20:04:44,368 : INFO : using symmetric alpha at 0.03125
# 2021-11-03 20:04:44,369 : INFO : using symmetric eta at 0.03125
# 2021-11-03 20:04:44,369 : INFO : using serial LDA version on this node
# 2021-11-03 20:04:44,370 : INFO : running online (single-pass) LDA training, 32 topics, 1 passes over the supplied corpus of 481 documents, updating model once every 481 documents, evaluating perplexity every 481 documents, iterating 50x with a convergence threshold of 0.001000
# 2021-11-03 20:04:44,371 : WARNING : too few updates, training might not converge; consider increasing the number of passes or iterations to improve accuracy
# 2021-11-03 20:04:44,481 : INFO : -10.358 per-word bound, 1312.4 perplexity estimate based on a held-out corpus of 481 documents with 2882 words
# 2021-11-03 20:04:44,482 : INFO : PROGRESS: pass 0, at document #481/481
# 2021-11-03 20:04:44,566 : INFO : topic #4 (0.031): 0.085*"진행" + 0.057*"자주" + 0.043*"경우" + 0.029*"만족하다" + 0.029*"건물" + 0.029*"친절" + 0.029*"전반" + 0.029*"원인" + 0.029*"가기" + 0.029*"모두"
# 2021-11-03 20:04:44,566 : INFO : topic #24 (0.031): 0.041*"요한" + 0.041*"힘들다" + 0.031*"전체" + 0.031*"특별하다" + 0.031*"피부" + 0.031*"다르다" + 0.031*"가깝다" + 0.031*"발목" + 0.031*"주말" + 0.020*"전문"
# 2021-11-03 20:04:44,567 : INFO : topic #23 (0.031): 0.048*"피부" + 0.039*"시술" + 0.039*"진단" + 0.029*"이야기" + 0.029*"추가" + 0.029*"가지" + 0.029*"소개" + 0.026*"주차" + 0.024*"주사" + 0.023*"편하다"
# 2021-11-03 20:04:44,568 : INFO : topic #7 (0.031): 0.044*"시술" + 0.039*"부위" + 0.030*"처치" + 0.026*"힘들다" + 0.026*"발목" + 0.026*"가게" + 0.026*"평일" + 0.021*"필요하다" + 0.017*"가장" + 0.017*"꼼꼼하다"
# 2021-11-03 20:04:44,568 : INFO : topic #1 (0.031): 0.066*"거의" + 0.047*"리뷰" + 0.029*"원인" + 0.029*"진찰" + 0.029*"얘기" + 0.029*"대충" + 0.029*"체질" + 0.019*"직접" + 0.019*"결제" + 0.019*"교통사고"
# 2021-11-03 20:04:44,569 : INFO : topic diff=19.782639, rho=1.000000
# 2021-11-03 20:04:44,570 : INFO : LdaModel lifecycle event {'msg': 'trained LdaModel(num_terms=167, num_topics=32, decay=0.5, chunksize=2000) in 0.20s', 'datetime': '2021-11-03T20:04:44.570184', 'gensim': '4.1.2', 'python': '3.8.11 (default, Aug  6 2021, 09:57:55) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19042-SP0', 'event': 'created'}
# 2021-11-03 20:04:44,572 : INFO : using ParallelWordOccurrenceAccumulator(processes=15, batch_size=64) to estimate probabilities from sliding windows
# 2021-11-03 20:04:47,342 : INFO : 15 accumulators retrieved from output queue
# 2021-11-03 20:04:47,391 : INFO : accumulated word occurrence stats for 984 virtual documents
# 2021-11-03 20:04:48,212 : INFO : using symmetric alpha at 0.02631578947368421
# 2021-11-03 20:04:48,213 : INFO : using symmetric eta at 0.02631578947368421
# 2021-11-03 20:04:48,213 : INFO : using serial LDA version on this node
# 2021-11-03 20:04:48,214 : INFO : running online (single-pass) LDA training, 38 topics, 1 passes over the supplied corpus of 481 documents, updating model once every 481 documents, evaluating perplexity every 481 documents, iterating 50x with a convergence threshold of 0.001000
# 2021-11-03 20:04:48,215 : WARNING : too few updates, training might not converge; consider increasing the number of passes or iterations to improve accuracy
# 2021-11-03 20:04:48,327 : INFO : -11.621 per-word bound, 3149.0 perplexity estimate based on a held-out corpus of 481 documents with 2882 words
# 2021-11-03 20:04:48,327 : INFO : PROGRESS: pass 0, at document #481/481
# 2021-11-03 20:04:48,410 : INFO : topic #2 (0.026): 0.054*"기억" + 0.041*"가면" + 0.041*"부위" + 0.041*"모두" + 0.027*"기본" + 0.027*"본인" + 0.027*"리뷰" + 0.027*"병행" + 0.027*"접근성" + 0.027*"입원"
# 2021-11-03 20:04:48,411 : INFO : topic #12 (0.026): 0.037*"질문" + 0.037*"권유" + 0.037*"요한" + 0.037*"위해" + 0.037*"본인" + 0.037*"어렵다" + 0.037*"건물" + 0.037*"약도" + 0.037*"보통" + 0.037*"전혀"
# 2021-11-03 20:04:48,411 : INFO : topic #31 (0.026): 0.070*"대충" + 0.058*"결제" + 0.047*"정형외과" + 0.035*"진짜" + 0.035*"주말" + 0.035*"이상" + 0.024*"부항" + 0.024*"어렵다" + 0.024*"여자" + 0.024*"검색"
# 2021-11-03 20:04:48,412 : INFO : topic #23 (0.026): 0.057*"시술" + 0.049*"양방" + 0.041*"주변" + 0.033*"발목" + 0.033*"편입" + 0.033*"이야기" + 0.033*"건물" + 0.033*"피부" + 0.025*"얘기" + 0.025*"모든"
# 2021-11-03 20:04:48,412 : INFO : topic #25 (0.026): 0.036*"진찰" + 0.036*"주변" + 0.036*"원래" + 0.036*"요한" + 0.036*"말씀" + 0.024*"다르다" + 0.024*"호전" + 0.024*"먼저" + 0.024*"접근성" + 0.024*"권유"
# 2021-11-03 20:04:48,413 : INFO : topic diff=25.308310, rho=1.000000
# 2021-11-03 20:04:48,414 : INFO : LdaModel lifecycle event {'msg': 'trained LdaModel(num_terms=167, num_topics=38, decay=0.5, chunksize=2000) in 0.20s', 'datetime': '2021-11-03T20:04:48.414462', 'gensim': '4.1.2', 'python': '3.8.11 (default, Aug  6 2021, 09:57:55) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19042-SP0', 'event': 'created'}
# 2021-11-03 20:04:48,417 : INFO : using ParallelWordOccurrenceAccumulator(processes=15, batch_size=64) to estimate probabilities from sliding windows
# 2021-11-03 20:04:51,165 : INFO : 15 accumulators retrieved from output queue
# 2021-11-03 20:04:51,221 : INFO : accumulated word occurrence stats for 984 virtual documents

# %%
if __name__ == '__main__': 
    processed_data = [sent.strip().split(",") for sent in tqdm(open('stemm_token_adj.csv', 'r', encoding='utf-8').readlines())] 
    
    # 정수 인코딩과 빈도수 생성 d
    dictionary = corpora.Dictionary(processed_data) 
    
    # 출현빈도가 적거나 자주 등장하는 단어는 제거 
    dictionary.filter_extremes(no_below=10, no_above=0.05) 
    corpus = [dictionary.doc2bow(text) for text in processed_data] 
    print('Number of unique tokens: %d' % len(dictionary)) 
    print('Number of documents: %d' % len(corpus)) 
    
    logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO) 
    
    # 최적의 토픽 수 찾기 => 35개로 나옴 
    # # find_optimal_number_of_topics(dictionary, corpus, processed_data) 
    # # exit() 
    # 
    perplexity_logger = PerplexityMetric(corpus=corpus, logger='shell') 
    coherence_logger = CoherenceMetric(corpus=corpus, coherence="u_mass", logger='shell') 
    
    lda_model = LdaModel(corpus, id2word=dictionary, num_topics=4, passes=30, callbacks=[coherence_logger, perplexity_logger]) 
    
    topics = lda_model.print_topics(num_words=5) 
    for topic in topics: 
        print(topic) 
        
    # Compute Coherence Score using c_v 
    coherence_model_lda = CoherenceModel(model=lda_model, texts=processed_data, dictionary=dictionary, coherence='c_v') 
    coherence_lda = coherence_model_lda.get_coherence() 
    print('\nCoherence Score (c_v): ', coherence_lda) 
    
    # Compute Coherence Score using UMass 
    coherence_model_lda = CoherenceModel(model=lda_model, texts=processed_data, dictionary=dictionary, coherence="u_mass") 
    coherence_lda = coherence_model_lda.get_coherence() 
    print('\nCoherence Score (u_mass): ', coherence_lda) 
    
    
    # 저장 
    pickle.dump(corpus, open('lda_corpus.pkl', 'wb')) 
    dictionary.save('lda_dictionary.gensim') 
    lda_model.save('lda_model.gensim') 
    
    # pyLDAvis html 저장 
    lda_visualization = pyLDAvis.gensim.prepare(lda_model, corpus, dictionary, sort_topics=True) 
    pyLDAvis.save_html(lda_visualization, 'lda_v3.html') 
    pyLDAvis.show(lda_visualization)
# Out:
# 100%|██████████| 481/481 [00:00<00:00, 240002.41it/s]
# 2021-11-03 20:06:00,296 : INFO : adding document #0 to Dictionary(0 unique tokens: [])
# 2021-11-03 20:06:00,313 : INFO : built Dictionary(2663 unique tokens: ['가게', '같다', '깨끗하다', '대기실', '대해']...) from 481 documents (total 16747 corpus positions)
# 2021-11-03 20:06:00,314 : INFO : Dictionary lifecycle event {'msg': "built Dictionary(2663 unique tokens: ['가게', '같다', '깨끗하다', '대기실', '대해']...) from 481 documents (total 16747 corpus positions)", 'datetime': '2021-11-03T20:06:00.314079', 'gensim': '4.1.2', 'python': '3.8.11 (default, Aug  6 2021, 09:57:55) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19042-SP0', 'event': 'created'}
# 2021-11-03 20:06:00,317 : INFO : discarding 2496 tokens: [('같다', 201), ('깨끗하다', 47), ('대기실', 7), ('대해', 34), ('때문', 56), ('마침', 3), ('며칠', 8), ('미미하다', 4), ('부탁드리다', 2), ('선생님', 120)]...
# 2021-11-03 20:06:00,317 : INFO : keeping 167 tokens which were in no less than 10 and no more than 24 (=5.0%) documents
# 2021-11-03 20:06:00,318 : INFO : resulting dictionary: Dictionary(167 unique tokens: ['가게', '동안', '디스크', '리뷰', '스럽다']...)
# 2021-11-03 20:06:00,325 : INFO : using symmetric alpha at 0.25
# 2021-11-03 20:06:00,325 : INFO : using symmetric eta at 0.25
# 2021-11-03 20:06:00,326 : INFO : using serial LDA version on this node
# 2021-11-03 20:06:00,327 : INFO : running online (multi-pass) LDA training, 4 topics, 30 passes over the supplied corpus of 481 documents, updating model once every 481 documents, evaluating perplexity every 481 documents, iterating 50x with a convergence threshold of 0.001000
# 2021-11-03 20:06:00,486 : INFO : -6.056 per-word bound, 66.5 perplexity estimate based on a held-out corpus of 481 documents with 2882 words
# 2021-11-03 20:06:00,486 : INFO : PROGRESS: pass 0, at document #481/481
# Number of unique tokens: 167
# Number of documents: 481
# 2021-11-03 20:06:00,617 : INFO : topic #0 (0.250): 0.026*"진행" + 0.022*"부항" + 0.019*"가깝다" + 0.017*"모두" + 0.016*"원래" + 0.016*"기본" + 0.015*"자주" + 0.015*"말씀" + 0.015*"기억" + 0.014*"약간"
# 2021-11-03 20:06:00,618 : INFO : topic #1 (0.250): 0.024*"얘기" + 0.018*"복용" + 0.017*"한번" + 0.017*"건물" + 0.016*"부황" + 0.015*"대충" + 0.015*"여자" + 0.015*"찜질" + 0.014*"시술" + 0.014*"지금"
# 2021-11-03 20:06:00,618 : INFO : topic #2 (0.250): 0.024*"꾸준하다" + 0.022*"보통" + 0.019*"결제" + 0.017*"침술" + 0.017*"거의" + 0.015*"대충" + 0.014*"부위" + 0.014*"진단" + 0.014*"리뷰" + 0.014*"다리"
# 2021-11-03 20:06:00,619 : INFO : topic #3 (0.250): 0.028*"주사" + 0.026*"피부" + 0.019*"전혀" + 0.019*"체질" + 0.016*"달라" + 0.015*"힘들다" + 0.015*"진짜" + 0.015*"시술" + 0.014*"정형외과" + 0.014*"이상"
# 2021-11-03 20:06:00,619 : INFO : topic diff=0.772155, rho=1.000000
# 2021-11-03 20:06:00,622 : INFO : Epoch 0: Coherence estimate: -10.141107810294315
# 2021-11-03 20:06:00,744 : INFO : Epoch 0: Perplexity estimate: 47.65736347902793
# 2021-11-03 20:06:00,869 : INFO : -5.575 per-word bound, 47.7 perplexity estimate based on a held-out corpus of 481 documents with 2882 words
# 2021-11-03 20:06:00,870 : INFO : PROGRESS: pass 1, at document #481/481
# 2021-11-03 20:06:00,970 : INFO : topic #0 (0.250): 0.029*"진행" + 0.026*"부항" + 0.020*"가깝다" + 0.019*"모두" + 0.018*"원래" + 0.018*"기본" + 0.017*"자주" + 0.016*"말씀" + 0.016*"기억" + 0.015*"주말"
# 2021-11-03 20:06:00,970 : INFO : topic #1 (0.250): 0.025*"얘기" + 0.021*"복용" + 0.018*"한번" + 0.016*"부황" + 0.016*"입원" + 0.016*"건물" + 0.016*"여자" + 0.015*"하니" + 0.015*"이야기" + 0.015*"찜질"
# 2021-11-03 20:06:00,971 : INFO : topic #2 (0.250): 0.027*"꾸준하다" + 0.023*"보통" + 0.020*"결제" + 0.019*"침술" + 0.019*"거의" + 0.017*"대충" + 0.017*"부위" + 0.016*"개인" + 0.015*"진단" + 0.015*"리뷰"
# 2021-11-03 20:06:00,971 : INFO : topic #3 (0.250): 0.032*"주사" + 0.030*"피부" + 0.023*"전혀" + 0.020*"체질" + 0.018*"진짜" + 0.017*"달라" + 0.017*"힘들다" + 0.017*"시술" + 0.016*"분위기" + 0.015*"이상"
# 2021-11-03 20:06:00,971 : INFO : topic diff=0.233006, rho=0.577350
# 2021-11-03 20:06:00,974 : INFO : Epoch 1: Coherence estimate: -10.322031379545878
# 2021-11-03 20:06:01,087 : INFO : Epoch 1: Perplexity estimate: 46.0137710612344
# 2021-11-03 20:06:01,201 : INFO : -5.524 per-word bound, 46.0 perplexity estimate based on a held-out corpus of 481 documents with 2882 words
# 2021-11-03 20:06:01,202 : INFO : PROGRESS: pass 2, at document #481/481
# 2021-11-03 20:06:01,291 : INFO : topic #0 (0.250): 0.031*"진행" + 0.029*"부항" + 0.021*"가깝다" + 0.020*"모두" + 0.019*"기본" + 0.018*"원래" + 0.018*"주말" + 0.016*"말씀" + 0.016*"자주" + 0.016*"빠르다"
# 2021-11-03 20:06:01,291 : INFO : topic #1 (0.250): 0.026*"얘기" + 0.023*"복용" + 0.018*"한번" + 0.017*"입원" + 0.017*"여자" + 0.017*"이야기" + 0.016*"부황" + 0.016*"건물" + 0.016*"하니" + 0.016*"가지"
# 2021-11-03 20:06:01,292 : INFO : topic #2 (0.250): 0.029*"꾸준하다" + 0.024*"보통" + 0.021*"거의" + 0.021*"침술" + 0.020*"결제" + 0.019*"대충" + 0.018*"부위" + 0.018*"개인" + 0.016*"진단" + 0.016*"리뷰"
# 2021-11-03 20:06:01,293 : INFO : topic #3 (0.250): 0.034*"주사" + 0.032*"피부" + 0.024*"전혀" + 0.021*"체질" + 0.020*"진짜" + 0.019*"시술" + 0.018*"달라" + 0.017*"힘들다" + 0.017*"분위기" + 0.016*"이상"
# 2021-11-03 20:06:01,293 : INFO : topic diff=0.188911, rho=0.500000
# 2021-11-03 20:06:01,297 : INFO : Epoch 2: Coherence estimate: -10.164753732530247
# 2021-11-03 20:06:01,402 : INFO : Epoch 2: Perplexity estimate: 45.069109726521305
# 2021-11-03 20:06:01,508 : INFO : -5.494 per-word bound, 45.1 perplexity estimate based on a held-out corpus of 481 documents with 2882 words
# 2021-11-03 20:06:01,509 : INFO : PROGRESS: pass 3, at document #481/481
# 2021-11-03 20:06:01,591 : INFO : topic #0 (0.250): 0.032*"진행" + 0.030*"부항" + 0.022*"가깝다" + 0.021*"모두" + 0.020*"주말" + 0.020*"기본" + 0.019*"원래" + 0.017*"빠르다" + 0.016*"말씀" + 0.016*"약간"
# 2021-11-03 20:06:01,592 : INFO : topic #1 (0.250): 0.027*"얘기" + 0.023*"복용" + 0.018*"입원" + 0.018*"이야기" + 0.017*"한번" + 0.017*"여자" + 0.017*"기계" + 0.016*"하니" + 0.016*"잘못" + 0.016*"가지"
# 2021-11-03 20:06:01,592 : INFO : topic #2 (0.250): 0.031*"꾸준하다" + 0.024*"보통" + 0.022*"침술" + 0.022*"거의" + 0.021*"결제" + 0.020*"개인" + 0.020*"대충" + 0.019*"부위" + 0.017*"진단" + 0.016*"리뷰"
# 2021-11-03 20:06:01,593 : INFO : topic #3 (0.250): 0.034*"주사" + 0.033*"피부" + 0.025*"전혀" + 0.021*"시술" + 0.021*"체질" + 0.020*"진짜" + 0.018*"달라" + 0.018*"분위기" + 0.017*"힘들다" + 0.017*"이상"
# 2021-11-03 20:06:01,593 : INFO : topic diff=0.160353, rho=0.447214
# 2021-11-03 20:06:01,597 : INFO : Epoch 3: Coherence estimate: -10.122296363174428
# 2021-11-03 20:06:01,700 : INFO : Epoch 3: Perplexity estimate: 44.47019437551358
# 2021-11-03 20:06:01,802 : INFO : -5.475 per-word bound, 44.5 perplexity estimate based on a held-out corpus of 481 documents with 2882 words
# 2021-11-03 20:06:01,803 : INFO : PROGRESS: pass 4, at document #481/481
# 2021-11-03 20:06:01,883 : INFO : topic #0 (0.250): 0.033*"진행" + 0.032*"부항" + 0.023*"가깝다" + 0.022*"주말" + 0.021*"모두" + 0.021*"기본" + 0.019*"원래" + 0.018*"찜질" + 0.017*"빠르다" + 0.016*"약간"
# 2021-11-03 20:06:01,883 : INFO : topic #1 (0.250): 0.027*"얘기" + 0.024*"복용" + 0.018*"이야기" + 0.018*"기계" + 0.018*"입원" + 0.018*"여자" + 0.017*"잘못" + 0.017*"한번" + 0.017*"가지" + 0.017*"하니"
# 2021-11-03 20:06:01,884 : INFO : topic #2 (0.250): 0.032*"꾸준하다" + 0.024*"보통" + 0.022*"침술" + 0.022*"거의" + 0.022*"개인" + 0.022*"결제" + 0.021*"대충" + 0.020*"부위" + 0.017*"진단" + 0.017*"여러"
# 2021-11-03 20:06:01,884 : INFO : topic #3 (0.250): 0.035*"주사" + 0.033*"피부" + 0.026*"전혀" + 0.023*"시술" + 0.021*"체질" + 0.021*"진짜" + 0.018*"달라" + 0.018*"분위기" + 0.017*"이상" + 0.017*"안되다"
# 2021-11-03 20:06:01,885 : INFO : topic diff=0.139296, rho=0.408248
# 2021-11-03 20:06:01,887 : INFO : Epoch 4: Coherence estimate: -9.341589081255355
# 2021-11-03 20:06:01,994 : INFO : Epoch 4: Perplexity estimate: 44.03363980352176
# 2021-11-03 20:06:02,098 : INFO : -5.461 per-word bound, 44.0 perplexity estimate based on a held-out corpus of 481 documents with 2882 words
# 2021-11-03 20:06:02,099 : INFO : PROGRESS: pass 5, at document #481/481
# 2021-11-03 20:06:02,177 : INFO : topic #0 (0.250): 0.034*"진행" + 0.033*"부항" + 0.023*"가깝다" + 0.023*"주말" + 0.021*"기본" + 0.021*"모두" + 0.020*"찜질" + 0.020*"원래" + 0.018*"빠르다" + 0.017*"다만"
# 2021-11-03 20:06:02,177 : INFO : topic #1 (0.250): 0.027*"얘기" + 0.024*"복용" + 0.019*"기계" + 0.019*"이야기" + 0.018*"잘못" + 0.018*"입원" + 0.018*"여자" + 0.017*"가지" + 0.017*"한번" + 0.017*"하니"
# 2021-11-03 20:06:02,178 : INFO : topic #2 (0.250): 0.033*"꾸준하다" + 0.024*"보통" + 0.023*"개인" + 0.023*"침술" + 0.023*"거의" + 0.022*"결제" + 0.021*"대충" + 0.020*"부위" + 0.017*"진단" + 0.017*"다리"
# 2021-11-03 20:06:02,179 : INFO : topic #3 (0.250): 0.035*"주사" + 0.034*"피부" + 0.026*"전혀" + 0.024*"시술" + 0.022*"체질" + 0.021*"진짜" + 0.019*"달라" + 0.018*"분위기" + 0.018*"안되다" + 0.018*"이상"
# 2021-11-03 20:06:02,180 : INFO : topic diff=0.122621, rho=0.377964
# 2021-11-03 20:06:02,184 : INFO : Epoch 5: Coherence estimate: -9.100165835119471
# 2021-11-03 20:06:02,282 : INFO : Epoch 5: Perplexity estimate: 43.701867332832265
# 2021-11-03 20:06:02,382 : INFO : -5.450 per-word bound, 43.7 perplexity estimate based on a held-out corpus of 481 documents with 2882 words
# 2021-11-03 20:06:02,383 : INFO : PROGRESS: pass 6, at document #481/481
# 2021-11-03 20:06:02,460 : INFO : topic #0 (0.250): 0.034*"진행" + 0.034*"부항" + 0.024*"가깝다" + 0.024*"주말" + 0.022*"기본" + 0.021*"찜질" + 0.021*"모두" + 0.020*"원래" + 0.018*"다만" + 0.018*"빠르다"
# 2021-11-03 20:06:02,461 : INFO : topic #1 (0.250): 0.027*"얘기" + 0.024*"복용" + 0.020*"기계" + 0.019*"잘못" + 0.019*"이야기" + 0.018*"입원" + 0.018*"여자" + 0.018*"가지" + 0.017*"태도" + 0.017*"한번"
# 2021-11-03 20:06:02,461 : INFO : topic #2 (0.250): 0.034*"꾸준하다" + 0.024*"보통" + 0.024*"개인" + 0.023*"침술" + 0.023*"거의" + 0.022*"대충" + 0.022*"결제" + 0.021*"부위" + 0.018*"다리" + 0.017*"진단"
# 2021-11-03 20:06:02,462 : INFO : topic #3 (0.250): 0.035*"주사" + 0.034*"피부" + 0.026*"전혀" + 0.025*"시술" + 0.022*"체질" + 0.022*"진짜" + 0.020*"달라" + 0.019*"안되다" + 0.018*"이상" + 0.018*"분위기"
# 2021-11-03 20:06:02,463 : INFO : topic diff=0.108553, rho=0.353553
# 2021-11-03 20:06:02,465 : INFO : Epoch 6: Coherence estimate: -9.142676287737862
# 2021-11-03 20:06:02,562 : INFO : Epoch 6: Perplexity estimate: 43.42587390352137
# 2021-11-03 20:06:02,658 : INFO : -5.440 per-word bound, 43.4 perplexity estimate based on a held-out corpus of 481 documents with 2882 words
# 2021-11-03 20:06:02,658 : INFO : PROGRESS: pass 7, at document #481/481
# 2021-11-03 20:06:02,735 : INFO : topic #0 (0.250): 0.035*"부항" + 0.035*"진행" + 0.024*"주말" + 0.024*"가깝다" + 0.023*"찜질" + 0.022*"기본" + 0.021*"모두" + 0.020*"원래" + 0.019*"다만" + 0.018*"빠르다"
# 2021-11-03 20:06:02,735 : INFO : topic #1 (0.250): 0.027*"얘기" + 0.024*"복용" + 0.021*"기계" + 0.020*"잘못" + 0.019*"이야기" + 0.018*"입원" + 0.018*"가지" + 0.018*"태도" + 0.018*"여자" + 0.017*"굉장하다"
# 2021-11-03 20:06:02,736 : INFO : topic #2 (0.250): 0.034*"꾸준하다" + 0.025*"개인" + 0.024*"보통" + 0.024*"침술" + 0.023*"거의" + 0.023*"대충" + 0.022*"결제" + 0.022*"부위" + 0.018*"다리" + 0.017*"진단"
# 2021-11-03 20:06:02,737 : INFO : topic #3 (0.250): 0.035*"주사" + 0.034*"피부" + 0.026*"시술" + 0.026*"전혀" + 0.022*"체질" + 0.022*"진짜" + 0.020*"달라" + 0.019*"이상" + 0.019*"안되다" + 0.018*"동안"
# 2021-11-03 20:06:02,737 : INFO : topic diff=0.097203, rho=0.333333
# 2021-11-03 20:06:02,739 : INFO : Epoch 7: Coherence estimate: -8.904109521033103
# 2021-11-03 20:06:02,837 : INFO : Epoch 7: Perplexity estimate: 43.2018968980139
# 2021-11-03 20:06:02,929 : INFO : -5.433 per-word bound, 43.2 perplexity estimate based on a held-out corpus of 481 documents with 2882 words
# 2021-11-03 20:06:02,930 : INFO : PROGRESS: pass 8, at document #481/481
# 2021-11-03 20:06:03,002 : INFO : topic #0 (0.250): 0.036*"부항" + 0.036*"진행" + 0.025*"주말" + 0.024*"찜질" + 0.024*"가깝다" + 0.023*"기본" + 0.021*"모두" + 0.021*"원래" + 0.020*"다만" + 0.019*"해주시"
# 2021-11-03 20:06:03,003 : INFO : topic #1 (0.250): 0.027*"얘기" + 0.024*"복용" + 0.022*"기계" + 0.021*"잘못" + 0.019*"이야기" + 0.018*"태도" + 0.018*"입원" + 0.018*"가지" + 0.018*"여자" + 0.018*"굉장하다"
# 2021-11-03 20:06:03,003 : INFO : topic #2 (0.250): 0.035*"꾸준하다" + 0.025*"개인" + 0.024*"침술" + 0.024*"보통" + 0.023*"대충" + 0.023*"거의" + 0.022*"부위" + 0.022*"결제" + 0.018*"다리" + 0.018*"여러"
# 2021-11-03 20:06:03,004 : INFO : topic #3 (0.250): 0.035*"주사" + 0.034*"피부" + 0.027*"시술" + 0.026*"전혀" + 0.022*"진짜" + 0.022*"체질" + 0.020*"달라" + 0.020*"이상" + 0.019*"안되다" + 0.019*"동안"
# 2021-11-03 20:06:03,004 : INFO : topic diff=0.086139, rho=0.316228
# 2021-11-03 20:06:03,007 : INFO : Epoch 8: Coherence estimate: -8.79386997139254
# 2021-11-03 20:06:03,106 : INFO : Epoch 8: Perplexity estimate: 43.02080536083325
# 2021-11-03 20:06:03,199 : INFO : -5.427 per-word bound, 43.0 perplexity estimate based on a held-out corpus of 481 documents with 2882 words
# 2021-11-03 20:06:03,199 : INFO : PROGRESS: pass 9, at document #481/481
# 2021-11-03 20:06:03,276 : INFO : topic #0 (0.250): 0.037*"부항" + 0.036*"진행" + 0.026*"찜질" + 0.026*"주말" + 0.024*"가깝다" + 0.023*"기본" + 0.021*"모두" + 0.021*"원래" + 0.021*"다만" + 0.019*"해주시"
# 2021-11-03 20:06:03,277 : INFO : topic #1 (0.250): 0.026*"얘기" + 0.024*"복용" + 0.022*"기계" + 0.021*"잘못" + 0.019*"이야기" + 0.019*"태도" + 0.018*"가지" + 0.018*"입원" + 0.018*"굉장하다" + 0.018*"여자"
# 2021-11-03 20:06:03,277 : INFO : topic #2 (0.250): 0.035*"꾸준하다" + 0.026*"개인" + 0.025*"침술" + 0.024*"보통" + 0.024*"대충" + 0.023*"거의" + 0.022*"부위" + 0.022*"결제" + 0.019*"다리" + 0.018*"여러"
# 2021-11-03 20:06:03,277 : INFO : topic #3 (0.250): 0.036*"주사" + 0.035*"피부" + 0.028*"시술" + 0.026*"전혀" + 0.022*"진짜" + 0.022*"체질" + 0.021*"달라" + 0.020*"이상" + 0.020*"안되다" + 0.019*"동안"
# 2021-11-03 20:06:03,278 : INFO : topic diff=0.076319, rho=0.301511
# 2021-11-03 20:06:03,281 : INFO : Epoch 9: Coherence estimate: -8.80012987786829
# 2021-11-03 20:06:03,374 : INFO : Epoch 9: Perplexity estimate: 42.8752493426867
# 2021-11-03 20:06:03,469 : INFO : -5.422 per-word bound, 42.9 perplexity estimate based on a held-out corpus of 481 documents with 2882 words
# 2021-11-03 20:06:03,470 : INFO : PROGRESS: pass 10, at document #481/481
# 2021-11-03 20:06:03,540 : INFO : topic #0 (0.250): 0.037*"부항" + 0.036*"진행" + 0.027*"찜질" + 0.026*"주말" + 0.025*"가깝다" + 0.023*"기본" + 0.021*"다만" + 0.021*"원래" + 0.020*"모두" + 0.019*"해주시"
# 2021-11-03 20:06:03,540 : INFO : topic #1 (0.250): 0.026*"얘기" + 0.024*"복용" + 0.023*"기계" + 0.022*"잘못" + 0.019*"이야기" + 0.019*"태도" + 0.019*"가지" + 0.018*"입원" + 0.018*"굉장하다" + 0.018*"여자"
# 2021-11-03 20:06:03,541 : INFO : topic #2 (0.250): 0.035*"꾸준하다" + 0.026*"개인" + 0.025*"침술" + 0.024*"대충" + 0.024*"보통" + 0.023*"거의" + 0.022*"부위" + 0.022*"결제" + 0.019*"다리" + 0.018*"여러"
# 2021-11-03 20:06:03,541 : INFO : topic #3 (0.250): 0.036*"주사" + 0.035*"피부" + 0.029*"시술" + 0.026*"전혀" + 0.023*"진짜" + 0.022*"체질" + 0.021*"달라" + 0.020*"이상" + 0.020*"안되다" + 0.019*"동안"
# 2021-11-03 20:06:03,541 : INFO : topic diff=0.067964, rho=0.288675
# 2021-11-03 20:06:03,544 : INFO : Epoch 10: Coherence estimate: -8.79963596939528
# 2021-11-03 20:06:03,639 : INFO : Epoch 10: Perplexity estimate: 42.75387645049588
# 2021-11-03 20:06:03,732 : INFO : -5.418 per-word bound, 42.8 perplexity estimate based on a held-out corpus of 481 documents with 2882 words
# 2021-11-03 20:06:03,733 : INFO : PROGRESS: pass 11, at document #481/481
# 2021-11-03 20:06:03,805 : INFO : topic #0 (0.250): 0.038*"부항" + 0.037*"진행" + 0.027*"찜질" + 0.026*"주말" + 0.025*"가깝다" + 0.023*"기본" + 0.022*"다만" + 0.021*"원래" + 0.020*"모두" + 0.019*"해주시"
# 2021-11-03 20:06:03,806 : INFO : topic #1 (0.250): 0.026*"얘기" + 0.024*"복용" + 0.023*"기계" + 0.022*"잘못" + 0.020*"이야기" + 0.019*"태도" + 0.019*"가지" + 0.018*"굉장하다" + 0.018*"입원" + 0.018*"여자"
# 2021-11-03 20:06:03,806 : INFO : topic #2 (0.250): 0.035*"꾸준하다" + 0.026*"개인" + 0.025*"침술" + 0.024*"대충" + 0.024*"보통" + 0.023*"거의" + 0.023*"부위" + 0.021*"결제" + 0.019*"다리" + 0.018*"여러"
# 2021-11-03 20:06:03,806 : INFO : topic #3 (0.250): 0.035*"주사" + 0.035*"피부" + 0.030*"시술" + 0.026*"전혀" + 0.023*"진짜" + 0.023*"체질" + 0.021*"달라" + 0.020*"이상" + 0.020*"안되다" + 0.019*"동안"
# 2021-11-03 20:06:03,807 : INFO : topic diff=0.060377, rho=0.277350
# 2021-11-03 20:06:03,810 : INFO : Epoch 11: Coherence estimate: -8.801888553329213
# 2021-11-03 20:06:03,904 : INFO : Epoch 11: Perplexity estimate: 42.65548576368894
# 2021-11-03 20:06:04,005 : INFO : -5.415 per-word bound, 42.7 perplexity estimate based on a held-out corpus of 481 documents with 2882 words
# 2021-11-03 20:06:04,005 : INFO : PROGRESS: pass 12, at document #481/481
# 2021-11-03 20:06:04,075 : INFO : topic #0 (0.250): 0.038*"부항" + 0.037*"진행" + 0.028*"찜질" + 0.027*"주말" + 0.025*"가깝다" + 0.023*"기본" + 0.022*"다만" + 0.021*"원래" + 0.020*"모두" + 0.020*"해주시"
# 2021-11-03 20:06:04,076 : INFO : topic #1 (0.250): 0.026*"얘기" + 0.024*"복용" + 0.023*"기계" + 0.022*"잘못" + 0.020*"이야기" + 0.020*"태도" + 0.019*"가지" + 0.019*"굉장하다" + 0.018*"여자" + 0.018*"입원"
# 2021-11-03 20:06:04,076 : INFO : topic #2 (0.250): 0.035*"꾸준하다" + 0.026*"개인" + 0.025*"침술" + 0.024*"대충" + 0.023*"보통" + 0.023*"거의" + 0.023*"부위" + 0.021*"결제" + 0.019*"다리" + 0.018*"여러"
# 2021-11-03 20:06:04,077 : INFO : topic #3 (0.250): 0.035*"주사" + 0.035*"피부" + 0.031*"시술" + 0.026*"전혀" + 0.023*"체질" + 0.023*"진짜" + 0.021*"달라" + 0.020*"이상" + 0.020*"안되다" + 0.019*"동안"
# 2021-11-03 20:06:04,077 : INFO : topic diff=0.054288, rho=0.267261
# 2021-11-03 20:06:04,081 : INFO : Epoch 12: Coherence estimate: -8.804170454247043
# 2021-11-03 20:06:04,176 : INFO : Epoch 12: Perplexity estimate: 42.570777509591295
# 2021-11-03 20:06:04,271 : INFO : -5.412 per-word bound, 42.6 perplexity estimate based on a held-out corpus of 481 documents with 2882 words
# 2021-11-03 20:06:04,272 : INFO : PROGRESS: pass 13, at document #481/481
# 2021-11-03 20:06:04,345 : INFO : topic #0 (0.250): 0.038*"부항" + 0.037*"진행" + 0.029*"찜질" + 0.027*"주말" + 0.025*"가깝다" + 0.023*"기본" + 0.022*"다만" + 0.021*"원래" + 0.020*"해주시" + 0.019*"모두"
# 2021-11-03 20:06:04,345 : INFO : topic #1 (0.250): 0.026*"얘기" + 0.025*"복용" + 0.024*"기계" + 0.023*"잘못" + 0.020*"이야기" + 0.020*"태도" + 0.019*"가지" + 0.019*"굉장하다" + 0.018*"여자" + 0.018*"입원"
# 2021-11-03 20:06:04,346 : INFO : topic #2 (0.250): 0.035*"꾸준하다" + 0.026*"개인" + 0.026*"침술" + 0.024*"대충" + 0.023*"거의" + 0.023*"보통" + 0.023*"부위" + 0.021*"결제" + 0.019*"다리" + 0.018*"여러"
# 2021-11-03 20:06:04,347 : INFO : topic #3 (0.250): 0.035*"주사" + 0.035*"피부" + 0.031*"시술" + 0.026*"전혀" + 0.023*"체질" + 0.023*"진짜" + 0.021*"달라" + 0.020*"안되다" + 0.020*"이상" + 0.019*"동안"
# 2021-11-03 20:06:04,347 : INFO : topic diff=0.048875, rho=0.258199
# 2021-11-03 20:06:04,350 : INFO : Epoch 13: Coherence estimate: -8.80212779440014
# 2021-11-03 20:06:04,453 : INFO : Epoch 13: Perplexity estimate: 42.4986582188689
# 2021-11-03 20:06:04,557 : INFO : -5.409 per-word bound, 42.5 perplexity estimate based on a held-out corpus of 481 documents with 2882 words
# 2021-11-03 20:06:04,557 : INFO : PROGRESS: pass 14, at document #481/481
# 2021-11-03 20:06:04,628 : INFO : topic #0 (0.250): 0.039*"부항" + 0.037*"진행" + 0.029*"찜질" + 0.028*"주말" + 0.025*"가깝다" + 0.023*"기본" + 0.023*"다만" + 0.021*"원래" + 0.020*"해주시" + 0.019*"빠르다"
# 2021-11-03 20:06:04,629 : INFO : topic #1 (0.250): 0.026*"얘기" + 0.025*"복용" + 0.024*"기계" + 0.023*"잘못" + 0.020*"이야기" + 0.020*"태도" + 0.019*"가지" + 0.019*"굉장하다" + 0.019*"여자" + 0.018*"입원"
# 2021-11-03 20:06:04,629 : INFO : topic #2 (0.250): 0.035*"꾸준하다" + 0.026*"개인" + 0.026*"침술" + 0.025*"대충" + 0.023*"거의" + 0.023*"보통" + 0.023*"부위" + 0.021*"결제" + 0.019*"다리" + 0.018*"여러"
# 2021-11-03 20:06:04,630 : INFO : topic #3 (0.250): 0.035*"주사" + 0.035*"피부" + 0.032*"시술" + 0.026*"전혀" + 0.023*"체질" + 0.023*"진짜" + 0.021*"달라" + 0.021*"안되다" + 0.020*"이상" + 0.019*"동안"
# 2021-11-03 20:06:04,631 : INFO : topic diff=0.043951, rho=0.250000
# 2021-11-03 20:06:04,634 : INFO : Epoch 14: Coherence estimate: -8.67682909365208
# 2021-11-03 20:06:04,727 : INFO : Epoch 14: Perplexity estimate: 42.438006366582115
# 2021-11-03 20:06:04,820 : INFO : -5.407 per-word bound, 42.4 perplexity estimate based on a held-out corpus of 481 documents with 2882 words
# 2021-11-03 20:06:04,820 : INFO : PROGRESS: pass 15, at document #481/481
# 2021-11-03 20:06:04,889 : INFO : topic #0 (0.250): 0.039*"부항" + 0.037*"진행" + 0.029*"찜질" + 0.028*"주말" + 0.025*"가깝다" + 0.023*"기본" + 0.023*"다만" + 0.021*"원래" + 0.020*"해주시" + 0.019*"기억"
# 2021-11-03 20:06:04,890 : INFO : topic #1 (0.250): 0.026*"얘기" + 0.025*"복용" + 0.024*"기계" + 0.023*"잘못" + 0.020*"이야기" + 0.020*"태도" + 0.019*"가지" + 0.019*"굉장하다" + 0.019*"여자" + 0.018*"입원"
# 2021-11-03 20:06:04,890 : INFO : topic #2 (0.250): 0.035*"꾸준하다" + 0.026*"개인" + 0.026*"침술" + 0.025*"대충" + 0.023*"거의" + 0.023*"부위" + 0.023*"보통" + 0.021*"결제" + 0.019*"다리" + 0.018*"여러"
# 2021-11-03 20:06:04,891 : INFO : topic #3 (0.250): 0.035*"주사" + 0.035*"피부" + 0.032*"시술" + 0.026*"전혀" + 0.024*"체질" + 0.023*"진짜" + 0.021*"달라" + 0.021*"안되다" + 0.020*"이상" + 0.019*"동안"
# 2021-11-03 20:06:04,891 : INFO : topic diff=0.040131, rho=0.242536
# 2021-11-03 20:06:04,893 : INFO : Epoch 15: Coherence estimate: -8.443367957552484
# 2021-11-03 20:06:04,988 : INFO : Epoch 15: Perplexity estimate: 42.3853085135651
# 2021-11-03 20:06:05,080 : INFO : -5.405 per-word bound, 42.4 perplexity estimate based on a held-out corpus of 481 documents with 2882 words
# 2021-11-03 20:06:05,081 : INFO : PROGRESS: pass 16, at document #481/481
# 2021-11-03 20:06:05,154 : INFO : topic #0 (0.250): 0.039*"부항" + 0.038*"진행" + 0.030*"찜질" + 0.028*"주말" + 0.025*"가깝다" + 0.023*"기본" + 0.023*"다만" + 0.021*"원래" + 0.020*"해주시" + 0.020*"기억"
# 2021-11-03 20:06:05,155 : INFO : topic #1 (0.250): 0.026*"얘기" + 0.025*"복용" + 0.024*"기계" + 0.023*"잘못" + 0.020*"이야기" + 0.020*"태도" + 0.019*"가지" + 0.019*"굉장하다" + 0.019*"여자" + 0.018*"입원"
# 2021-11-03 20:06:05,155 : INFO : topic #2 (0.250): 0.035*"꾸준하다" + 0.026*"개인" + 0.026*"침술" + 0.025*"대충" + 0.023*"거의" + 0.023*"부위" + 0.023*"보통" + 0.021*"결제" + 0.019*"다리" + 0.018*"여러"
# 2021-11-03 20:06:05,156 : INFO : topic #3 (0.250): 0.035*"주사" + 0.035*"피부" + 0.032*"시술" + 0.026*"전혀" + 0.024*"체질" + 0.023*"진짜" + 0.021*"달라" + 0.021*"안되다" + 0.020*"이상" + 0.019*"동안"
# 2021-11-03 20:06:05,156 : INFO : topic diff=0.036136, rho=0.235702
# 2021-11-03 20:06:05,159 : INFO : Epoch 16: Coherence estimate: -8.443367957552484
# 2021-11-03 20:06:05,254 : INFO : Epoch 16: Perplexity estimate: 42.33874796306135
# 2021-11-03 20:06:05,345 : INFO : -5.404 per-word bound, 42.3 perplexity estimate based on a held-out corpus of 481 documents with 2882 words
# 2021-11-03 20:06:05,345 : INFO : PROGRESS: pass 17, at document #481/481
# 2021-11-03 20:06:05,419 : INFO : topic #0 (0.250): 0.039*"부항" + 0.038*"진행" + 0.030*"찜질" + 0.028*"주말" + 0.025*"가깝다" + 0.024*"기본" + 0.023*"다만" + 0.021*"원래" + 0.020*"기억" + 0.020*"해주시"
# 2021-11-03 20:06:05,419 : INFO : topic #1 (0.250): 0.026*"얘기" + 0.025*"복용" + 0.025*"기계" + 0.023*"잘못" + 0.021*"이야기" + 0.021*"태도" + 0.019*"굉장하다" + 0.019*"가지" + 0.019*"여자" + 0.018*"입원"
# 2021-11-03 20:06:05,420 : INFO : topic #2 (0.250): 0.035*"꾸준하다" + 0.027*"개인" + 0.026*"침술" + 0.025*"대충" + 0.023*"거의" + 0.023*"부위" + 0.023*"보통" + 0.021*"결제" + 0.019*"다리" + 0.019*"여러"
# 2021-11-03 20:06:05,420 : INFO : topic #3 (0.250): 0.035*"주사" + 0.035*"피부" + 0.033*"시술" + 0.026*"전혀" + 0.024*"체질" + 0.023*"진짜" + 0.021*"달라" + 0.021*"안되다" + 0.020*"이상" + 0.019*"동안"
# 2021-11-03 20:06:05,421 : INFO : topic diff=0.032794, rho=0.229416
# 2021-11-03 20:06:05,423 : INFO : Epoch 17: Coherence estimate: -8.444136859346145
# 2021-11-03 20:06:05,517 : INFO : Epoch 17: Perplexity estimate: 42.30058768735131
# 2021-11-03 20:06:05,609 : INFO : -5.403 per-word bound, 42.3 perplexity estimate based on a held-out corpus of 481 documents with 2882 words
# 2021-11-03 20:06:05,609 : INFO : PROGRESS: pass 18, at document #481/481
# 2021-11-03 20:06:05,682 : INFO : topic #0 (0.250): 0.039*"부항" + 0.038*"진행" + 0.030*"찜질" + 0.029*"주말" + 0.025*"가깝다" + 0.024*"기본" + 0.023*"다만" + 0.021*"원래" + 0.021*"기억" + 0.020*"해주시"
# 2021-11-03 20:06:05,682 : INFO : topic #1 (0.250): 0.026*"얘기" + 0.025*"복용" + 0.025*"기계" + 0.023*"잘못" + 0.021*"이야기" + 0.021*"태도" + 0.019*"굉장하다" + 0.019*"가지" + 0.019*"여자" + 0.018*"입원"
# 2021-11-03 20:06:05,683 : INFO : topic #2 (0.250): 0.035*"꾸준하다" + 0.027*"개인" + 0.026*"침술" + 0.025*"대충" + 0.023*"거의" + 0.023*"부위" + 0.023*"보통" + 0.021*"결제" + 0.019*"다리" + 0.019*"여러"
# 2021-11-03 20:06:05,684 : INFO : topic #3 (0.250): 0.035*"주사" + 0.035*"피부" + 0.033*"시술" + 0.026*"전혀" + 0.024*"체질" + 0.023*"진짜" + 0.021*"달라" + 0.021*"안되다" + 0.020*"이상" + 0.019*"동안"
# 2021-11-03 20:06:05,684 : INFO : topic diff=0.030150, rho=0.223607
# 2021-11-03 20:06:05,687 : INFO : Epoch 18: Coherence estimate: -8.444136859346145
# 2021-11-03 20:06:05,782 : INFO : Epoch 18: Perplexity estimate: 42.2641091579267
# 2021-11-03 20:06:05,875 : INFO : -5.401 per-word bound, 42.3 perplexity estimate based on a held-out corpus of 481 documents with 2882 words
# 2021-11-03 20:06:05,875 : INFO : PROGRESS: pass 19, at document #481/481
# 2021-11-03 20:06:05,946 : INFO : topic #0 (0.250): 0.039*"부항" + 0.038*"진행" + 0.030*"찜질" + 0.029*"주말" + 0.025*"가깝다" + 0.024*"다만" + 0.024*"기본" + 0.021*"원래" + 0.021*"기억" + 0.020*"해주시"
# 2021-11-03 20:06:05,946 : INFO : topic #1 (0.250): 0.026*"얘기" + 0.025*"기계" + 0.025*"복용" + 0.024*"잘못" + 0.021*"이야기" + 0.021*"태도" + 0.019*"굉장하다" + 0.019*"가지" + 0.019*"여자" + 0.018*"입원"
# 2021-11-03 20:06:05,947 : INFO : topic #2 (0.250): 0.035*"꾸준하다" + 0.027*"개인" + 0.026*"침술" + 0.025*"대충" + 0.023*"거의" + 0.023*"부위" + 0.023*"보통" + 0.021*"결제" + 0.019*"다리" + 0.019*"여러"
# 2021-11-03 20:06:05,948 : INFO : topic #3 (0.250): 0.035*"주사" + 0.035*"피부" + 0.033*"시술" + 0.026*"전혀" + 0.025*"체질" + 0.023*"진짜" + 0.021*"달라" + 0.021*"안되다" + 0.020*"이상" + 0.019*"동안"
# 2021-11-03 20:06:05,949 : INFO : topic diff=0.027694, rho=0.218218
# 2021-11-03 20:06:05,951 : INFO : Epoch 19: Coherence estimate: -8.44828073571251
# 2021-11-03 20:06:06,045 : INFO : Epoch 19: Perplexity estimate: 42.230457190550915
# 2021-11-03 20:06:06,138 : INFO : -5.400 per-word bound, 42.2 perplexity estimate based on a held-out corpus of 481 documents with 2882 words
# 2021-11-03 20:06:06,139 : INFO : PROGRESS: pass 20, at document #481/481
# 2021-11-03 20:06:06,219 : INFO : topic #0 (0.250): 0.039*"부항" + 0.038*"진행" + 0.031*"찜질" + 0.029*"주말" + 0.025*"가깝다" + 0.024*"다만" + 0.024*"기본" + 0.022*"기억" + 0.021*"원래" + 0.020*"해주시"
# 2021-11-03 20:06:06,220 : INFO : topic #1 (0.250): 0.026*"얘기" + 0.025*"기계" + 0.025*"복용" + 0.024*"잘못" + 0.021*"태도" + 0.021*"이야기" + 0.019*"굉장하다" + 0.019*"가지" + 0.019*"여자" + 0.018*"입원"
# 2021-11-03 20:06:06,220 : INFO : topic #2 (0.250): 0.035*"꾸준하다" + 0.027*"개인" + 0.026*"침술" + 0.025*"대충" + 0.023*"부위" + 0.023*"거의" + 0.023*"보통" + 0.021*"결제" + 0.019*"다리" + 0.019*"여러"
# 2021-11-03 20:06:06,221 : INFO : topic #3 (0.250): 0.035*"주사" + 0.035*"피부" + 0.033*"시술" + 0.026*"전혀" + 0.025*"체질" + 0.023*"진짜" + 0.021*"달라" + 0.021*"안되다" + 0.020*"이상" + 0.019*"동안"
# 2021-11-03 20:06:06,221 : INFO : topic diff=0.025525, rho=0.213201
# 2021-11-03 20:06:06,224 : INFO : Epoch 20: Coherence estimate: -8.449215487301446
# 2021-11-03 20:06:06,318 : INFO : Epoch 20: Perplexity estimate: 42.19869236853512
# 2021-11-03 20:06:06,410 : INFO : -5.399 per-word bound, 42.2 perplexity estimate based on a held-out corpus of 481 documents with 2882 words
# 2021-11-03 20:06:06,411 : INFO : PROGRESS: pass 21, at document #481/481
# 2021-11-03 20:06:06,481 : INFO : topic #0 (0.250): 0.040*"부항" + 0.038*"진행" + 0.031*"찜질" + 0.029*"주말" + 0.025*"가깝다" + 0.024*"다만" + 0.024*"기본" + 0.022*"기억" + 0.021*"원래" + 0.021*"저렴하다"
# 2021-11-03 20:06:06,482 : INFO : topic #1 (0.250): 0.026*"얘기" + 0.025*"기계" + 0.024*"복용" + 0.024*"잘못" + 0.021*"태도" + 0.021*"이야기" + 0.019*"가지" + 0.019*"굉장하다" + 0.019*"여자" + 0.018*"입원"
# 2021-11-03 20:06:06,483 : INFO : topic #2 (0.250): 0.035*"꾸준하다" + 0.027*"개인" + 0.026*"침술" + 0.025*"대충" + 0.023*"부위" + 0.023*"거의" + 0.023*"보통" + 0.021*"결제" + 0.019*"다리" + 0.019*"여러"
# 2021-11-03 20:06:06,483 : INFO : topic #3 (0.250): 0.035*"주사" + 0.035*"피부" + 0.033*"시술" + 0.026*"전혀" + 0.025*"체질" + 0.023*"진짜" + 0.021*"달라" + 0.021*"안되다" + 0.020*"이상" + 0.019*"동안"
# 2021-11-03 20:06:06,484 : INFO : topic diff=0.023839, rho=0.208514
# 2021-11-03 20:06:06,486 : INFO : Epoch 21: Coherence estimate: -8.569152627517715
# 2021-11-03 20:06:06,580 : INFO : Epoch 21: Perplexity estimate: 42.16745849919253
# 2021-11-03 20:06:06,673 : INFO : -5.398 per-word bound, 42.2 perplexity estimate based on a held-out corpus of 481 documents with 2882 words
# 2021-11-03 20:06:06,673 : INFO : PROGRESS: pass 22, at document #481/481
# 2021-11-03 20:06:06,744 : INFO : topic #0 (0.250): 0.040*"부항" + 0.038*"진행" + 0.031*"찜질" + 0.029*"주말" + 0.025*"가깝다" + 0.024*"다만" + 0.024*"기본" + 0.022*"기억" + 0.021*"원래" + 0.021*"저렴하다"
# 2021-11-03 20:06:06,744 : INFO : topic #1 (0.250): 0.026*"얘기" + 0.025*"기계" + 0.024*"복용" + 0.024*"잘못" + 0.021*"태도" + 0.021*"이야기" + 0.019*"가지" + 0.019*"굉장하다" + 0.019*"여자" + 0.018*"입원"
# 2021-11-03 20:06:06,745 : INFO : topic #2 (0.250): 0.035*"꾸준하다" + 0.027*"개인" + 0.026*"침술" + 0.025*"대충" + 0.024*"부위" + 0.023*"거의" + 0.023*"보통" + 0.020*"결제" + 0.019*"다리" + 0.019*"여러"
# 2021-11-03 20:06:06,746 : INFO : topic #3 (0.250): 0.035*"주사" + 0.035*"피부" + 0.033*"시술" + 0.026*"전혀" + 0.025*"체질" + 0.023*"진짜" + 0.021*"달라" + 0.021*"안되다" + 0.020*"이상" + 0.019*"동안"
# 2021-11-03 20:06:06,746 : INFO : topic diff=0.022330, rho=0.204124
# 2021-11-03 20:06:06,750 : INFO : Epoch 22: Coherence estimate: -8.569152627517715
# 2021-11-03 20:06:06,842 : INFO : Epoch 22: Perplexity estimate: 42.13825963069322
# 2021-11-03 20:06:06,933 : INFO : -5.397 per-word bound, 42.1 perplexity estimate based on a held-out corpus of 481 documents with 2882 words
# 2021-11-03 20:06:06,934 : INFO : PROGRESS: pass 23, at document #481/481
# 2021-11-03 20:06:07,003 : INFO : topic #0 (0.250): 0.040*"부항" + 0.038*"진행" + 0.032*"찜질" + 0.029*"주말" + 0.025*"가깝다" + 0.024*"다만" + 0.024*"기본" + 0.022*"기억" + 0.021*"원래" + 0.021*"저렴하다"
# 2021-11-03 20:06:07,004 : INFO : topic #1 (0.250): 0.026*"얘기" + 0.025*"기계" + 0.024*"복용" + 0.024*"잘못" + 0.022*"태도" + 0.021*"이야기" + 0.019*"가지" + 0.019*"여자" + 0.019*"굉장하다" + 0.018*"입원"
# 2021-11-03 20:06:07,004 : INFO : topic #2 (0.250): 0.035*"꾸준하다" + 0.027*"개인" + 0.026*"침술" + 0.025*"대충" + 0.024*"부위" + 0.023*"거의" + 0.023*"보통" + 0.020*"결제" + 0.019*"다리" + 0.019*"진단"
# 2021-11-03 20:06:07,005 : INFO : topic #3 (0.250): 0.035*"주사" + 0.035*"피부" + 0.034*"시술" + 0.026*"전혀" + 0.025*"체질" + 0.023*"진짜" + 0.021*"달라" + 0.021*"안되다" + 0.020*"이상" + 0.019*"동안"
# 2021-11-03 20:06:07,005 : INFO : topic diff=0.021259, rho=0.200000
# 2021-11-03 20:06:07,008 : INFO : Epoch 23: Coherence estimate: -8.566628987117285
# 2021-11-03 20:06:07,102 : INFO : Epoch 23: Perplexity estimate: 42.10635208992948
# 2021-11-03 20:06:07,196 : INFO : -5.396 per-word bound, 42.1 perplexity estimate based on a held-out corpus of 481 documents with 2882 words
# 2021-11-03 20:06:07,196 : INFO : PROGRESS: pass 24, at document #481/481
# 2021-11-03 20:06:07,265 : INFO : topic #0 (0.250): 0.040*"부항" + 0.038*"진행" + 0.032*"찜질" + 0.029*"주말" + 0.025*"가깝다" + 0.025*"다만" + 0.024*"기본" + 0.023*"기억" + 0.022*"원래" + 0.021*"저렴하다"
# 2021-11-03 20:06:07,267 : INFO : topic #1 (0.250): 0.026*"얘기" + 0.025*"기계" + 0.024*"복용" + 0.024*"잘못" + 0.022*"태도" + 0.021*"이야기" + 0.019*"여자" + 0.019*"가지" + 0.019*"굉장하다" + 0.018*"입원"
# 2021-11-03 20:06:07,267 : INFO : topic #2 (0.250): 0.035*"꾸준하다" + 0.027*"개인" + 0.026*"침술" + 0.025*"대충" + 0.024*"부위" + 0.023*"거의" + 0.023*"보통" + 0.020*"결제" + 0.019*"진단" + 0.019*"다리"
# 2021-11-03 20:06:07,267 : INFO : topic #3 (0.250): 0.035*"주사" + 0.035*"피부" + 0.034*"시술" + 0.026*"전혀" + 0.025*"체질" + 0.023*"진짜" + 0.021*"달라" + 0.021*"안되다" + 0.020*"이상" + 0.019*"동안"
# 2021-11-03 20:06:07,267 : INFO : topic diff=0.019863, rho=0.196116
# 2021-11-03 20:06:07,270 : INFO : Epoch 24: Coherence estimate: -8.567214323315385
# 2021-11-03 20:06:07,362 : INFO : Epoch 24: Perplexity estimate: 42.078179077019165
# 2021-11-03 20:06:07,454 : INFO : -5.395 per-word bound, 42.1 perplexity estimate based on a held-out corpus of 481 documents with 2882 words
# 2021-11-03 20:06:07,454 : INFO : PROGRESS: pass 25, at document #481/481
# 2021-11-03 20:06:07,523 : INFO : topic #0 (0.250): 0.040*"부항" + 0.038*"진행" + 0.032*"찜질" + 0.029*"주말" + 0.025*"가깝다" + 0.025*"다만" + 0.024*"기본" + 0.023*"기억" + 0.022*"저렴하다" + 0.022*"원래"
# 2021-11-03 20:06:07,523 : INFO : topic #1 (0.250): 0.025*"얘기" + 0.025*"기계" + 0.024*"잘못" + 0.024*"복용" + 0.022*"태도" + 0.021*"이야기" + 0.019*"여자" + 0.019*"가지" + 0.019*"굉장하다" + 0.018*"입원"
# 2021-11-03 20:06:07,524 : INFO : topic #2 (0.250): 0.035*"꾸준하다" + 0.027*"개인" + 0.026*"침술" + 0.025*"대충" + 0.024*"부위" + 0.023*"거의" + 0.022*"보통" + 0.020*"결제" + 0.020*"진단" + 0.019*"다리"
# 2021-11-03 20:06:07,524 : INFO : topic #3 (0.250): 0.035*"주사" + 0.035*"피부" + 0.034*"시술" + 0.026*"전혀" + 0.025*"체질" + 0.023*"진짜" + 0.021*"달라" + 0.021*"안되다" + 0.020*"이상" + 0.019*"동안"
# 2021-11-03 20:06:07,525 : INFO : topic diff=0.018545, rho=0.192450
# 2021-11-03 20:06:07,527 : INFO : Epoch 25: Coherence estimate: -8.567868673513477
# 2021-11-03 20:06:07,620 : INFO : Epoch 25: Perplexity estimate: 42.0512703487393
# 2021-11-03 20:06:07,714 : INFO : -5.394 per-word bound, 42.1 perplexity estimate based on a held-out corpus of 481 documents with 2882 words
# 2021-11-03 20:06:07,714 : INFO : PROGRESS: pass 26, at document #481/481
# 2021-11-03 20:06:07,785 : INFO : topic #0 (0.250): 0.040*"부항" + 0.038*"진행" + 0.032*"찜질" + 0.029*"주말" + 0.025*"가깝다" + 0.025*"다만" + 0.024*"기본" + 0.023*"기억" + 0.022*"저렴하다" + 0.022*"원래"
# 2021-11-03 20:06:07,787 : INFO : topic #1 (0.250): 0.025*"얘기" + 0.025*"기계" + 0.024*"잘못" + 0.024*"복용" + 0.022*"태도" + 0.021*"이야기" + 0.019*"여자" + 0.019*"가지" + 0.019*"굉장하다" + 0.018*"입원"
# 2021-11-03 20:06:07,787 : INFO : topic #2 (0.250): 0.035*"꾸준하다" + 0.027*"개인" + 0.026*"침술" + 0.025*"대충" + 0.024*"부위" + 0.023*"거의" + 0.022*"보통" + 0.020*"결제" + 0.020*"진단" + 0.019*"여러"
# 2021-11-03 20:06:07,788 : INFO : topic #3 (0.250): 0.035*"주사" + 0.035*"피부" + 0.034*"시술" + 0.026*"전혀" + 0.025*"체질" + 0.023*"진짜" + 0.021*"달라" + 0.021*"안되다" + 0.020*"이상" + 0.019*"동안"
# 2021-11-03 20:06:07,788 : INFO : topic diff=0.017401, rho=0.188982
# 2021-11-03 20:06:07,791 : INFO : Epoch 26: Coherence estimate: -8.556316220507485
# 2021-11-03 20:06:07,885 : INFO : Epoch 26: Perplexity estimate: 42.0242506579617
# 2021-11-03 20:06:07,977 : INFO : -5.393 per-word bound, 42.0 perplexity estimate based on a held-out corpus of 481 documents with 2882 words
# 2021-11-03 20:06:07,978 : INFO : PROGRESS: pass 27, at document #481/481
# 2021-11-03 20:06:08,047 : INFO : topic #0 (0.250): 0.040*"부항" + 0.038*"진행" + 0.032*"찜질" + 0.030*"주말" + 0.026*"가깝다" + 0.025*"다만" + 0.024*"기본" + 0.023*"기억" + 0.022*"저렴하다" + 0.022*"원래"
# 2021-11-03 20:06:08,047 : INFO : topic #1 (0.250): 0.025*"얘기" + 0.025*"기계" + 0.024*"잘못" + 0.024*"복용" + 0.022*"태도" + 0.022*"이야기" + 0.020*"여자" + 0.019*"가지" + 0.019*"굉장하다" + 0.018*"입원"
# 2021-11-03 20:06:08,048 : INFO : topic #2 (0.250): 0.035*"꾸준하다" + 0.026*"개인" + 0.026*"침술" + 0.025*"대충" + 0.024*"부위" + 0.023*"거의" + 0.022*"보통" + 0.020*"진단" + 0.020*"결제" + 0.019*"여러"
# 2021-11-03 20:06:08,048 : INFO : topic #3 (0.250): 0.035*"주사" + 0.035*"피부" + 0.034*"시술" + 0.026*"전혀" + 0.025*"체질" + 0.023*"진짜" + 0.021*"달라" + 0.021*"안되다" + 0.019*"동안" + 0.019*"이상"
# 2021-11-03 20:06:08,048 : INFO : topic diff=0.016705, rho=0.185695
# 2021-11-03 20:06:08,051 : INFO : Epoch 27: Coherence estimate: -8.55471798677164
# 2021-11-03 20:06:08,144 : INFO : Epoch 27: Perplexity estimate: 41.99751390129802
# 2021-11-03 20:06:08,236 : INFO : -5.392 per-word bound, 42.0 perplexity estimate based on a held-out corpus of 481 documents with 2882 words
# 2021-11-03 20:06:08,236 : INFO : PROGRESS: pass 28, at document #481/481
# 2021-11-03 20:06:08,307 : INFO : topic #0 (0.250): 0.040*"부항" + 0.038*"진행" + 0.032*"찜질" + 0.030*"주말" + 0.026*"다만" + 0.026*"가깝다" + 0.024*"기본" + 0.023*"기억" + 0.022*"저렴하다" + 0.022*"원래"
# 2021-11-03 20:06:08,307 : INFO : topic #1 (0.250): 0.025*"얘기" + 0.025*"기계" + 0.024*"잘못" + 0.023*"복용" + 0.023*"태도" + 0.022*"이야기" + 0.020*"여자" + 0.019*"가지" + 0.019*"굉장하다" + 0.018*"입원"
# 2021-11-03 20:06:08,308 : INFO : topic #2 (0.250): 0.035*"꾸준하다" + 0.026*"개인" + 0.026*"침술" + 0.025*"대충" + 0.024*"부위" + 0.023*"거의" + 0.022*"보통" + 0.021*"진단" + 0.020*"결제" + 0.019*"여러"
# 2021-11-03 20:06:08,308 : INFO : topic #3 (0.250): 0.035*"주사" + 0.035*"피부" + 0.034*"시술" + 0.026*"전혀" + 0.025*"체질" + 0.023*"진짜" + 0.021*"달라" + 0.021*"안되다" + 0.019*"동안" + 0.019*"전반"
# 2021-11-03 20:06:08,308 : INFO : topic diff=0.015822, rho=0.182574
# 2021-11-03 20:06:08,311 : INFO : Epoch 28: Coherence estimate: -8.800563266164952
# 2021-11-03 20:06:08,406 : INFO : Epoch 28: Perplexity estimate: 41.969362184023964
# 2021-11-03 20:06:08,496 : INFO : -5.391 per-word bound, 42.0 perplexity estimate based on a held-out corpus of 481 documents with 2882 words
# 2021-11-03 20:06:08,497 : INFO : PROGRESS: pass 29, at document #481/481
# 2021-11-03 20:06:08,566 : INFO : topic #0 (0.250): 0.040*"부항" + 0.038*"진행" + 0.033*"찜질" + 0.030*"주말" + 0.026*"다만" + 0.026*"가깝다" + 0.024*"기본" + 0.023*"기억" + 0.022*"저렴하다" + 0.022*"원래"
# 2021-11-03 20:06:08,566 : INFO : topic #1 (0.250): 0.025*"얘기" + 0.025*"기계" + 0.024*"잘못" + 0.023*"복용" + 0.023*"태도" + 0.022*"이야기" + 0.020*"여자" + 0.019*"가지" + 0.019*"굉장하다" + 0.018*"입원"
# 2021-11-03 20:06:08,568 : INFO : topic #2 (0.250): 0.035*"꾸준하다" + 0.026*"개인" + 0.026*"침술" + 0.025*"대충" + 0.024*"부위" + 0.023*"거의" + 0.022*"보통" + 0.021*"진단" + 0.020*"결제" + 0.019*"여러"
# 2021-11-03 20:06:08,568 : INFO : topic #3 (0.250): 0.035*"주사" + 0.035*"피부" + 0.035*"시술" + 0.026*"전혀" + 0.025*"체질" + 0.023*"진짜" + 0.021*"달라" + 0.021*"안되다" + 0.019*"동안" + 0.019*"전반"
# 2021-11-03 20:06:08,569 : INFO : topic diff=0.015355, rho=0.179605
# 2021-11-03 20:06:08,572 : INFO : Epoch 29: Coherence estimate: -8.800563266164952
# 2021-11-03 20:06:08,662 : INFO : Epoch 29: Perplexity estimate: 41.94013984171886
# 2021-11-03 20:06:08,662 : INFO : LdaModel lifecycle event {'msg': 'trained LdaModel(num_terms=167, num_topics=4, decay=0.5, chunksize=2000) in 8.34s', 'datetime': '2021-11-03T20:06:08.662965', 'gensim': '4.1.2', 'python': '3.8.11 (default, Aug  6 2021, 09:57:55) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19042-SP0', 'event': 'created'}
# 2021-11-03 20:06:08,663 : INFO : topic #0 (0.250): 0.040*"부항" + 0.038*"진행" + 0.033*"찜질" + 0.030*"주말" + 0.026*"다만"
# 2021-11-03 20:06:08,663 : INFO : topic #1 (0.250): 0.025*"얘기" + 0.025*"기계" + 0.024*"잘못" + 0.023*"복용" + 0.023*"태도"
# 2021-11-03 20:06:08,664 : INFO : topic #2 (0.250): 0.035*"꾸준하다" + 0.026*"개인" + 0.026*"침술" + 0.025*"대충" + 0.024*"부위"
# 2021-11-03 20:06:08,664 : INFO : topic #3 (0.250): 0.035*"주사" + 0.035*"피부" + 0.035*"시술" + 0.026*"전혀" + 0.025*"체질"
# 2021-11-03 20:06:08,667 : INFO : using ParallelWordOccurrenceAccumulator(processes=15, batch_size=64) to estimate probabilities from sliding windows
# (0, '0.040*"부항" + 0.038*"진행" + 0.033*"찜질" + 0.030*"주말" + 0.026*"다만"')
# (1, '0.025*"얘기" + 0.025*"기계" + 0.024*"잘못" + 0.023*"복용" + 0.023*"태도"')
# (2, '0.035*"꾸준하다" + 0.026*"개인" + 0.026*"침술" + 0.025*"대충" + 0.024*"부위"')
# (3, '0.035*"주사" + 0.035*"피부" + 0.035*"시술" + 0.026*"전혀" + 0.025*"체질"')
# 2021-11-03 20:06:11,440 : INFO : 15 accumulators retrieved from output queue
# 2021-11-03 20:06:11,461 : INFO : accumulated word occurrence stats for 948 virtual documents
# 2021-11-03 20:06:11,596 : INFO : Dictionary lifecycle event {'fname_or_handle': 'lda_dictionary.gensim', 'separately': 'None', 'sep_limit': 10485760, 'ignore': frozenset(), 'datetime': '2021-11-03T20:06:11.596036', 'gensim': '4.1.2', 'python': '3.8.11 (default, Aug  6 2021, 09:57:55) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19042-SP0', 'event': 'saving'}
# 2021-11-03 20:06:11,597 : INFO : saved lda_dictionary.gensim
# 2021-11-03 20:06:11,598 : INFO : LdaState lifecycle event {'fname_or_handle': 'lda_model.gensim.state', 'separately': 'None', 'sep_limit': 10485760, 'ignore': frozenset(), 'datetime': '2021-11-03T20:06:11.598003', 'gensim': '4.1.2', 'python': '3.8.11 (default, Aug  6 2021, 09:57:55) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19042-SP0', 'event': 'saving'}
# 2021-11-03 20:06:11,599 : INFO : saved lda_model.gensim.state
# 2021-11-03 20:06:11,600 : INFO : LdaModel lifecycle event {'fname_or_handle': 'lda_model.gensim', 'separately': "['expElogbeta', 'sstats']", 'sep_limit': 10485760, 'ignore': ['state', 'dispatcher', 'id2word'], 'datetime': '2021-11-03T20:06:11.600004', 'gensim': '4.1.2', 'python': '3.8.11 (default, Aug  6 2021, 09:57:55) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19042-SP0', 'event': 'saving'}
# 2021-11-03 20:06:11,600 : INFO : storing np array 'expElogbeta' to lda_model.gensim.expElogbeta.npy
# 2021-11-03 20:06:11,601 : INFO : not storing attribute state
# 2021-11-03 20:06:11,602 : INFO : not storing attribute dispatcher
# 2021-11-03 20:06:11,602 : INFO : not storing attribute id2word
# 2021-11-03 20:06:11,604 : INFO : saved lda_model.gensim
# Coherence Score (c_v):  0.3685917111884536
#
# Coherence Score (u_mass):  -10.403123586147862
# C:\Users\yukir\anaconda3\envs\NLP\lib\site-packages\pyLDAvis\_prepare.py:228: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   default_term_info  = pd.DataFrame({'saliency': saliency, 'Term': vocab, \
# Note: if you're in the IPython notebook, pyLDAvis.show() is not the best command
#       to use. Consider using pyLDAvis.display(), or pyLDAvis.enable_notebook().
#       See more information at http://pyLDAvis.github.io/quickstart.html .
#
# You must interrupt the kernel to end this command
#
# Serving to http://127.0.0.1:8891/    [Ctrl-C to exit]
# 127.0.0.1 - - [03/Nov/2021 20:06:16] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Nov/2021 20:06:16] "GET /LDAvis.css HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Nov/2021 20:06:16] "GET /d3.js HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Nov/2021 20:06:16] "GET /LDAvis.js HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Nov/2021 20:06:16] code 404, message Not Found
# 127.0.0.1 - - [03/Nov/2021 20:06:16] "GET /favicon.ico HTTP/1.1" 404 -
